# %%
# Parameters
DatasetID = "DS000017724"
DEV = False
test_DatasetID = ""
DS_test = False
title = "Recursion DLD1 Library3- Screen2 (NGS5888)"
description = "Production scale screen in DLD-1 cells with 1/4 of the genome-wide CRISPR library (sub-lib-3, ~22K guides). 1 time point: Day-5. We performed 24 rxns of 10x 3' HT kit with an estimated loading of 52K cells. We performed a pilot study to test the library quality before the production-level sequencing. We will submit 72 libraries (24 GEX, 24 HTO and 24 sgRNA) We request 600M reads for GEX, 20M for HTO and 40M for sgRNA, after finishing QC sequencing of NGS5887. NGS has built the GEX and sgRNA libraries using automation, we will provide manually constructed HTO libraries."
name_space = [{"id": "GRCh38", "type": "genome"}]
sources = [{"id": "Siavash-1234", "name": "Geo-ID"}]
tech_name = "scRNA-seq"
author = "SG"
alt_experiments = ["crispr", "hashing"]
organism = "human"
groupby = "Sample"
min_cells = 3
min_genes = 500
max_genes = None
pct_mt = None
total_counts = None
n_top_genes = 2000
ribo = True
doublets = True
Mapping_rate = {"LIB6238859_SAM24456643": "Total number of reads: 93950171\nNumber of reads with valid cell barcodes: 91425705 (97.31%)\nNumber of reads with valid feature barcodes: 80603221 (85.79%)\nNumber of reads with valid cell and feature barcodes: 78798541 (83.87%)\n\nSection LIB6238859_SAM24456643.crispr\nNumber of valid cell barcodes: 173302\nNumber of valid reads (with matching cell and feature barcodes): 78798541\nMean number of valid reads per cell barcode: 454.69\nNumber of valid UMIs (with matching cell and feature barcodes): 2504575\nMean number of valid UMIs per cell barcode: 14.45\nSequencing saturation: 96.82%\n", "LIB6238835_SAM24456643": "Total number of reads: 24595367\nNumber of reads with valid cell barcodes: 23625577 (96.06%)\nNumber of reads with valid feature barcodes: 22834511 (92.84%)\nNumber of reads with valid cell and feature barcodes: 22326114 (90.77%)\n\nSection LIB6238835_SAM24456643.hashing\nNumber of valid cell barcodes: 819552\nNumber of valid reads (with matching cell and feature barcodes): 22326114\nMean number of valid reads per cell barcode: 27.24\nNumber of valid UMIs (with matching cell and feature barcodes): 18871282\nMean number of valid UMIs per cell barcode: 23.03\nSequencing saturation: 15.47%\n", "LIB6238861_SAM24456643": "Total number of reads: 83282937\nNumber of reads with valid cell barcodes: 80772593 (96.99%)\nNumber of reads with valid feature barcodes: 70991820 (85.24%)\nNumber of reads with valid cell and feature barcodes: 69148437 (83.03%)\n\nSection LIB6238861_SAM24456643.crispr\nNumber of valid cell barcodes: 192799\nNumber of valid reads (with matching cell and feature barcodes): 69148437\nMean number of valid reads per cell barcode: 358.66\nNumber of valid UMIs (with matching cell and feature barcodes): 2414110\nMean number of valid UMIs per cell barcode: 12.52\nSequencing saturation: 96.51%\n", "LIB6238837_SAM24456643": "Total number of reads: 21099389\nNumber of reads with valid cell barcodes: 20168622 (95.59%)\nNumber of reads with valid feature barcodes: 19400248 (91.95%)\nNumber of reads with valid cell and feature barcodes: 18968705 (89.90%)\n\nSection LIB6238837_SAM24456643.hashing\nNumber of valid cell barcodes: 840549\nNumber of valid reads (with matching cell and feature barcodes): 18968705\nMean number of valid reads per cell barcode: 22.57\nNumber of valid UMIs (with matching cell and feature barcodes): 15813721\nMean number of valid UMIs per cell barcode: 18.81\nSequencing saturation: 16.63%\n", "LIB6238860_SAM24456643": "Total number of reads: 88913790\nNumber of reads with valid cell barcodes: 86377687 (97.15%)\nNumber of reads with valid feature barcodes: 75742163 (85.19%)\nNumber of reads with valid cell and feature barcodes: 73888485 (83.10%)\n\nSection LIB6238860_SAM24456643.crispr\nNumber of valid cell barcodes: 192490\nNumber of valid reads (with matching cell and feature barcodes): 73888485\nMean number of valid reads per cell barcode: 383.86\nNumber of valid UMIs (with matching cell and feature barcodes): 2210235\nMean number of valid UMIs per cell barcode: 11.48\nSequencing saturation: 97.01%\n", "LIB6238836_SAM24456643": "Total number of reads: 20895214\nNumber of reads with valid cell barcodes: 19808219 (94.80%)\nNumber of reads with valid feature barcodes: 18912185 (90.51%)\nNumber of reads with valid cell and feature barcodes: 18485035 (88.47%)\n\nSection LIB6238836_SAM24456643.hashing\nNumber of valid cell barcodes: 750806\nNumber of valid reads (with matching cell and feature barcodes): 18485035\nMean number of valid reads per cell barcode: 24.62\nNumber of valid UMIs (with matching cell and feature barcodes): 15365497\nMean number of valid UMIs per cell barcode: 20.47\nSequencing saturation: 16.88%\n", "LIB6238858_SAM24456643": "Total number of reads: 83828767\nNumber of reads with valid cell barcodes: 81585254 (97.32%)\nNumber of reads with valid feature barcodes: 72067159 (85.97%)\nNumber of reads with valid cell and feature barcodes: 70439275 (84.03%)\n\nSection LIB6238858_SAM24456643.crispr\nNumber of valid cell barcodes: 166330\nNumber of valid reads (with matching cell and feature barcodes): 70439275\nMean number of valid reads per cell barcode: 423.49\nNumber of valid UMIs (with matching cell and feature barcodes): 2468445\nMean number of valid UMIs per cell barcode: 14.84\nSequencing saturation: 96.50%\n", "LIB6238834_SAM24456643": "Total number of reads: 26104042\nNumber of reads with valid cell barcodes: 25133236 (96.28%)\nNumber of reads with valid feature barcodes: 24255677 (92.92%)\nNumber of reads with valid cell and feature barcodes: 23731353 (90.91%)\n\nSection LIB6238834_SAM24456643.hashing\nNumber of valid cell barcodes: 826133\nNumber of valid reads (with matching cell and feature barcodes): 23731353\nMean number of valid reads per cell barcode: 28.73\nNumber of valid UMIs (with matching cell and feature barcodes): 20068264\nMean number of valid UMIs per cell barcode: 24.29\nSequencing saturation: 15.44%\n"}
raw_qc = "/gstore/scratch/u/ghaffars/Dataset/crc_NGS5888//DS000017724/raw_qc.h5ad"
raw_embedding = "/gstore/scratch/u/ghaffars/Dataset/crc_NGS5888//DS000017724/qc_embedding.h5ad"

# %% [markdown]
#  # QC analysis of single cell RNA-seq dataset: This notebook will guide you through the process of quality control analyis on a single-cell RNA sequencing dataset

# %%
# Different scenario for original dataset or test dataset
try:
    if DS_test==True:
        DSID = test_DatasetID
        Version = '2'   # the version of your dataset
        DEV = True
    elif len(alt_experiments)==2:
        DSID = DatasetID
        Version = '4'   # the version of your dataset
        your_experiment = "crispr_hashing_harmonized" # A string that is a key known for our desired experimnet that you wish to work on
    else:
        DSID = DatasetID
        Version = '2'   # the version of your dataset
        your_experiment = "main" # A string that is a key known for our desired experimnet that you wish to work on

except TypeError:
    DSID = DatasetID
    Version = '1'   # the version of your dataset
    your_experiment = "raw_qc" # A string that is a key known for our desired experimnet that you wish to work on

New_experiment = "raw_qc" # A string that is a key known for the updated data saved by that that name

# %%
## Import Libraries
from __future__ import division
import pandas as pd

#single cell libraries
import scanpy as sc

#general
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

#plotting
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('talk')

# %%
import sys
sys.path.append("..")
import Templates.tools.DatasetDB as DB
import Templates.tools.RNA_Seq_QC as rnaqc
import Templates.tools.scProc as proc
try:
    import Templates.tools.rapids_modified as rp
except ImportError:
        pass

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Check if GPU device is available

# %%
GPU = rnaqc.pipeline_has_gpu()

# %%
GPU
# Out:
# True

# %% [markdown]
# ## Instantiate a dataset object given our dataset info

# %%
DS = DB.DATASET(DSID, DEV, title=title, description=description, name_space=name_space, organism=organism,
                       sources=sources, tech_name=tech_name, author=author)

# %%
adata, adatas = DS.load_dataset(Version, your_experiment, Corr=False)
# Out:
# 08:43:42 -> Collating dataset: 'DS000017724' metadata.
# 08:43:42 -> Retrieving all project: 'DS000017724@4' metadata.
# 08:43:42 -> Reading: 'DS000017724'.
#
# 08:43:42 -> Reading: 'DS000017724 -> Experiment: main'.
#
# 08:43:42 -> Reading: 'DS000017724 -> Experiment: main -> Alt. Exp.: crispr'.
# 08:43:43 -> Reading: 'DS000017724 -> Experiment: main -> Alt. Exp.: hashing'.
# 08:43:45 -> Reading: 'DS000017724 -> Experiment: crispr_hashing_harmonized'.
#
# 08:43:45 -> Reading: 'DS000017724 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: crispr'.
# 08:43:46 -> Reading: 'DS000017724 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: hashing'.

# %%
adata = rnaqc.load_data(adata,  alt_experiments)

# %%
adata.obs.head()
# Out:
#                                         Sample           Barcode  \
# SAM24456643_rep5-AAACCCAAGAGGTCAC  SAM24456643  AAACCCAAGAGGTCAC
# SAM24456643_rep5-AAACCCAAGCCTGCCA  SAM24456643  AAACCCAAGCCTGCCA
# SAM24456643_rep5-AAACCCAAGCTGTCCG  SAM24456643  AAACCCAAGCTGTCCG
# SAM24456643_rep5-AAACCCAAGGTTCACT  SAM24456643  AAACCCAAGGTTCACT
# SAM24456643_rep5-AAACCCAAGGTTGGAC  SAM24456643  AAACCCAAGGTTGGAC
#
#                                   DemuxType_crispr  \
# SAM24456643_rep5-AAACCCAAGAGGTCAC          doublet
# SAM24456643_rep5-AAACCCAAGCCTGCCA          singlet
# SAM24456643_rep5-AAACCCAAGCTGTCCG          unknown
# SAM24456643_rep5-AAACCCAAGGTTCACT          singlet
# SAM24456643_rep5-AAACCCAAGGTTGGAC          doublet
#
#                                                 DemuxAssignment_crispr  \
# SAM24456643_rep5-AAACCCAAGAGGTCAC  ENSG00000176171_3,ENSG00000243811_3
# SAM24456643_rep5-AAACCCAAGCCTGCCA                    ENSG00000134313_4
# SAM24456643_rep5-AAACCCAAGCTGTCCG                              unknown
# SAM24456643_rep5-AAACCCAAGGTTCACT                    ENSG00000206538_3
# SAM24456643_rep5-AAACCCAAGGTTGGAC  ENSG00000223611_1,ENSG00000142549_4
#
#                                   DemuxType_hashing DemuxAssignment_hashing  \
# SAM24456643_rep5-AAACCCAAGAGGTCAC           singlet             SAM24439044
# SAM24456643_rep5-AAACCCAAGCCTGCCA           singlet             SAM24439043
# SAM24456643_rep5-AAACCCAAGCTGTCCG           singlet             SAM24439045
# SAM24456643_rep5-AAACCCAAGGTTCACT           singlet             SAM24439044
# SAM24456643_rep5-AAACCCAAGGTTGGAC           singlet             SAM24439043
#
#                                   cellline timepoint     HTO   NGS_ID  \
# SAM24456643_rep5-AAACCCAAGAGGTCAC     DLD1      day5  HTO-14  NGS5888
# SAM24456643_rep5-AAACCCAAGCCTGCCA     DLD1      day5   HTO-1  NGS5888
# SAM24456643_rep5-AAACCCAAGCTGTCCG     DLD1      day5   HTO-8  NGS5888
# SAM24456643_rep5-AAACCCAAGGTTCACT     DLD1      day5   HTO-5  NGS5888
# SAM24456643_rep5-AAACCCAAGGTTGGAC     DLD1      day5   HTO-2  NGS5888
#
#                                   Biological_replicate 10Xrun  \
# SAM24456643_rep5-AAACCCAAGAGGTCAC          SAM24439044      5
# SAM24456643_rep5-AAACCCAAGCCTGCCA          SAM24439043      5
# SAM24456643_rep5-AAACCCAAGCTGTCCG          SAM24439045      5
# SAM24456643_rep5-AAACCCAAGGTTCACT          SAM24439044      5
# SAM24456643_rep5-AAACCCAAGGTTGGAC          SAM24439043      5
#
#                                                                           sublibrary  \
# SAM24456643_rep5-AAACCCAAGAGGTCAC  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
# SAM24456643_rep5-AAACCCAAGCCTGCCA  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
# SAM24456643_rep5-AAACCCAAGCTGTCCG  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
# SAM24456643_rep5-AAACCCAAGGTTCACT  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
# SAM24456643_rep5-AAACCCAAGGTTGGAC  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
#
#                                   gRNA_library_MOI  \
# SAM24456643_rep5-AAACCCAAGAGGTCAC              0.5
# SAM24456643_rep5-AAACCCAAGCCTGCCA              0.5
# SAM24456643_rep5-AAACCCAAGCTGTCCG              0.5
# SAM24456643_rep5-AAACCCAAGGTTCACT              0.5
# SAM24456643_rep5-AAACCCAAGGTTGGAC              0.5
#
#                                                            gene_symbol  \
# SAM24456643_rep5-AAACCCAAGAGGTCAC  ENSG00000176171_3,ENSG00000243811_3
# SAM24456643_rep5-AAACCCAAGCCTGCCA                            KIDINS220
# SAM24456643_rep5-AAACCCAAGCTGTCCG                              unknown
# SAM24456643_rep5-AAACCCAAGGTTCACT                                VGLL3
# SAM24456643_rep5-AAACCCAAGGTTGGAC  ENSG00000223611_1,ENSG00000142549_4
#
#                                                                  class
# SAM24456643_rep5-AAACCCAAGAGGTCAC  ENSG00000176171_3,ENSG00000243811_3
# SAM24456643_rep5-AAACCCAAGCCTGCCA                               target
# SAM24456643_rep5-AAACCCAAGCTGTCCG                              unknown
# SAM24456643_rep5-AAACCCAAGGTTCACT                               target
# SAM24456643_rep5-AAACCCAAGGTTGGAC  ENSG00000223611_1,ENSG00000142549_4

# %%
adata.var.head()
# Out:
#                                         ID                     Symbol  \
# Symbol
# 3xLinker                 3xLinker_3xLinker          3xLinker_3xLinker
# MIR1302-2HG  GRCh38-2020-A_ENSG00000243485  GRCh38-2020-A_MIR1302-2HG
# FAM138A      GRCh38-2020-A_ENSG00000237613      GRCh38-2020-A_FAM138A
# OR4F5        GRCh38-2020-A_ENSG00000186092        GRCh38-2020-A_OR4F5
# AL627309.1   GRCh38-2020-A_ENSG00000238009   GRCh38-2020-A_AL627309.1
#
#                         Type
# Symbol
# 3xLinker     Gene Expression
# MIR1302-2HG  Gene Expression
# FAM138A      Gene Expression
# OR4F5        Gene Expression
# AL627309.1   Gene Expression

# %% [markdown]
# ## Mapping Rate information

# %%
combined_df,agg,agg_percentage = rnaqc.Mapping_reads_info(Mapping_rate)

# %%
combined_df
# Out:
#                        Total number of reads  \
# LIB6238859_SAM24456643              93950171
# LIB6238835_SAM24456643              24595367
# LIB6238836_SAM24456643                                           15365497
# LIB6238858_SAM24456643                                            2468445
# LIB6238834_SAM24456643                                           20068264
#
#                        Mean number of valid UMIs per cell barcode  \
# LIB6238859_SAM24456643                                      14.45
# LIB6238835_SAM24456643                                      23.03
# LIB6238861_SAM24456643                                      12.52
# LIB6238837_SAM24456643                                      18.81
# LIB6238860_SAM24456643                                      11.48
# LIB6238836_SAM24456643                                      20.47
# LIB6238858_SAM24456643                                      14.84
# LIB6238834_SAM24456643                                      24.29
#
#                        Sequencing saturation Experiment
# LIB6238859_SAM24456643                96.82%     crispr
# LIB6238835_SAM24456643                15.47%    hashing
# LIB6238861_SAM24456643                96.51%     crispr
# LIB6238837_SAM24456643                16.63%    hashing
# LIB6238860_SAM24456643                97.01%     crispr
# LIB6238836_SAM24456643                16.88%    hashing
# LIB6238858_SAM24456643                96.50%     crispr
# LIB6238834_SAM24456643                15.44%    hashing

# %%
#Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
agg.plot(kind='barh', ax=ax1, stacked=False, color=['midnightblue', 'blue', 'deepskyblue'], legend=False)
ax1.set_xlabel('Read Count')
agg_percentage.plot(kind='barh', ax=ax2, stacked=False, color=['midnightblue', 'blue', 'deepskyblue'])
ax2.set_xlabel('%Read Count')
ax2.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.suptitle('Mapping Rate', fontsize=25)
plt.show()

# %% [markdown]
# ## Doublet information

# %%
rnaqc.doublet_counter(adata)
# Out:
#                                                     Cell counts
# total Cells                                              108700
# cells after keeping singlets by hashing                   85766
# cells after keeping singlets by gRNA                      45681
# cells after keeping singlets by both hashing an...        40638

# %% [markdown]
# ### Sumarize counts

# %%
cnts_before = rnaqc.Summerize_counts(adata, groupby)

# %%
cnts_before
# Out:
#                 cnt    pct
# Sample
# SAM24456643  108700  100.0

# %% [markdown]
# ### calculate qc metrics

# %%
adata = proc.calc_qc_metrics(adata, organism)

# %%
LOWER,UPPER = rnaqc.upper_lower_limits(adata, groupby)

# %%
LOWER
# Out:
#              n_genes_by_counts  total_counts  pct_counts_mt  pct_counts_ribo
# SAM24456643           -994.125     -12002.25      -1.812208        -2.382138

# %%
UPPER
# Out:
#              n_genes_by_counts  total_counts  pct_counts_mt  pct_counts_ribo
# SAM24456643           9090.875      35167.75      12.882227        31.981959

# %%
sc.pl.scatter(adata, 'n_genes_by_counts', 'total_counts', color='pct_counts_mt')

# %%
sc.pl.scatter(adata, 'pct_counts_mt', 'pct_counts_ribo', color='n_genes_by_counts')

# %%
sc.pl.violin(
    adata, 
    [
     'n_genes_by_counts', 
     'total_counts', 
     'pct_counts_mt'
     ],
    multi_panel=True
)

# %%
aggr = rnaqc.aggregation(adata, groupby, None, 'before')

# %%
adata.obs.head()
# Out:
#                                         Sample           Barcode  \
# SAM24456643_rep5-AAACCCAAGAGGTCAC  SAM24456643  AAACCCAAGAGGTCAC
# SAM24456643_rep5-AAACCCAAGCCTGCCA  SAM24456643  AAACCCAAGCCTGCCA
# SAM24456643_rep5-AAACCCAAGCTGTCCG  SAM24456643  AAACCCAAGCTGTCCG
# SAM24456643_rep5-AAACCCAAGGTTCACT  SAM24456643  AAACCCAAGGTTCACT
# SAM24456643_rep5-AAACCCAAGGTTGGAC  SAM24456643  AAACCCAAGGTTGGAC
#
#                                   DemuxType_crispr  \
# SAM24456643_rep5-AAACCCAAGAGGTCAC          doublet
# SAM24456643_rep5-AAACCCAAGCCTGCCA          singlet
# SAM24456643_rep5-AAACCCAAGCTGTCCG          unknown
# SAM24456643_rep5-AAACCCAAGGTTCACT          singlet
# SAM24456643_rep5-AAACCCAAGGTTGGAC          doublet
#
#                                                 DemuxAssignment_crispr  \
# SAM24456643_rep5-AAACCCAAGAGGTCAC  ENSG00000176171_3,ENSG00000243811_3
# SAM24456643_rep5-AAACCCAAGCCTGCCA                    ENSG00000134313_4
# SAM24456643_rep5-AAACCCAAGCTGTCCG                              unknown
# SAM24456643_rep5-AAACCCAAGGTTCACT                    ENSG00000206538_3
# SAM24456643_rep5-AAACCCAAGGTTGGAC  ENSG00000223611_1,ENSG00000142549_4
#
#                                   DemuxType_hashing DemuxAssignment_hashing  \
# SAM24456643_rep5-AAACCCAAGAGGTCAC           singlet             SAM24439044
# SAM24456643_rep5-AAACCCAAGCCTGCCA           singlet             SAM24439043
# SAM24456643_rep5-AAACCCAAGCTGTCCG           singlet             SAM24439045
# SAM24456643_rep5-AAACCCAAGGTTCACT           singlet             SAM24439044
# SAM24456643_rep5-AAACCCAAGGTTGGAC           singlet             SAM24439043
#
#                                   cellline timepoint     HTO   NGS_ID  ...  \
# SAM24456643_rep5-AAACCCAAGAGGTCAC     DLD1      day5  HTO-14  NGS5888  ...
# SAM24456643_rep5-AAACCCAAGCCTGCCA     DLD1      day5   HTO-1  NGS5888  ...
# SAM24456643_rep5-AAACCCAAGCTGTCCG     DLD1      day5   HTO-8  NGS5888  ...
# SAM24456643_rep5-AAACCCAAGGTTCACT     DLD1      day5   HTO-5  NGS5888  ...
# SAM24456643_rep5-AAACCCAAGGTTGGAC     DLD1      day5   HTO-2  NGS5888  ...
#
#                                                                           sublibrary  \
# SAM24456643_rep5-AAACCCAAGAGGTCAC  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
# SAM24456643_rep5-AAACCCAAGCCTGCCA  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
# SAM24456643_rep5-AAACCCAAGCTGTCCG  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
# SAM24456643_rep5-AAACCCAAGGTTCACT  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
# SAM24456643_rep5-AAACCCAAGGTTGGAC  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
#
#                                   gRNA_library_MOI  \
# SAM24456643_rep5-AAACCCAAGAGGTCAC              0.5
# SAM24456643_rep5-AAACCCAAGCCTGCCA              0.5
# SAM24456643_rep5-AAACCCAAGCTGTCCG              0.5
# SAM24456643_rep5-AAACCCAAGGTTCACT              0.5
# SAM24456643_rep5-AAACCCAAGGTTGGAC              0.5
#
#                                                            gene_symbol  \
# SAM24456643_rep5-AAACCCAAGAGGTCAC  ENSG00000176171_3,ENSG00000243811_3
# SAM24456643_rep5-AAACCCAAGCCTGCCA                            KIDINS220
# SAM24456643_rep5-AAACCCAAGCTGTCCG                              unknown
# SAM24456643_rep5-AAACCCAAGGTTCACT                                VGLL3
# SAM24456643_rep5-AAACCCAAGGTTGGAC  ENSG00000223611_1,ENSG00000142549_4
#
#                                                                  class  \
# SAM24456643_rep5-AAACCCAAGAGGTCAC  ENSG00000176171_3,ENSG00000243811_3
# SAM24456643_rep5-AAACCCAAGCCTGCCA                               target
# SAM24456643_rep5-AAACCCAAGCTGTCCG                              unknown
# SAM24456643_rep5-AAACCCAAGGTTCACT                               target
# SAM24456643_rep5-AAACCCAAGGTTGGAC  ENSG00000223611_1,ENSG00000142549_4
#
#                                   n_genes_by_counts total_counts  \
# SAM24456643_rep5-AAACCCAAGAGGTCAC              4718        14380
# SAM24456643_rep5-AAACCCAAGCCTGCCA              4489        12787
# SAM24456643_rep5-AAACCCAAGCTGTCCG              4249        12870
# SAM24456643_rep5-AAACCCAAGGTTCACT              4497        13266
# SAM24456643_rep5-AAACCCAAGGTTGGAC              5141        16001
#
#                                    total_counts_mt  pct_counts_mt  \
# SAM24456643_rep5-AAACCCAAGAGGTCAC              878       6.105702
# SAM24456643_rep5-AAACCCAAGCCTGCCA              482       3.769453
# SAM24456643_rep5-AAACCCAAGCTGTCCG              498       3.869464
# SAM24456643_rep5-AAACCCAAGGTTCACT              719       5.419870
# SAM24456643_rep5-AAACCCAAGGTTGGAC              697       4.355978
#
#                                    total_counts_ribo  pct_counts_ribo
# SAM24456643_rep5-AAACCCAAGAGGTCAC               2398        16.675939
# SAM24456643_rep5-AAACCCAAGCCTGCCA               1843        14.413076
# SAM24456643_rep5-AAACCCAAGCTGTCCG               2710        21.056721
# SAM24456643_rep5-AAACCCAAGGTTCACT               2356        17.759686
# SAM24456643_rep5-AAACCCAAGGTTGGAC               2778        17.361415
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Instantiate a RapidsSingleCellPipeline object given our AnnData to prepare RAPIDS environment for other steps

# %%
RP = rp.RapidsSingleCellPipeline(adata)

# %% [markdown]
# ## Notice:
# - **RP._adata is adata before filtering**
# - **RP.adata_ is adata after filtering**
# - **Rp.adata is adata after normalization (and highly variable genes selected)**

# %%
max_cells = None
cell_batch_size = 100000
gene_batch_size = 1200
target_sum = 1e4
n_top_genes = 2000
counts_layer = "counts"
batch_key = "DemuxAssignment_hashing"

# %% [markdown]
# ## Apply filter using GPU

# %%
if GPU:
    RP.filter_data(
    groupby,
    min_genes=min_genes,
    max_genes=max_genes,
    max_cells=max_cells,
    cell_batch_size=cell_batch_size,
    min_cells=min_cells,
    gene_batch_size=gene_batch_size,
        ribo=ribo, 
        doublets=doublets,
        pct_mt=pct_mt, 
        total_counts=total_counts
)
# Out:
# starting with 108700 cells
# Filtering cells.
# Processed 0 cells..
# Processed 100000 cells..
# Filtering genes.
# Completed preprocessing.
# Calculating upper outliers
# Now 99650 cells after filtering max genes
# Calculating upper outliers
# Now 83843 cells after filtering pct mt
# Calculating upper outliers
# Now 81844 cells after filtering total counts
# Now 81652 cells after filtering pct ribo
# Now 68340 cells after keeping singlets by hashing
# Now 39746 cells after keeping singlets by gRNA
# Preprocessing took 34.66482877731323 seconds

# %%
RP._adata
# Out:
# AnnData object with n_obs × n_vars = 108700 × 36603
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo'
#     var: 'ID', 'Symbol', 'Type', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: '.internal'
#     layers: 'counts'

# %%
RP.adata_
# Out:
# View of AnnData object with n_obs × n_vars = 39746 × 32139
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo'
#     var: 'ID', 'Symbol', 'Type', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     layers: 'counts'

# %%
RP._adata.obs["qc_pass"] = RP._adata.obs.index.isin(RP.adata_.obs.index)

# %%
RP._adata.obs
# Out:
#                                         Sample           Barcode  \
# SAM24456643_rep5-AAACCCAAGAGGTCAC  SAM24456643  AAACCCAAGAGGTCAC
# SAM24456643_rep5-AAACCCAAGCCTGCCA  SAM24456643  AAACCCAAGCCTGCCA
# SAM24456643_rep5-AAACCCAAGCTGTCCG  SAM24456643  AAACCCAAGCTGTCCG
# SAM24456643_rep5-AAACCCAAGGTTCACT  SAM24456643  AAACCCAAGGTTCACT
# SAM24456643_rep5-AAACCCAAGGTTGGAC  SAM24456643  AAACCCAAGGTTGGAC
# ...                                        ...               ...
# SAM24456643_rep8-TTTGTTGTCAGGGAT
...
# SAM24456643_rep8-TTTGTTGTCAGGGATG             412       2.154361
# SAM24456643_rep8-TTTGTTGTCCATCGTC             285       3.798481
# SAM24456643_rep8-TTTGTTGTCGATCCAA            1203       5.665442
# SAM24456643_rep8-TTTGTTGTCGCGGACT             278       2.841955
# SAM24456643_rep8-TTTGTTGTCTAGGCAT               1       0.136426
#
#                                    total_counts_ribo  pct_counts_ribo  qc_pass
# SAM24456643_rep5-AAACCCAAGAGGTCAC               2398        16.675939    False
# SAM24456643_rep5-AAACCCAAGCCTGCCA               1843        14.413076     True
# SAM24456643_rep5-AAACCCAAGCTGTCCG               2710        21.056721    False
# SAM24456643_rep5-AAACCCAAGGTTCACT               2356        17.759686     True
# SAM24456643_rep5-AAACCCAAGGTTGGAC               2778        17.361415    False
# ...                                              ...              ...      ...
# SAM24456643_rep8-TTTGTTGTCAGGGATG               3015        15.765530    False
# SAM24456643_rep8-TTTGTTGTCCATCGTC               1154        15.380514     True
# SAM24456643_rep8-TTTGTTGTCGATCCAA               3115        14.669869    False
# SAM24456643_rep8-TTTGTTGTCGCGGACT               1865        19.065631    False
# SAM24456643_rep8-TTTGTTGTCTAGGCAT                212        28.922237    False
#
# [108700 rows x 23 columns]

# %% [markdown]
# ## Apply filter uisng CPU

# %%
if GPU==False:
    adata = proc.filter_adata(
    adata, 
    groupby, 
    min_cells, 
    min_genes, 
    ribo, 
    doublets=doublets, pct_mt=pct_mt)

# %%
sc.pl.scatter(RP.adata_, 'n_genes_by_counts', 'total_counts', color='pct_counts_mt')

# %%
sc.pl.scatter(RP.adata_, 'pct_counts_mt', 'pct_counts_ribo', color='n_genes_by_counts')

# %%
aggr = rnaqc.aggregation(RP.adata_, groupby,aggr, 'after')

# %%
#QC plots before and after
for k in ['n_genes_by_counts', 'total_counts', 'pct_counts_mt', 'pct_counts_ribo']:
    proc.plotQCSplit(aggr, groupby, k)

# %%
cnts_after = rnaqc.Summerize_counts(RP.adata_,groupby)

# %%
cnts_after
# Out:
#                cnt    pct
# Sample
# SAM24456643  39746  100.0

# %%
proc.aggCnts(cnts_before, cnts_after)
# Out:
#              before  after  pct left
# Sample
# SAM24456643  108700  39746      36.6

# %%
proc.plot_cell_left(cnts_before, cnts_after, groupby)

# %% [markdown]
# ## Run Normalize -> HGV -> PCA -> kNN -> Leiden -> UMAP

# %%
RP.proc(n_top_genes, norm=True, scale=True, regress=False, embedding=True, n_pcs=30, 
        n_neighbors=10, knn_n_pcs=30, batch_key=None)
# Out:
# normalizing
# Processed 0 cells..
# normalizing data.
# Completed preprocessing.
# Preprocessing took 4.38845682144165 seconds
# selecting highly variable genes
# Filtering to highly variable genes.
# Processed 0 genes..
# Processed 1200 genes..
# Processed 2400 genes..
# Processed 3600 genes..
# Processed 4800 genes..
# Processed 6000 genes..
# Processed 7200 genes..
# Processed 8400 genes..
# Processed 9600 genes..
# Processed 10800 genes..
# Processed 12000 genes..
# Processed 13200 genes..
# Processed 14400 genes..
# Processed 15600 genes..
# Processed 16800 genes..
# Processed 18000 genes..
# Processed 19200 genes..
# Processed 20400 genes..
# Processed 21600 genes..
# Processed 22800 genes..
# Processed 24000 genes..
# Processed 25200 genes..
# Processed 26400 genes..
# Processed 27600 genes..
# Processed 28800 genes..
# Processed 30000 genes..
# Processed 31200 genes..
# Completed preprocessing.
# Converting sparse GPU array to dense GPU array.
# Preprocessing took 13.178983449935913 seconds
# scaling
# scaling took 0.8343374729156494 seconds
# computing PCA
# PCA took 0.5814721584320068 seconds
# kNN took 4.709624528884888 seconds
# computing UMAP
# WARNING: .obsp["connectivities"] have not been computed using umap
# UMAP took 0.2774991989135742 seconds
# computing Leiden clustering
# Leiden clustering took 0.13190937042236328 seconds

# %% [markdown]
# ## Batch Correction

# %%
#RP.run_scvi(counts_layer = "counts", batch_key = "DemuxAssignment_hashing")

# %%
#RP.adata.obsm["X_scVI"]

# %% [markdown]
# ## Plot PCA UMAP

# %%
if GPU:
    sc.pl.umap(RP.adata, color="leiden")

# %%
if GPU:
    sc.pl.umap(RP.adata, color=groupby)

# %%
if GPU:
    sc.pl.umap(RP.adata, color="DemuxAssignment_hashing")

# %%
#This is just to quickly check how the data looks. Cell cycle scores are added to main adata object, but normalized and processed object is not saved
if GPU==False:
    adata_tmp = adata.copy()

# %%
if GPU==False:
    adata_tmp = proc.proc(adata_tmp, 'auto', norm=True, scale=True, regress=False, embedding=True)
    sc.pl.umap(adata_tmp, color=groupby)

# %% [markdown]
# ## Add score cell cycle

# %%
if organism=='human':
    fcc =  '/gstore/data/cbfunge/data/CellCycleGenes/Homo_sapiens.csv'
elif organism == 'mouse':
    fcc = '/gstore/data/cbfunge/data/CellCycleGenes/Mus_musculus.csv'
    
if GPU:
    proc.compute_cellCycleScores(RP._adata, fcc)
else:
    proc.compute_cellCycleScores(adata_tmp, fcc)

# %%
RP._adata
# Out:
# AnnData object with n_obs × n_vars = 108700 × 36603
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'qc_pass', 'S_score', 'G2M_score', 'phase'
#     var: 'ID', 'Symbol', 'Type', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: '.internal'
#     layers: 'counts'

# %%
RP.adata
# Out:
# AnnData object with n_obs × n_vars = 39746 × 2000
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'leiden'
#     uns: 'neighbors', 'umap', 'leiden_colors', 'Sample_colors', 'DemuxAssignment_hashing_colors'
#     obsm: 'X_pca', 'X_umap'
#     obsp: 'distances', 'connectivities'

# %%
if GPU==False:
    adata.obs['phase'] = adata_tmp.obs['phase']
    adata.obs['G2M_score'] = adata_tmp.obs['G2M_score']
    adata.obs['S_score'] = adata_tmp.obs['S_score']
    adata.obs

# %%
if GPU==False:
    sc.pl.umap(adata_tmp, color='phase')

# %%
adatas
# Out:
# {'crispr': AnnData object with n_obs × n_vars = 108700 × 20345
#      uns: '.internal'
#      layers: 'counts',
#  'hashing': AnnData object with n_obs × n_vars = 108700 × 19
#      uns: '.internal'
#      layers: 'counts'}

# %%
adatas_updated = adatas.copy()
if GPU:
    adata_updated = RP._adata.copy()
else:
    adata_updated = adata.copy()

# %%
adata_updated
# Out:
# AnnData object with n_obs × n_vars = 108700 × 36603
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'qc_pass', 'S_score', 'G2M_score', 'phase'
#     var: 'ID', 'Symbol', 'Type', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: '.internal'
#     layers: 'counts'

# %%
adatas_updated
# Out:
# {'crispr': AnnData object with n_obs × n_vars = 108700 × 20345
#      uns: '.internal'
#      layers: 'counts',
#  'hashing': AnnData object with n_obs × n_vars = 108700 × 19
#      uns: '.internal'
#      layers: 'counts'}

# %% [markdown]
# ### Write h5ad version on the disk

# %%
# If you wish to write on the disk
#adata_updated.var.index.name = None
#adata_updated.write_h5ad(raw_qc)

# %% [markdown]
# ## Write h5ad file with embedings for Energy Distance analaysis

# %%
if GPU:
    RP.adata_.obsp = RP.adata.obsp.copy()
    RP.adata_.obsm = RP.adata.obsm.copy()
else:
    adata.obsp = adata_tmp.obsp.copy()
    adata.obsm = adata_tmp.obsm.copy()

# %%
if GPU:
    adata_embedding = RP.adata_.copy()
else:
    adata_embedding = adata.copy()

# %%
adata_embedding.write_h5ad(raw_embedding)

# %% [markdown]
# ## Update the dataset with new experiment "raw_qc"

# %%
if DS_test==False:
    dsid, version = DS.update_dataset(New_experiment, adata_updated, adatas_updated, test=False)
else:    
    dsid, version = DS.update_another_dataset(test_DatasetID, True, 1, New_experiment, adata_updated, adatas_updated, test=True)
# Out:
# 08:46:00 -> Collating dataset: 'DS000017724' metadata.
# 08:46:00 -> Retrieving all project: 'DS000017724@1' metadata.
#
# 08:46:00 -> Reading: 'DS000017724'.
#
# 08:46:00 -> Reading: 'DS000017724 -> Experiment: main'.
#
# 08:46:00 -> Reading: 'DS000017724 -> Experiment: main -> Alt. Exp.: crispr'.
# 08:46:01 -> Reading: 'DS000017724 -> Experiment: main -> Alt. Exp.: hashing'.
# PYDSDB:INFO: Experiment already contained metadata, overwriting.
# PYDSDB:INFO: Experiment already contained metadata, overwriting.
# PYDSDB:INFO: Experiment already contained metadata, overwriting.
# Retrieving cached token data.
# Successfully authenticated.
# 08:47:32 -> Retrieving all project: 'DS000017724@latest' metadata.
# 08:47:33 -> Collating and validating project resources.
# 08:47:33 -> Attempting upload.
#   0%|                                        | 0/73 [00:00<?, ?file/s]
#   1%|▌                                       | 1/73 [00:00<00:23,  3.11file/s]
#   3%|█                                       | 2/73 [00:00<00:14,  4.77file/s]
#   4%|█▋                                      | 3/73 [00:01<00:25,  2.70file/s]
#   5%|██▏                                     | 4/73 [00:01<00:18,  3.65file/s]
#   7%|██▋                                     | 5/73 [00:01<00:14,  4.67file/s]
#  10%|███▊                                    | 7/73 [00:01<00:10,  6.35file/s]
#  12%|████▉                                   | 9/73 [00:02<00:13,  4.75file/s]
#  14%|█████▍                                  | 10/73 [00:02<00:11,  5.34file/s]
#  15%|██████                                  | 11/73 [00:02<00:11,  5.60file/s]
#  16%|██████▌                                 | 12/73 [00:02<00:14,  4.13file/s]
#  18%|███████                                 | 13/73 [00:02<00:12,  4.71file/s]
#  19%|███████▋                                | 14/73 [00:02<00:10,  5.42file/s]
#  21%|████████▏                               | 15/73 [00:03<00:09,  5.97file/s]
#  22%|████████▊                               | 16/73 [00:03<00:08,  6.50file/s]
#  23%|█████████▎                              | 17/73 [00:03<00:13,  4.08file/s]
#  26%|██████████▍                             | 19/73 [00:03<00:09,  5.88file/s]
#  29%|███████████▌                            | 21/73 [00:04<00:07,  6.99file/s]
#  30%|████████████                            | 22/73 [00:04<00:07,  6.95file/s]
#  32%|████████████▌                           | 23/73 [02:33<29:44, 35.69s/file]
#  33%|█████████████▏                          | 24/73 [02:33<21:50, 26.74s/file]
#  36%|██████████████▏                         | 26/73 [02:33<12:09, 15.52s/file]
#  37%|██████████████▊                         | 27/73 [02:47<11:29, 15.00s/file]
#  38%|███████████████▎                        | 28/73 [02:47<08:31, 11.37s/file]
#  40%|███████████████▉                        | 29/73 [02:47<06:13,  8.49s/file]
#  41%|████████████████▍                       | 30/73 [02:48<04:33,  6.36s/file]
#  42%|████████████████▉                       | 31/73 [02:54<04:24,  6.29s/file]
#  44%|█████████████████▌                      | 32/73 [02:54<03:05,  4.53s/file]
#  47%|██████████████████▋                     | 34/73 [02:55<01:39,  2.56s/file]
#  48%|███████████████████▏                    | 35/73 [02:55<01:14,  1.96s/file]
#  49%|███████████████████▋                    | 36/73 [02:55<00:55,  1.49s/file]
#  52%|████████████████████▊                   | 38/73 [02:55<00:31,  1.11file/s]
#  55%|█████████████████████▉                  | 40/73 [02:55<00:19,  1.69file/s]
#  58%|███████████████████████                 | 42/73 [02:56<00:14,  2.08file/s]
#  59%|███████████████████████▌                | 43/73 [02:56<00:12,  2.44file/s]
#  62%|████████████████████████▋               | 45/73 [02:56<00:08,  3.43file/s]
#  63%|█████████████████████████▏              | 46/73 [02:56<00:08,  3.27file/s]
#  64%|█████████████████████████▊              | 47/73 [02:57<00:08,  3.19file/s]
#  66%|██████████████████████████▎             | 48/73 [02:57<00:06,  3.82file/s]
#  67%|██████████████████████████▊             | 49/73 [02:57<00:06,  3.52file/s]
#  68%|███████████████████████████▍            | 50/73 [02:58<00:07,  3.07file/s]
#  70%|███████████████████████████▉            | 51/73 [02:58<00:10,  2.10file/s]
#  71%|████████████████████████████▍           | 52/73 [02:59<00:07,  2.69file/s]
#  73%|█████████████████████████████           | 53/73 [03:04<00:37,  1.89s/file]
#  74%|█████████████████████████████▌          | 54/73 [03:05<00:27,  1.45s/file]
#  75%|██████████████████████████████▏         | 55/73 [03:09<00:42,  2.37s/file]
#  77%|██████████████████████████████▋         | 56/73 [03:10<00:30,  1.79s/file]
#  78%|███████████████████████████████▏        | 57/73 [03:24<01:28,  5.55s/file]
#  79%|███████████████████████████████▊        | 58/73 [03:24<00:59,  3.94s/file]
#  82%|████████████████████████████████▉       | 60/73 [03:24<00:28,  2.17s/file]
#  84%|█████████████████████████████████▍      | 61/73 [03:24<00:20,  1.68s/file]
#  85%|█████████████████████████████████▉      | 62/73 [03:25<00:14,  1.34s/file]
#  86%|██████████████████████████████████▌     | 63/73 [03:26<00:11,  1.16s/file]
#  88%|███████████████████████████████████     | 64/73 [03:26<00:07,  1.16file/s]
#  90%|████████████████████████████████████▏   | 66/73 [03:26<00:03,  1.94file/s]
#  92%|████████████████████████████████████▋   | 67/73 [03:26<00:02,  2.07file/s]
#  93%|█████████████████████████████████████▎  | 68/73 [03:26<00:02,  2.47file/s]
#  95%|█████████████████████████████████████▊  | 69/73 [03:27<00:01,  2.57file/s]
#  96%|██████████████████████████████████████▎ | 70/73 [03:27<00:01,  2.63file/s]
#  99%|███████████████████████████████████████▍| 72/73 [03:59<00:07,  7.15s/file]
# 100%|████████████████████████████████████████| 73/73 [03:59<00:00,  5.50s/file]
# 100%|████████████████████████████████████████| 73/73 [03:59<00:00,  3.28s/file]
# Clearing upload info.
# 08:51:48 -> Upload completed.
# Processing...
# Processing...
# Processing...
# Upload successful, your DSID is 'DS000017724' and version is: '5'. Also written to 'upload_info.json' in staging dir.

# %%
dsid, version
# Out:
# ('DS000017724', '5')
