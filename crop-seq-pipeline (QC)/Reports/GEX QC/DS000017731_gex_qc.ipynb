# %%
# Parameters
DatasetID = "DS000017731"
DEV = False
test_DatasetID = ""
DS_test = False
title = "Recursion DLD1 Library3- Screen2 (NGS5888)"
description = "Production scale screen in DLD-1 cells with 1/4 of the genome-wide CRISPR library (sub-lib-3, ~22K guides). 1 time point: Day-5. We performed 24 rxns of 10x 3' HT kit with an estimated loading of 52K cells. We performed a pilot study to test the library quality before the production-level sequencing. We will submit 72 libraries (24 GEX, 24 HTO and 24 sgRNA) We request 600M reads for GEX, 20M for HTO and 40M for sgRNA, after finishing QC sequencing of NGS5887. NGS has built the GEX and sgRNA libraries using automation, we will provide manually constructed HTO libraries."
name_space = [{"id": "GRCh38", "type": "genome"}]
sources = [{"id": "Siavash-1234", "name": "Geo-ID"}]
tech_name = "scRNA-seq"
author = "SG"
alt_experiments = ["crispr", "hashing"]
organism = "human"
groupby = "Sample"
min_cells = 3
min_genes = 500
max_genes = None
pct_mt = None
total_counts = None
n_top_genes = 2000
ribo = True
doublets = True
Mapping_rate = {"LIB6238864_SAM24456643": "Total number of reads: 89896794\nNumber of reads with valid cell barcodes: 87563746 (97.40%)\nNumber of reads with valid feature barcodes: 76510333 (85.11%)\nNumber of reads with valid cell and feature barcodes: 74879915 (83.30%)\n\nSection LIB6238864_SAM24456643.crispr\nNumber of valid cell barcodes: 190010\nNumber of valid reads (with matching cell and feature barcodes): 74879915\nMean number of valid reads per cell barcode: 394.08\nNumber of valid UMIs (with matching cell and feature barcodes): 2764618\nMean number of valid UMIs per cell barcode: 14.55\nSequencing saturation: 96.31%\n", "LIB6238840_SAM24456643": "Total number of reads: 19414773\nNumber of reads with valid cell barcodes: 18546993 (95.53%)\nNumber of reads with valid feature barcodes: 17741537 (91.38%)\nNumber of reads with valid cell and feature barcodes: 17359355 (89.41%)\n\nSection LIB6238840_SAM24456643.hashing\nNumber of valid cell barcodes: 620501\nNumber of valid reads (with matching cell and feature barcodes): 17359355\nMean number of valid reads per cell barcode: 27.98\nNumber of valid UMIs (with matching cell and feature barcodes): 14928895\nMean number of valid UMIs per cell barcode: 24.06\nSequencing saturation: 14.00%\n", "LIB6238862_SAM24456643": "Total number of reads: 75499035\nNumber of reads with valid cell barcodes: 73482795 (97.33%)\nNumber of reads with valid feature barcodes: 64373165 (85.26%)\nNumber of reads with valid cell and feature barcodes: 62943218 (83.37%)\n\nSection LIB6238862_SAM24456643.crispr\nNumber of valid cell barcodes: 184869\nNumber of valid reads (with matching cell and feature barcodes): 62943218\nMean number of valid reads per cell barcode: 340.47\nNumber of valid UMIs (with matching cell and feature barcodes): 2456297\nMean number of valid UMIs per cell barcode: 13.29\nSequencing saturation: 96.10%\n", "LIB6238838_SAM24456643": "Total number of reads: 20414601\nNumber of reads with valid cell barcodes: 19464694 (95.35%)\nNumber of reads with valid feature barcodes: 18649078 (91.35%)\nNumber of reads with valid cell and feature barcodes: 18218505 (89.24%)\n\nSection LIB6238838_SAM24456643.hashing\nNumber of valid cell barcodes: 847227\nNumber of valid reads (with matching cell and feature barcodes): 18218505\nMean number of valid reads per cell barcode: 21.50\nNumber of valid UMIs (with matching cell and feature barcodes): 15540929\nMean number of valid UMIs per cell barcode: 18.34\nSequencing saturation: 14.70%\n", "LIB6238863_SAM24456643": "Total number of reads: 100954349\nNumber of reads with valid cell barcodes: 98342818 (97.41%)\nNumber of reads with valid feature barcodes: 86360254 (85.54%)\nNumber of reads with valid cell and feature barcodes: 84503934 (83.71%)\n\nSection LIB6238863_SAM24456643.crispr\nNumber of valid cell barcodes: 172720\nNumber of valid reads (with matching cell and feature barcodes): 84503934\nMean number of valid reads per cell barcode: 489.25\nNumber of valid UMIs (with matching cell and feature barcodes): 2842173\nMean number of valid UMIs per cell barcode: 16.46\nSequencing saturation: 96.64%\n", "LIB6238839_SAM24456643": "Total number of reads: 20428463\nNumber of reads with valid cell barcodes: 19669540 (96.28%)\nNumber of reads with valid feature barcodes: 19062788 (93.31%)\nNumber of reads with valid cell and feature barcodes: 18640890 (91.25%)\n\nSection LIB6238839_SAM24456643.hashing\nNumber of valid cell barcodes: 742338\nNumber of valid reads (with matching cell and feature barcodes): 18640890\nMean number of valid reads per cell barcode: 25.11\nNumber of valid UMIs (with matching cell and feature barcodes): 16301481\nMean number of valid UMIs per cell barcode: 21.96\nSequencing saturation: 12.55%\n", "LIB6238865_SAM24456643": "Total number of reads: 85681518\nNumber of reads with valid cell barcodes: 83412857 (97.35%)\nNumber of reads with valid feature barcodes: 73219504 (85.46%)\nNumber of reads with valid cell and feature barcodes: 71603176 (83.57%)\n\nSection LIB6238865_SAM24456643.crispr\nNumber of valid cell barcodes: 194659\nNumber of valid reads (with matching cell and feature barcodes): 71603176\nMean number of valid reads per cell barcode: 367.84\nNumber of valid UMIs (with matching cell and feature barcodes): 2554611\nMean number of valid UMIs per cell barcode: 13.12\nSequencing saturation: 96.43%\n", "LIB6238841_SAM24456643": "Total number of reads: 19794368\nNumber of reads with valid cell barcodes: 18926709 (95.62%)\nNumber of reads with valid feature barcodes: 18048888 (91.18%)\nNumber of reads with valid cell and feature barcodes: 17658413 (89.21%)\n\nSection LIB6238841_SAM24456643.hashing\nNumber of valid cell barcodes: 748284\nNumber of valid reads (with matching cell and feature barcodes): 17658413\nMean number of valid reads per cell barcode: 23.60\nNumber of valid UMIs (with matching cell and feature barcodes): 15092076\nMean number of valid UMIs per cell barcode: 20.17\nSequencing saturation: 14.53%\n"}
raw_qc = "/gstore/scratch/u/ghaffars/Dataset/crc_NGS5888//DS000017731/raw_qc.h5ad"
raw_embedding = "/gstore/scratch/u/ghaffars/Dataset/crc_NGS5888//DS000017731/qc_embedding.h5ad"

# %% [markdown]
#  # QC analysis of single cell RNA-seq dataset: This notebook will guide you through the process of quality control analyis on a single-cell RNA sequencing dataset

# %%
# Different scenario for original dataset or test dataset
try:
    if DS_test==True:
        DSID = test_DatasetID
        Version = '2'   # the version of your dataset
        DEV = True
    elif len(alt_experiments)==2:
        DSID = DatasetID
        Version = '4'   # the version of your dataset
        your_experiment = "crispr_hashing_harmonized" # A string that is a key known for our desired experimnet that you wish to work on
    else:
        DSID = DatasetID
        Version = '2'   # the version of your dataset
        your_experiment = "main" # A string that is a key known for our desired experimnet that you wish to work on

except TypeError:
    DSID = DatasetID
    Version = '1'   # the version of your dataset
    your_experiment = "raw_qc" # A string that is a key known for our desired experimnet that you wish to work on

New_experiment = "raw_qc" # A string that is a key known for the updated data saved by that that name

# %%
## Import Libraries
from __future__ import division
import pandas as pd

#single cell libraries
import scanpy as sc

#general
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

#plotting
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('talk')

# %%
import sys
sys.path.append("..")
import Templates.tools.DatasetDB as DB
import Templates.tools.RNA_Seq_QC as rnaqc
import Templates.tools.scProc as proc
try:
    import Templates.tools.rapids_modified as rp
except ImportError:
        pass

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Check if GPU device is available

# %%
GPU = rnaqc.pipeline_has_gpu()

# %%
GPU
# Out:
# True

# %% [markdown]
# ## Instantiate a dataset object given our dataset info

# %%
DS = DB.DATASET(DSID, DEV, title=title, description=description, name_space=name_space, organism=organism,
                       sources=sources, tech_name=tech_name, author=author)

# %%
adata, adatas = DS.load_dataset(Version, your_experiment, Corr=False)
# Out:
# 08:52:43 -> Collating dataset: 'DS000017731' metadata.
# 08:52:43 -> Retrieving all project: 'DS000017731@4' metadata.
# 08:52:43 -> Reading: 'DS000017731'.
#
# 08:52:43 -> Reading: 'DS000017731 -> Experiment: main'.
#
# 08:52:43 -> Reading: 'DS000017731 -> Experiment: main -> Alt. Exp.: crispr'.
# 08:52:43 -> Reading: 'DS000017731 -> Experiment: main -> Alt. Exp.: hashing'.
# 08:52:46 -> Reading: 'DS000017731 -> Experiment: crispr_hashing_harmonized'.
#
# 08:52:46 -> Reading: 'DS000017731 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: crispr'.
# 08:52:47 -> Reading: 'DS000017731 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: hashing'.

# %%
adata = rnaqc.load_data(adata,  alt_experiments)

# %%
adata.obs.head()
# Out:
#                                          Sample           Barcode  \
# SAM24456643_rep10-AAACCCAAGCTGCGAA  SAM24456643  AAACCCAAGCTGCGAA
# SAM24456643_rep10-AAACCCAAGGAGAATG  SAM24456643  AAACCCAAGGAGAATG
# SAM24456643_rep10-AAACCCAAGGCATCAG  SAM24456643  AAACCCAAGGCATCAG
# SAM24456643_rep10-AAACCCAAGTCATCCA  SAM24456643  AAACCCAAGTCATCCA
# SAM24456643_rep10-AAACCCAAGTGCACTT  SAM24456643  AAACCCAAGTGCACTT
#
#                                    DemuxType_crispr DemuxAssignment_crispr  \
# SAM24456643_rep10-AAACCCAAGCTGCGAA          singlet      ENSG00000182950_1
# SAM24456643_rep10-AAACCCAAGGAGAATG          unknown                unknown
# SAM24456643_rep10-AAACCCAAGGCATCAG          singlet      ENSG00000137726_2
# SAM24456643_rep10-AAACCCAAGTCATCCA          unknown                unknown
# SAM24456643_rep10-AAACCCAAGTGCACTT          singlet      ENSG00000187555_1
#
#                                    DemuxType_hashing DemuxAssignment_hashing  \
# SAM24456643_rep10-AAACCCAAGCTGCGAA           singlet             SAM24439044
# SAM24456643_rep10-AAACCCAAGGAGAATG           singlet             SAM24439044
# SAM24456643_rep10-AAACCCAAGGCATCAG           singlet             SAM24439043
# SAM24456643_rep10-AAACCCAAGTCATCCA           singlet             SAM24439044
# SAM24456643_rep10-AAACCCAAGTGCACTT           singlet             SAM24439043
#
#                                    cellline timepoint     HTO   NGS_ID  \
# SAM24456643_rep10-AAACCCAAGCTGCGAA     DLD1      day5  HTO-14  NGS5888
# SAM24456643_rep10-AAACCCAAGGAGAATG     DLD1      day5   HTO-6  NGS5888
# SAM24456643_rep10-AAACCCAAGGCATCAG     DLD1      day5   HTO-1  NGS5888
# SAM24456643_rep10-AAACCCAAGTCATCCA     DLD1      day5   HTO-4  NGS5888
# SAM24456643_rep10-AAACCCAAGTGCACTT     DLD1      day5   HTO-1  NGS5888
#
#                                    Biological_replicate 10Xrun  \
# SAM24456643_rep10-AAACCCAAGCTGCGAA          SAM24439044     10
# SAM24456643_rep10-AAACCCAAGGAGAATG          SAM24439044     10
# SAM24456643_rep10-AAACCCAAGGCATCAG          SAM24439043     10
# SAM24456643_rep10-AAACCCAAGTCATCCA          SAM24439044     10
# SAM24456643_rep10-AAACCCAAGTGCACTT          SAM24439043     10
#
#                                                                            sublibrary  \
# SAM24456643_rep10-AAACCCAAGCTGCGAA  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
# SAM24456643_rep10-AAACCCAAGGAGAATG  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
# SAM24456643_rep10-AAACCCAAGGCATCAG  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
# SAM24456643_rep10-AAACCCAAGTCATCCA  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
# SAM24456643_rep10-AAACCCAAGTGCACTT  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
#
#                                    gRNA_library_MOI gene_symbol    class
# SAM24456643_rep10-AAACCCAAGCTGCGAA              0.5      ODF3L1   target
# SAM24456643_rep10-AAACCCAAGGAGAATG              0.5     unknown  unknown
# SAM24456643_rep10-AAACCCAAGGCATCAG              0.5       FXYD6   target
# SAM24456643_rep10-AAACCCAAGTCATCCA              0.5     unknown  unknown
# SAM24456643_rep10-AAACCCAAGTGCACTT              0.5        USP7   target

# %%
adata.var.head()
# Out:
#                                         ID                     Symbol  \
# Symbol
# 3xLinker                 3xLinker_3xLinker          3xLinker_3xLinker
# MIR1302-2HG  GRCh38-2020-A_ENSG00000243485  GRCh38-2020-A_MIR1302-2HG
# FAM138A      GRCh38-2020-A_ENSG00000237613      GRCh38-2020-A_FAM138A
# OR4F5        GRCh38-2020-A_ENSG00000186092        GRCh38-2020-A_OR4F5
# AL627309.1   GRCh38-2020-A_ENSG00000238009   GRCh38-2020-A_AL627309.1
#
#                         Type
# Symbol
# 3xLinker     Gene Expression
# MIR1302-2HG  Gene Expression
# FAM138A      Gene Expression
# OR4F5        Gene Expression
# AL627309.1   Gene Expression

# %% [markdown]
# ## Mapping Rate information

# %%
combined_df,agg,agg_percentage = rnaqc.Mapping_reads_info(Mapping_rate)

# %%
combined_df
# Out:
#                        Total number of reads  \
# LIB6238864_SAM24456643              89896794
# LIB6238840_SAM24456643              19414773
# LIB6238862_SAM24456643              75499035
# LIB6238838_SAM24456643              20414601
# LIB6238863_SAM24456643             100954349
# LIB6238839_SAM24456643              20428463
# LIB6238865_SAM24456643              85681518
# LIB6238841_SAM24456643              19794368
#
#                        Number of reads with valid cell barcodes  \
# LIB6238864_SAM24456643                        87563746 (97.40%)
# LIB6238840_SAM24456643                        18546993 (95.53%)
# LIB6238862_SAM24456643                        73482795 (97.33%)
# LIB6238838_SAM24456643                        19464694 (95.35%)
# LIB6238863_SAM24456643                        98342818 (97.41%)
# LIB6238839_SAM24456643                        19669540 (96.28%)
# LIB6238865_SAM24456643                        83412857 (97.35%)
# LIB6238841_SAM24456643                        18926709 (95.62%)
#
#                        Number of reads with valid feature barcodes  \
# LIB6238864_SAM24456643                           76510333 (85.11%)
# LIB6238840_SAM24456643                           17741537 (91.38%)
# LIB6238862_SAM24456643                           64373165 (85.26%)
# LIB6238838_SAM24456643                           18649078 (91.35%)
# LIB6238863_SAM24456643                           86360254 (85.54%)
# LIB6238839_SAM24456643                           19062788 (93.31%)
# LIB6238865_SAM24456643                           73219504 (85.46%)
# LIB6238841_SAM24456643                           18048888 (91.18%)
#
#                        Number of reads with valid cell and feature barcodes  \
# LIB6238864_SAM24456643                                  74879915 (83.30%)
# LIB6238840_SAM24456643                                  17359355 (89.41%)
# LIB6238862_SAM24456643                                  62943218 (83.37%)
# LIB6238838_SAM24456643                                  18218505 (89.24%)
# LIB6238863_SAM24456643                                  84503934 (83.71%)
# LIB6238839_SAM24456643                                  18640890 (91.25%)
# LIB6238865_SAM24456643                                  71603176 (83.57%)
# LIB6238841_SAM24456643                                  17658413 (89.21%)
#
#                        Number of valid cell barcodes  \
# LIB6238864_SAM24456643                        190010
# LIB6238840_SAM24456643                        620501
# LIB6238862_SAM24456643                        184869
# LIB6238838_SAM24456643                        847227
# LIB6238863_SAM24456643                        172720
# LIB6238839_SAM24456643                        742338
# LIB6238865_SAM24456643                        194659
# LIB6238841_SAM24456643                        748284
#
#                        Number of valid reads (with matching cell and feature barcodes)  \
# LIB6238864_SAM24456643                                           74879915
# LIB6238840_SAM24456643                                           17359355
# LIB6238862_SAM24456643                                           62943218
# LIB6238838_SAM24456643                                           18218505
# LIB6238863_SAM24456643                                           84503934
# LIB6238839_SAM24456643                                           18640890
# LIB6238865_SAM24456643                                           71603176
# LIB6238841_SAM24456643                                           17658413
#
#                        Mean number of valid reads per cell barcode  \
# LIB6238864_SAM24456643                                      394.08
# LIB6238840_SAM24456643                                       27.98
# LIB6238862_SAM24456643                                      340.47
# LIB6238838_SAM24456643                                       21.50
# LIB6238863_SAM24456643                                      489.25
# LIB6238839_SAM24456643                                       25.11
# LIB6238865_SAM24456643                                      367.84
# LIB6238841_SAM24456643                                       23.60
#
#                        Number of valid UMIs (with matching cell and feature barcodes)  \
# LIB6238864_SAM24456643                                            2764618
# LIB6238840_SAM24456643                                           14928895
# LIB6238862_SAM24456643                                            2456297
# LIB6238838_SAM24456643                                           15540929
# LIB6238863_SAM24456643                                            2842173
# LIB6238839_SAM24456643                                           16301481
# LIB6238865_SAM24456643                                            2554611
# LIB6238841_SAM24456643                                           15092076
#
#                        Mean number of valid UMIs per cell barcode  \
# LIB6238864_SAM24456643                                      14.55
# LIB6238840_SAM24456643                                      24.06
# LIB6238862_SAM24456643                                      13.29
# LIB6238838_SAM24456643                                      18.34
# LIB6238863_SAM24456643                                      16.46
# LIB6238839_SAM24456643                                      21.96
# LIB6238865_SAM24456643                                      13.12
# LIB6238841_SAM24456643                                      20.17
#
#                        Sequencing saturation Experiment
# LIB6238864_SAM24456643                96.31%     crispr
# LIB6238840_SAM24456643                14.00%    hashing
# LIB6238862_SAM24456643                96.10%     crispr
# LIB6238838_SAM24456643                14.70%    hashing
# LIB6238863_SAM24456643                96.64%     crispr
# LIB6238839_SAM24456643                12.55%    hashing
# LIB6238865_SAM24456643                96.43%     crispr
# LIB6238841_SAM24456643                14.53%    hashing

# %%
#Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
agg.plot(kind='barh', ax=ax1, stacked=False, color=['midnightblue', 'blue', 'deepskyblue'], legend=False)
ax1.set_xlabel('Read Count')
agg_percentage.plot(kind='barh', ax=ax2, stacked=False, color=['midnightblue', 'blue', 'deepskyblue'])
ax2.set_xlabel('%Read Count')
ax2.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.suptitle('Mapping Rate', fontsize=25)
plt.show()

# %% [markdown]
# ## Doublet information

# %%
rnaqc.doublet_counter(adata)
# Out:
#                                                     Cell counts
# total Cells                                              125208
# cells after keeping singlets by hashing                   96059
# cells after keeping singlets by gRNA                      52475
# cells after keeping singlets by both hashing an...        46325

# %% [markdown]
# ### Sumarize counts

# %%
cnts_before = rnaqc.Summerize_counts(adata, groupby)

# %%
cnts_before
# Out:
#                 cnt    pct
# Sample
# SAM24456643  125208  100.0

# %% [markdown]
# ### calculate qc metrics

# %%
adata = proc.calc_qc_metrics(adata, organism)

# %%
LOWER,UPPER = rnaqc.upper_lower_limits(adata, groupby)

# %%
LOWER
# Out:
#              n_genes_by_counts  total_counts  pct_counts_mt  pct_counts_ribo
# SAM24456643             -933.0      -10994.0      -1.836917        -1.031098

# %%
UPPER
# Out:
#              n_genes_by_counts  total_counts  pct_counts_mt  pct_counts_ribo
# SAM24456643             8795.0       32822.0      12.375551         31.05615

# %%
sc.pl.scatter(adata, 'n_genes_by_counts', 'total_counts', color='pct_counts_mt')

# %%
sc.pl.scatter(adata, 'pct_counts_mt', 'pct_counts_ribo', color='n_genes_by_counts')

# %%
sc.pl.violin(
    adata, 
    [
     'n_genes_by_counts', 
     'total_counts', 
     'pct_counts_mt'
     ],
    multi_panel=True
)

# %%
aggr = rnaqc.aggregation(adata, groupby, None, 'before')

# %%
adata.obs.head()
# Out:
#                                          Sample           Barcode  \
# SAM24456643_rep10-AAACCCAAGCTGCGAA  SAM24456643  AAACCCAAGCTGCGAA
# SAM24456643_rep10-AAACCCAAGGAGAATG  SAM24456643  AAACCCAAGGAGAATG
# SAM24456643_rep10-AAACCCAAGGCATCAG  SAM24456643  AAACCCAAGGCATCAG
# SAM24456643_rep10-AAACCCAAGTCATCCA  SAM24456643  AAACCCAAGTCATCCA
# SAM24456643_rep10-AAACCCAAGTGCACTT  SAM24456643  AAACCCAAGTGCACTT
#
#                                    DemuxType_crispr DemuxAssignment_crispr  \
# SAM24456643_rep10-AAACCCAAGCTGCGAA          singlet      ENSG00000182950_1
# SAM24456643_rep10-AAACCCAAGGAGAATG          unknown                unknown
# SAM24456643_rep10-AAACCCAAGGCATCAG          singlet      ENSG00000137726_2
# SAM24456643_rep10-AAACCCAAGTCATCCA          unknown                unknown
# SAM24456643_rep10-AAACCCAAGTGCACTT          singlet      ENSG00000187555_1
#
#                                    DemuxType_hashing DemuxAssignment_hashing  \
# SAM24456643_rep10-AAACCCAAGCTGCGAA           singlet             SAM24439044
# SAM24456643_rep10-AAACCCAAGGAGAATG           singlet             SAM24439044
# SAM24456643_rep10-AAACCCAAGGCATCAG           singlet             SAM24439043
# SAM24456643_rep10-AAACCCAAGTCATCCA           singlet             SAM24439044
# SAM24456643_rep10-AAACCCAAGTGCACTT           singlet             SAM24439043
#
#                                    cellline timepoint     HTO   NGS_ID  ...  \
# SAM24456643_rep10-AAACCCAAGCTGCGAA     DLD1      day5  HTO-14  NGS5888  ...
# SAM24456643_rep10-AAACCCAAGGAGAATG     DLD1      day5   HTO-6  NGS5888  ...
# SAM24456643_rep10-AAACCCAAGGCATCAG     DLD1      day5   HTO-1  NGS5888  ...
# SAM24456643_rep10-AAACCCAAGTCATCCA     DLD1      day5   HTO-4  NGS5888  ...
# SAM24456643_rep10-AAACCCAAGTGCACTT     DLD1      day5   HTO-1  NGS5888  ...
#
#                                                                            sublibrary  \
# SAM24456643_rep10-AAACCCAAGCTGCGAA  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
# SAM24456643_rep10-AAACCCAAGGAGAATG  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
# SAM24456643_rep10-AAACCCAAGGCATCAG  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
# SAM24456643_rep10-AAACCCAAGTCATCCA  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
# SAM24456643_rep10-AAACCCAAGTGCACTT  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
#
#                                    gRNA_library_MOI gene_symbol    class  \
# SAM24456643_rep10-AAACCCAAGCTGCGAA              0.5      ODF3L1   target
# SAM24456643_rep10-AAACCCAAGGAGAATG              0.5     unknown  unknown
# SAM24456643_rep10-AAACCCAAGGCATCAG              0.5       FXYD6   target
# SAM24456643_rep10-AAACCCAAGTCATCCA              0.5     unknown  unknown
# SAM24456643_rep10-AAACCCAAGTGCACTT              0.5        USP7   target
#
#                                    n_genes_by_counts total_counts  \
# SAM24456643_rep10-AAACCCAAGCTGCGAA              4582        14184
# SAM24456643_rep10-AAACCCAAGGAGAATG              2123         3810
# SAM24456643_rep10-AAACCCAAGGCATCAG              4504        14833
# SAM24456643_rep10-AAACCCAAGTCATCCA              2387         4296
# SAM24456643_rep10-AAACCCAAGTGCACTT              6640        22388
#
#                                     total_counts_mt  pct_counts_mt  \
# SAM24456643_rep10-AAACCCAAGCTGCGAA              398       2.805979
# SAM24456643_rep10-AAACCCAAGGAGAATG              787      20.656168
# SAM24456643_rep10-AAACCCAAGGCATCAG              649       4.375379
# SAM24456643_rep10-AAACCCAAGTCATCCA              590      13.733706
# SAM24456643_rep10-AAACCCAAGTGCACTT              877       3.917277
#
#                                     total_counts_ribo  pct_counts_ribo
# SAM24456643_rep10-AAACCCAAGCTGCGAA               2955        20.833333
# SAM24456643_rep10-AAACCCAAGGAGAATG                103         2.703412
# SAM24456643_rep10-AAACCCAAGGCATCAG               2720        18.337491
# SAM24456643_rep10-AAACCCAAGTCATCCA                 73         1.699255
# SAM24456643_rep10-AAACCCAAGTGCACTT               2466        11.014829
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Instantiate a RapidsSingleCellPipeline object given our AnnData to prepare RAPIDS environment for other steps

# %%
RP = rp.RapidsSingleCellPipeline(adata)

# %% [markdown]
# ## Notice:
# - **RP._adata is adata before filtering**
# - **RP.adata_ is adata after filtering**
# - **Rp.adata is adata after normalization (and highly variable genes selected)**

# %%
max_cells = None
cell_batch_size = 100000
gene_batch_size = 1200
target_sum = 1e4
n_top_genes = 2000
counts_layer = "counts"
batch_key = "DemuxAssignment_hashing"

# %% [markdown]
# ## Apply filter using GPU

# %%
if GPU:
    RP.filter_data(
    groupby,
    min_genes=min_genes,
    max_genes=max_genes,
    max_cells=max_cells,
    cell_batch_size=cell_batch_size,
    min_cells=min_cells,
    gene_batch_size=gene_batch_size,
        ribo=ribo, 
        doublets=doublets,
        pct_mt=pct_mt, 
        total_counts=total_counts
)
# Out:
# starting with 125208 cells
# Filtering cells.
# Processed 0 cells..
# Processed 100000 cells..
# Filtering genes.
# Completed preprocessing.
# Calculating upper outliers
# Now 114937 cells after filtering max genes
# Calculating upper outliers
# Now 97826 cells after filtering pct mt
# Calculating upper outliers
# Now 95028 cells after filtering total counts
# Now 94846 cells after filtering pct ribo
# Now 77473 cells after keeping singlets by hashing
# Now 45182 cells after keeping singlets by gRNA
# Preprocessing took 38.746195554733276 seconds

# %%
RP._adata
# Out:
# AnnData object with n_obs × n_vars = 125208 × 36603
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo'
#     var: 'ID', 'Symbol', 'Type', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: '.internal'
#     layers: 'counts'

# %%
RP.adata_
# Out:
# View of AnnData object with n_obs × n_vars = 45182 × 32285
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo'
#     var: 'ID', 'Symbol', 'Type', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     layers: 'counts'

# %%
RP._adata.obs["qc_pass"] = RP._adata.obs.index.isin(RP.adata_.obs.index)

# %%
RP._adata.obs
# Out:
#                                          Sample           Barcode  \
# SAM24456643_rep10-AAACCCAAGCTGCGAA  SAM24456643  AAACCCAAGCTGCGAA
# SAM24456643_rep10-AAACCCAAGGAGAATG  SAM24456643  AAACCCAAGGAGAATG
# SAM24456643_rep10-AAACCCAAGGCATCAG  SAM24456643  AAACCCAAGGCATCAG
# SAM24456643_rep10-AAACCCAAGTCATCCA  SAM24456643  AAACCCAAGTCATCCA
# SAM24456643_rep10-AAACCCAAGTGCACTT  SAM24456643  AAACCCAAGTGCACTT
# ...                                         ...               ...
# SAM24456643_rep9-TTTGTTGTCACTGGTA   SAM24456643  TTTGTTGTCACTGGTA
# SAM24456643_rep9-TTTGTTGTCAGGAGAC   SAM24456643  TTTGTTGTCAGGAGAC
# SAM24456643_rep9-TTTGTTGTCATTGCTT   SAM24456643  TTTGTTGTCATTGCTT
# SAM24456643_rep9-TTTGTTGTCCTAGCTC   SAM24456643  TTTGTTGTCCTAGCTC
# SAM24456643_rep9-TTTGTTGTCGGTGTTA   SAM24456643  TTTGTTGTCGGTGTTA
#
#                                    DemuxType_crispr  \
# SAM24456643_rep10-AAACCCAAGCTGCGAA          singlet
# SAM24456643_rep10-AAACCCAAGGAGAATG          unknown
# SAM24456643_rep10-AAACCCAAGGCATCAG          singlet
# SAM24456643_rep10-AAACCCAAGTCATCCA          unknown
# SAM24456643_rep10-AAACCCAAGTGCACTT          singlet
# ...                                             ...
# SAM24456643_rep9-TTTGTTGTCACTGGTA           unknown
# SAM24456643_rep9-TTTGTTGTCAGGAGAC           singlet
# SAM24456643_rep9-TTTGTTGTCATTGCTT           singlet
# SAM24456643_rep9-TTTGTTGTCCTAGCTC           doublet
# SAM24456643_rep9-TTTGTTGTCGGTGTTA           unknown
#
#                                                  DemuxAssignment_crispr  \
# SAM24456643_rep10-AAACCCAAGCTGCGAA                    ENSG00000182950_1
# SAM24456643_rep10-AAACCCAAGGAGAATG                              unknown
# SAM24456643_rep10-AAACCCAAGGCATCAG                    ENSG00000137726_2
# SAM24456643_rep10-AAACCCAAGTCATCCA                              unknown
# SAM24456643_rep10-AAACCCAAGTGCACTT                    ENSG00000187555_1
# ...                                                                 ...
# SAM24456643_rep9-TTTGTTGTCACTGGTA                               unknown
# SAM24456643_rep9-TTTGTTGTCAGGAGAC                     ENSG00000105499_1
# SAM24456643_rep9-TTTGTTGTCATTGCTT                     ENSG00000167550_1
# SAM24456643_rep9-TTTGTTGTCCTAGCTC   ENSG00000187616_4,ENSG00000286007_4
# SAM24456643_rep9-TTTGTTGTCGGTGTTA                               unknown
#
#                                    DemuxType_hashing DemuxAssignment_hashing  \
# SAM24456643_rep10-AAACCCAAGCTGCGAA           singlet             SAM24439044
# SAM24456643_rep10-AAACCCAAGGAGAATG           singlet             SAM24439044
# SAM24456643_rep10-AAACCCAAGGCATCAG           singlet             SAM24439043
# SAM24456643_rep10-AAACCCAAGTCATCCA           singlet             SAM24439044
# SAM24456643_rep10-AAACCCAAGTGCACTT           singlet             SAM24439043
# ...                                              ...                     ...
# SAM24456643_rep9-TTTGTTGTCACTGGTA            singlet             SAM24439045
# SAM24456643_rep9-TTTGTTGTCAGGAGAC            singlet             SAM24439044
# SAM24456643_rep9-TTTGTTGTCATTGCTT            singlet             SAM24439044
# SAM24456643_rep9-TTTGTTGTCCTAGCTC            singlet             SAM24439043
# SAM24456643_rep9-TTTGTTGTCGGTGTTA            singlet             SAM24439044
#
#                                    cellline timepoint     HTO   NGS_ID  ...  \
# SAM24456643_rep10-AAACCCAAGCTGCGAA     DLD1      day5  HTO-14  NGS5888  ...
# SAM24456643_rep10-AAACCCAAGGAGAATG     DLD1      day5   HTO-6  NGS5888  ...
# SAM24456643_rep10-AAACCCAAGGCATCAG     DLD1      day5   HTO-1  NGS5888  ...
# SAM24456643_rep10-AAACCCAAGTCATCCA     DLD1      day5   HTO-4  NGS5888  ...
# SAM24456643_rep10-AAACCCAAGTGCACTT     DLD1      day5   HTO-1  NGS5888  ...
# ...                                     ...       ...     ...      ...  ...
# SAM24456643_rep9-TTTGTTGTCACTGGTA      DLD1      day5  HTO-16  NGS5888  ...
# SAM24456643_rep9-TTTGTTGTCAGGAGAC      DLD1      day5  HTO-14  NGS5888  ...
# SAM24456643_rep9-TTTGTTGTCATTGCTT      DLD1      day5  HTO-14  NGS5888  ...
# SAM24456643_rep9-TTTGTTGTCCTAGCTC      DLD1      day5   HTO-1  NGS5888  ...
# SAM24456643_rep9-TTTGTTGTCGGTGTTA      DLD1      day5  HTO-14  NGS5888  ...
#
#                                    gRNA_library_MOI  \
# SAM24456643_rep10-AAACCCAAGCTGCGAA              0.5
# SAM24456643_rep10-AAACCCAAGGAGAATG              0.5
# SAM24456643_rep10-AAACCCAAGGCATCAG              0.5
# SAM24456643_rep10-AAACCCAAGTCATCCA              0.5
# SAM24456643_rep10-AAACCCAAGTGCACTT              0.5
# ...                                             ...
# SAM24456643_rep9-TTTGTTGTCACTGGTA               0.5
# SAM24456643_rep9-TTTGTTGTCAGGAGAC               0.5
# SAM24456643_rep9-TTTGTTGTCATTGCTT               0.5
# SAM24456643_rep9-TTTGTTGTCCTAGCTC               0.5
# SAM24456643_rep9-TTTGTTGTCGGTGTTA               0.5
#
#                                                             gene_symbol  \
# SAM24456643_rep10-AAACCCAAGCTGCGAA                               ODF3L1
# SAM24456643_rep10-AAACCCAAGGAGAATG                              unknown
# SAM24456643_rep10-AAACCCAAGGCATCAG                                FXYD6
# SAM24456643_rep10-AAACCCAAGTCATCCA                              unknown
# SAM24456643_rep10-AAACCCAAGTGCACTT                                 USP7
# ...                                                                 ...
# SAM24456643_rep9-TTTGTTGTCACTGGTA                               unknown
# SAM24456643_rep9-TTTGTTGTCAGGAGAC                               PLA2G4C
# SAM24456643_rep9-TTTGTTGTCATTGCTT                                RHEBL1
# SAM24456643_rep9-TTTGTTGTCCTAGCTC   ENSG00000187616_4,ENSG00000286007_4
# SAM24456643_rep9-TTTGTTGTCGGTGTTA                               unknown
#
#                                                                   class  \
# SAM24456643_rep10-AAACCCAAGCTGCGAA                               target
# SAM24456643_rep10-AAACCCAAGGAGAATG                              unknown
# SAM24456643_rep10-AAACCCAAGGCATCAG                               target
# SAM24456643_rep10-AAACCCAAGTCATCCA                              unknown
# SAM24456643_rep10-AAACCCAAGTGCACTT                               target
# ...                                                                 ...
# SAM24456643_rep9-TTTGTTGTCACTGGTA                               unknown
# SAM24456643_rep9-TTTGTTGTCAGGAGAC                                target
# SAM24456643_rep9-TTTGTTGTCATTGCTT                                target
# SAM24456643_rep9-TTTGTTGTCCTAGCTC   ENSG00000187616_4,ENSG00000286007_4
# SAM24456643_rep9-TTTGTTGTCGGTGTTA                               unknown
#
#                                    n_genes_by_counts total_counts  \
# SAM24456643_rep10-AAACCCAAGCTGCGAA              4582        14184
# SAM24456643_rep10-AAACCCAAGGAGAATG              2123         3810
# SAM24456643_rep10-AAACCCAAGGCATCAG              4504        14833
# SAM24456643_rep10-AAACCCAAGTCATCCA              2387         4296
# SAM24456643_rep10-AAACCCAAGTGCACTT              6640        22388
# ...                                              ...          ...
# SAM24456643_rep9-TTTGTTGTCACTGGTA                614         1097
# SAM24456643_rep9-TTTGTTGTCAGGAGAC               4828        15853
# SAM24456643_rep9-TTTGTTGTCATTGCTT               5131        13145
# SAM24456643_rep9-TTTGTTGTCCTAGCTC               8012        49419
# SAM24456643_rep9-TTTGTTGTCGGTGTTA               2876         6243
#
#                                    total_counts_mt  pct_counts_mt  \
# SAM24456643_rep10-AAACCCAAGCTGCGAA             398       2.805979
# SAM24456643_rep10-AAACCCAAGGAGAATG             787      20.656168
# SAM24456643_rep10-AAACCCAAGGCATCAG             649       4.375379
# SAM24456643_rep10-AAACCCAAGTCATCCA             590      13.733706
# SAM24456643_rep10-AAACCCAAGTGCACTT             877       3.917277
# ...                                            ...            ...
# SAM24456643_rep9-TTTGTTGTCACTGGTA              384      35.004558
# SAM24456643_rep9-TTTGTTGTCAGGAGAC              440       2.775500
# SAM24456643_rep9-TTTGTTGTCATTGCTT             1135       8.634462
# SAM24456643_rep9-TTTGTTGTCCTAGCTC             2161       4.372812
# SAM24456643_rep9-TTTGTTGTCGGTGTTA             1314      21.047573
#
#                                     total_counts_ribo  pct_counts_ribo  \
# SAM24456643_rep10-AAACCCAAGCTGCGAA               2955        20.833333
# SAM24456643_rep10-AAACCCAAGGAGAATG                103         2.703412
# SAM24456643_rep10-AAACCCAAGGCATCAG               2720        18.337491
# SAM24456643_rep10-AAACCCAAGTCATCCA                 73         1.699255
# SAM24456643_rep10-AAACCCAAGTGCACTT               2466        11.014829
# ...                                               ...              ...
# SAM24456643_rep9-TTTGTTGTCACTGGTA                  93         8.477666
# SAM24456643_rep9-TTTGTTGTCAGGAGAC                3254        20.526083
# SAM24456643_rep9-TTTGTTGTCATTGCTT                 982         7.470521
# SAM24456643_rep9-TTTGTTGTCCTAGCTC                8649        17.501366
# SAM24456643_rep9-TTTGTTGTCGGTGTTA                 162         2.594906
#
#                                     qc_pass
# SAM24456643_rep10-AAACCCAAGCTGCGAA     True
# SAM24456643_rep10-AAACCCAAGGAGAATG    False
# SAM24456643_rep10-AAACCCAAGGCATCAG     True
# SAM24456643_rep10-AAACCCAAGTCATCCA    False
# SAM24456643_rep10-AAACCCAAGTGCACTT     True
# ...                                     ...
# SAM24456643_rep9-TTTGTTGTCACTGGTA     False
# SAM24456643_rep9-TTTGTTGTCAGGAGAC      True
# SAM24456643_rep9-TTTGTTGTCATTGCTT      True
# SAM24456643_rep9-TTTGTTGTCCTAGCTC     False
# SAM24456643_rep9-TTTGTTGTCGGTGTTA     False
#
# [125208 rows x 23 columns]

# %% [markdown]
# ## Apply filter uisng CPU

# %%
if GPU==False:
    adata = proc.filter_adata(
    adata, 
    groupby, 
    min_cells, 
    min_genes, 
    ribo, 
    doublets=doublets, pct_mt=pct_mt)

# %%
sc.pl.scatter(RP.adata_, 'n_genes_by_counts', 'total_counts', color='pct_counts_mt')

# %%
sc.pl.scatter(RP.adata_, 'pct_counts_mt', 'pct_counts_ribo', color='n_genes_by_counts')

# %%
aggr = rnaqc.aggregation(RP.adata_, groupby,aggr, 'after')

# %%
#QC plots before and after
for k in ['n_genes_by_counts', 'total_counts', 'pct_counts_mt', 'pct_counts_ribo']:
    proc.plotQCSplit(aggr, groupby, k)

# %%
cnts_after = rnaqc.Summerize_counts(RP.adata_,groupby)

# %%
cnts_after
# Out:
#                cnt    pct
# Sample
# SAM24456643  45182  100.0

# %%
proc.aggCnts(cnts_before, cnts_after)
# Out:
#              before  after  pct left
# Sample
# SAM24456643  125208  45182      36.1

# %%
proc.plot_cell_left(cnts_before, cnts_after, groupby)

# %% [markdown]
# ## Run Normalize -> HGV -> PCA -> kNN -> Leiden -> UMAP

# %%
RP.proc(n_top_genes, norm=True, scale=True, regress=False, embedding=True, n_pcs=30, 
        n_neighbors=10, knn_n_pcs=30, batch_key=None)
# Out:
# normalizing
# Processed 0 cells..
# normalizing data.
# Completed preprocessing.
# Preprocessing took 4.73710823059082 seconds
# selecting highly variable genes
# Filtering to highly variable genes.
# Processed 0 genes..
# Processed 1200 genes..
# Processed 2400 genes..
# Processed 3600 genes..
# Processed 4800 genes..
# Processed 6000 genes..
# Processed 7200 genes..
# Processed 8400 genes..
# Processed 9600 genes..
# Processed 10800 genes..
# Processed 12000 genes..
# Processed 13200 genes..
# Processed 14400 genes..
# Processed 15600 genes..
# Processed 16800 genes..
# Processed 18000 genes..
# Processed 19200 genes..
# Processed 20400 genes..
# Processed 21600 genes..
# Processed 22800 genes..
# Processed 24000 genes..
# Processed 25200 genes..
# Processed 26400 genes..
# Processed 27600 genes..
# Processed 28800 genes..
# Processed 30000 genes..
# Processed 31200 genes..
# Completed preprocessing.
# Converting sparse GPU array to dense GPU array.
# Preprocessing took 14.209182739257812 seconds
# scaling
# scaling took 0.6927056312561035 seconds
# computing PCA
# PCA took 0.6339385509490967 seconds
# kNN took 4.91826057434082 seconds
# computing UMAP
# WARNING: .obsp["connectivities"] have not been computed using umap
# UMAP took 0.3170814514160156 seconds
# computing Leiden clustering
# Leiden clustering took 0.13021230697631836 seconds

# %% [markdown]
# ## Batch Correction

# %%
#RP.run_scvi(counts_layer = "counts", batch_key = "DemuxAssignment_hashing")

# %%
#RP.adata.obsm["X_scVI"]

# %% [markdown]
# ## Plot PCA UMAP

# %%
if GPU:
    sc.pl.umap(RP.adata, color="leiden")

# %%
if GPU:
    sc.pl.umap(RP.adata, color=groupby)

# %%
if GPU:
    sc.pl.umap(RP.adata, color="DemuxAssignment_hashing")

# %%
#This is just to quickly check how the data looks. Cell cycle scores are added to main adata object, but normalized and processed object is not saved
if GPU==False:
    adata_tmp = adata.copy()

# %%
if GPU==False:
    adata_tmp = proc.proc(adata_tmp, 'auto', norm=True, scale=True, regress=False, embedding=True)
    sc.pl.umap(adata_tmp, color=groupby)

# %% [markdown]
# ## Add score cell cycle

# %%
if organism=='human':
    fcc =  '/gstore/data/cbfunge/data/CellCycleGenes/Homo_sapiens.csv'
elif organism == 'mouse':
    fcc = '/gstore/data/cbfunge/data/CellCycleGenes/Mus_musculus.csv'
    
if GPU:
    proc.compute_cellCycleScores(RP._adata, fcc)
else:
    proc.compute_cellCycleScores(adata_tmp, fcc)

# %%
RP._adata
# Out:
# AnnData object with n_obs × n_vars = 125208 × 36603
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'qc_pass', 'S_score', 'G2M_score', 'phase'
#     var: 'ID', 'Symbol', 'Type', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: '.internal'
#     layers: 'counts'

# %%
RP.adata
# Out:
# AnnData object with n_obs × n_vars = 45182 × 2000
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'leiden'
#     uns: 'neighbors', 'umap', 'leiden_colors', 'Sample_colors', 'DemuxAssignment_hashing_colors'
#     obsm: 'X_pca', 'X_umap'
#     obsp: 'distances', 'connectivities'

# %%
if GPU==False:
    adata.obs['phase'] = adata_tmp.obs['phase']
    adata.obs['G2M_score'] = adata_tmp.obs['G2M_score']
    adata.obs['S_score'] = adata_tmp.obs['S_score']
    adata.obs

# %%
if GPU==False:
    sc.pl.umap(adata_tmp, color='phase')

# %%
adatas
# Out:
# {'crispr': AnnData object with n_obs × n_vars = 125208 × 20345
#      uns: '.internal'
#      layers: 'counts',
#  'hashing': AnnData object with n_obs × n_vars = 125208 × 19
#      uns: '.internal'
#      layers: 'counts'}

# %%
adatas_updated = adatas.copy()
if GPU:
    adata_updated = RP._adata.copy()
else:
    adata_updated = adata.copy()

# %%
adata_updated
# Out:
# AnnData object with n_obs × n_vars = 125208 × 36603
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'qc_pass', 'S_score', 'G2M_score', 'phase'
#     var: 'ID', 'Symbol', 'Type', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: '.internal'
#     layers: 'counts'

# %%
adatas_updated
# Out:
# {'crispr': AnnData object with n_obs × n_vars = 125208 × 20345
#      uns: '.internal'
#      layers: 'counts',
#  'hashing': AnnData object with n_obs × n_vars = 125208 × 19
#      uns: '.internal'
#      layers: 'counts'}

# %% [markdown]
# ### Write h5ad version on the disk

# %%
# If you wish to write on the disk
#adata_updated.var.index.name = None
#adata_updated.write_h5ad(raw_qc)

# %% [markdown]
# ## Write h5ad file with embedings for Energy Distance analaysis

# %%
if GPU:
    RP.adata_.obsp = RP.adata.obsp.copy()
    RP.adata_.obsm = RP.adata.obsm.copy()
else:
    adata.obsp = adata_tmp.obsp.copy()
    adata.obsm = adata_tmp.obsm.copy()

# %%
if GPU:
    adata_embedding = RP.adata_.copy()
else:
    adata_embedding = adata.copy()

# %%
adata_embedding.write_h5ad(raw_embedding)

# %% [markdown]
# ## Update the dataset with new experiment "raw_qc"

# %%
if DS_test==False:
    dsid, version = DS.update_dataset(New_experiment, adata_updated, adatas_updated, test=False)
else:    
    dsid, version = DS.update_another_dataset(test_DatasetID, True, 1, New_experiment, adata_updated, adatas_updated, test=True)
# Out:
# 08:55:12 -> Collating dataset: 'DS000017731' metadata.
# 08:55:12 -> Retrieving all project: 'DS000017731@1' metadata.
#
# 08:55:12 -> Reading: 'DS000017731'.
#
# 08:55:12 -> Reading: 'DS000017731 -> Experiment: main'.
#
# 08:55:12 -> Reading: 'DS000017731 -> Experiment: main -> Alt. Exp.: crispr'.
# 08:55:12 -> Reading: 'DS000017731 -> Experiment: main -> Alt. Exp.: hashing'.
# PYDSDB:INFO: Experiment already contained metadata, overwriting.
# PYDSDB:INFO: Experiment already contained metadata, overwriting.
# PYDSDB:INFO: Experiment already contained metadata, overwriting.
# Retrieving cached token data.
# Successfully authenticated.
# 08:56:58 -> Retrieving all project: 'DS000017731@latest' metadata.
# 08:56:58 -> Collating and validating project resources.
# 08:56:59 -> Attempting upload.
#   0%|                                        | 0/73 [00:00<?, ?file/s]
#   1%|▌                                       | 1/73 [00:01<01:12,  1.01s/file]
#   3%|█                                       | 2/73 [00:01<00:33,  2.10file/s]
#   4%|█▋                                      | 3/73 [00:01<00:30,  2.33file/s]
#   5%|██▏                                     | 4/73 [00:01<00:23,  2.93file/s]
#   7%|██▋                                     | 5/73 [00:01<00:17,  3.90file/s]
#   8%|███▎                                    | 6/73 [00:02<00:16,  4.13file/s]
#  10%|███▊                                    | 7/73 [00:02<00:14,  4.66file/s]
#  12%|████▉                                   | 9/73 [00:03<00:22,  2.83file/s]
#  14%|█████▍                                  | 10/73 [00:03<00:19,  3.30file/s]
#  15%|██████                                  | 11/73 [00:03<00:15,  3.97file/s]
#  16%|██████▌                                 | 12/73 [00:03<00:12,  4.71file/s]
#  18%|███████                                 | 13/73 [00:03<00:10,  5.51file/s]
#  21%|████████▏                               | 15/73 [00:03<00:08,  6.96file/s]
#  23%|█████████▎                              | 17/73 [00:03<00:06,  8.60file/s]
#  26%|██████████▍                             | 19/73 [00:04<00:05,  9.55file/s]
#  29%|███████████▌                            | 21/73 [00:04<00:05,  9.31file/s]
#  30%|████████████                            | 22/73 [00:19<00:05,  9.31file/s]
#  32%|████████████▌                           | 23/73 [01:59<15:43, 18.87s/file]
#  33%|█████████████▏                          | 24/73 [02:00<12:36, 15.44s/file]
#  36%|██████████████▏                         | 26/73 [02:01<07:56, 10.13s/file]
#  37%|██████████████▊                         | 27/73 [02:05<06:51,  8.94s/file]
#  40%|███████████████▉                        | 29/73 [02:05<04:11,  5.71s/file]
#  41%|████████████████▍                       | 30/73 [02:05<03:16,  4.56s/file]
#  42%|████████████████▉                       | 31/73 [02:07<02:46,  3.95s/file]
#  44%|█████████████████▌                      | 32/73 [02:07<02:03,  3.01s/file]
#  47%|██████████████████▋                     | 34/73 [02:07<01:10,  1.81s/file]
#  48%|███████████████████▏                    | 35/73 [02:08<00:56,  1.48s/file]
#  49%|███████████████████▋                    | 36/73 [02:08<00:44,  1.21s/file]
#  51%|████████████████████▎                   | 37/73 [02:08<00:34,  1.05file/s]
#  52%|████████████████████▊                   | 38/73 [02:08<00:26,  1.34file/s]
#  53%|█████████████████████▎                  | 39/73 [02:09<00:22,  1.50file/s]
#  55%|█████████████████████▉                  | 40/73 [02:09<00:17,  1.93file/s]
#  56%|██████████████████████▍                 | 41/73 [02:09<00:12,  2.50file/s]
#  59%|███████████████████████▌                | 43/73 [02:09<00:07,  3.82file/s]
#  62%|████████████████████████▋               | 45/73 [02:09<00:05,  5.20file/s]
#  64%|█████████████████████████▊              | 47/73 [02:10<00:04,  6.47file/s]
#  66%|██████████████████████████▎             | 48/73 [02:10<00:03,  6.75file/s]
#  67%|██████████████████████████▊             | 49/73 [02:10<00:03,  7.11file/s]
#  68%|███████████████████████████▍            | 50/73 [02:11<00:07,  3.26file/s]
#  70%|███████████████████████████▉            | 51/73 [02:11<00:07,  2.90file/s]
#  71%|████████████████████████████▍           | 52/73 [02:11<00:06,  3.48file/s]
#  73%|█████████████████████████████           | 53/73 [02:14<00:19,  1.04file/s]
#  74%|█████████████████████████████▌          | 54/73 [02:14<00:15,  1.26file/s]
#  75%|██████████████████████████████▏         | 55/73 [02:17<00:25,  1.43s/file]
#  77%|██████████████████████████████▋         | 56/73 [02:18<00:19,  1.14s/file]
#  78%|███████████████████████████████▏        | 57/73 [02:30<01:09,  4.37s/file]
#  79%|███████████████████████████████▊        | 58/73 [02:30<00:47,  3.14s/file]
#  82%|████████████████████████████████▉       | 60/73 [02:30<00:22,  1.75s/file]
#  84%|█████████████████████████████████▍      | 61/73 [02:30<00:16,  1.35s/file]
#  85%|█████████████████████████████████▉      | 62/73 [02:31<00:13,  1.23s/file]
#  86%|██████████████████████████████████▌     | 63/73 [02:32<00:10,  1.01s/file]
#  88%|███████████████████████████████████     | 64/73 [02:32<00:08,  1.12file/s]
#  89%|███████████████████████████████████▌    | 65/73 [02:32<00:05,  1.49file/s]
#  90%|████████████████████████████████████▏   | 66/73 [02:33<00:03,  1.90file/s]
#  92%|████████████████████████████████████▋   | 67/73 [02:33<00:02,  2.46file/s]
#  93%|█████████████████████████████████████▎  | 68/73 [02:33<00:01,  2.51file/s]
#  96%|██████████████████████████████████████▎ | 70/73 [02:33<00:00,  3.89file/s]
#  97%|██████████████████████████████████████▉ | 71/73 [02:33<00:00,  4.35file/s]
#  99%|███████████████████████████████████████▍| 72/73 [02:59<00:06,  6.85s/file]
# 100%|████████████████████████████████████████| 73/73 [02:59<00:00,  2.46s/file]
# Clearing upload info.
# 09:00:15 -> Upload completed.
# Processing...
# Processing...
# Processing...
# Upload successful, your DSID is 'DS000017731' and version is: '5'. Also written to 'upload_info.json' in staging dir.

# %%
dsid, version
# Out:
# ('DS000017731', '5')
