# %%
# Parameters
DatasetID = "DS000017727"
DEV = False
test_DatasetID = ""
DS_test = False
title = "Recursion DLD1 Library3- Screen2 (NGS5888)"
description = "Production scale screen in DLD-1 cells with 1/4 of the genome-wide CRISPR library (sub-lib-3, ~22K guides). 1 time point: Day-5. We performed 24 rxns of 10x 3' HT kit with an estimated loading of 52K cells. We performed a pilot study to test the library quality before the production-level sequencing. We will submit 72 libraries (24 GEX, 24 HTO and 24 sgRNA) We request 600M reads for GEX, 20M for HTO and 40M for sgRNA, after finishing QC sequencing of NGS5887. NGS has built the GEX and sgRNA libraries using automation, we will provide manually constructed HTO libraries."
name_space = [{"id": "GRCh38", "type": "genome"}]
sources = [{"id": "Siavash-1234", "name": "Geo-ID"}]
tech_name = "scRNA-seq"
author = "SG"
alt_experiments = ["crispr", "hashing"]
organism = "human"
groupby = "Sample"
min_cells = 3
min_genes = 500
max_genes = None
pct_mt = None
total_counts = None
n_top_genes = 2000
ribo = True
doublets = True
Mapping_rate = {"LIB6238868_SAM24456643": "Total number of reads: 93430882\nNumber of reads with valid cell barcodes: 90733324 (97.11%)\nNumber of reads with valid feature barcodes: 79722279 (85.33%)\nNumber of reads with valid cell and feature barcodes: 77738473 (83.20%)\n\nSection LIB6238868_SAM24456643.crispr\nNumber of valid cell barcodes: 193503\nNumber of valid reads (with matching cell and feature barcodes): 77738473\nMean number of valid reads per cell barcode: 401.74\nNumber of valid UMIs (with matching cell and feature barcodes): 2568699\nMean number of valid UMIs per cell barcode: 13.27\nSequencing saturation: 96.70%\n", "LIB6238844_SAM24456643": "Total number of reads: 20671715\nNumber of reads with valid cell barcodes: 19916651 (96.35%)\nNumber of reads with valid feature barcodes: 19210640 (92.93%)\nNumber of reads with valid cell and feature barcodes: 18769672 (90.80%)\n\nSection LIB6238844_SAM24456643.hashing\nNumber of valid cell barcodes: 875219\nNumber of valid reads (with matching cell and feature barcodes): 18769672\nMean number of valid reads per cell barcode: 21.45\nNumber of valid UMIs (with matching cell and feature barcodes): 15851410\nMean number of valid UMIs per cell barcode: 18.11\nSequencing saturation: 15.55%\n", "LIB6238869_SAM24456643": "Total number of reads: 89653129\nNumber of reads with valid cell barcodes: 87115787 (97.17%)\nNumber of reads with valid feature barcodes: 77382849 (86.31%)\nNumber of reads with valid cell and feature barcodes: 75461114 (84.17%)\n\nSection LIB6238869_SAM24456643.crispr\nNumber of valid cell barcodes: 186766\nNumber of valid reads (with matching cell and feature barcodes): 75461114\nMean number of valid reads per cell barcode: 404.04\nNumber of valid UMIs (with matching cell and feature barcodes): 2418604\nMean number of valid UMIs per cell barcode: 12.95\nSequencing saturation: 96.79%\n", "LIB6238845_SAM24456643": "Total number of reads: 21096144\nNumber of reads with valid cell barcodes: 20336962 (96.40%)\nNumber of reads with valid feature barcodes: 19593163 (92.88%)\nNumber of reads with valid cell and feature barcodes: 19155456 (90.80%)\n\nSection LIB6238845_SAM24456643.hashing\nNumber of valid cell barcodes: 896867\nNumber of valid reads (with matching cell and feature barcodes): 19155456\nMean number of valid reads per cell barcode: 21.36\nNumber of valid UMIs (with matching cell and feature barcodes): 16158630\nMean number of valid UMIs per cell barcode: 18.02\nSequencing saturation: 15.64%\n", "LIB6238866_SAM24456643": "Total number of reads: 99590506\nNumber of reads with valid cell barcodes: 96866479 (97.26%)\nNumber of reads with valid feature barcodes: 85179651 (85.53%)\nNumber of reads with valid cell and feature barcodes: 83218842 (83.56%)\n\nSection LIB6238866_SAM24456643.crispr\nNumber of valid cell barcodes: 173783\nNumber of valid reads (with matching cell and feature barcodes): 83218842\nMean number of valid reads per cell barcode: 478.87\nNumber of valid UMIs (with matching cell and feature barcodes): 2496899\nMean number of valid UMIs per cell barcode: 14.37\nSequencing saturation: 97.00%\n", "LIB6238842_SAM24456643": "Total number of reads: 20480190\nNumber of reads with valid cell barcodes: 19549213 (95.45%)\nNumber of reads with valid feature barcodes: 18874806 (92.16%)\nNumber of reads with valid cell and feature barcodes: 18443192 (90.05%)\n\nSection LIB6238842_SAM24456643.hashing\nNumber of valid cell barcodes: 748002\nNumber of valid reads (with matching cell and feature barcodes): 18443192\nMean number of valid reads per cell barcode: 24.66\nNumber of valid UMIs (with matching cell and feature barcodes): 15611164\nMean number of valid UMIs per cell barcode: 20.87\nSequencing saturation: 15.36%\n", "LIB6238867_SAM24456643": "Total number of reads: 80117591\nNumber of reads with valid cell barcodes: 77898854 (97.23%)\nNumber of reads with valid feature barcodes: 68600399 (85.62%)\nNumber of reads with valid cell and feature barcodes: 67003135 (83.63%)\n\nSection LIB6238867_SAM24456643.crispr\nNumber of valid cell barcodes: 177738\nNumber of valid reads (with matching cell and feature barcodes): 67003135\nMean number of valid reads per cell barcode: 376.98\nNumber of valid UMIs (with matching cell and feature barcodes): 2355603\nMean number of valid UMIs per cell barcode: 13.25\nSequencing saturation: 96.48%\n", "LIB6238843_SAM24456643": "Total number of reads: 20663289\nNumber of reads with valid cell barcodes: 19945555 (96.53%)\nNumber of reads with valid feature barcodes: 19258975 (93.20%)\nNumber of reads with valid cell and feature barcodes: 18824819 (91.10%)\n\nSection LIB6238843_SAM24456643.hashing\nNumber of valid cell barcodes: 870406\nNumber of valid reads (with matching cell and feature barcodes): 18824819\nMean number of valid reads per cell barcode: 21.63\nNumber of valid UMIs (with matching cell and feature barcodes): 15773765\nMean number of valid UMIs per cell barcode: 18.12\nSequencing saturation: 16.21%\n"}
raw_qc = "/gstore/scratch/u/ghaffars/Dataset/crc_NGS5888//DS000017727/raw_qc.h5ad"
raw_embedding = "/gstore/scratch/u/ghaffars/Dataset/crc_NGS5888//DS000017727/qc_embedding.h5ad"

# %% [markdown]
#  # QC analysis of single cell RNA-seq dataset: This notebook will guide you through the process of quality control analyis on a single-cell RNA sequencing dataset

# %%
# Different scenario for original dataset or test dataset
try:
    if DS_test==True:
        DSID = test_DatasetID
        Version = '2'   # the version of your dataset
        DEV = True
    elif len(alt_experiments)==2:
        DSID = DatasetID
        Version = '4'   # the version of your dataset
        your_experiment = "crispr_hashing_harmonized" # A string that is a key known for our desired experimnet that you wish to work on
    else:
        DSID = DatasetID
        Version = '2'   # the version of your dataset
        your_experiment = "main" # A string that is a key known for our desired experimnet that you wish to work on

except TypeError:
    DSID = DatasetID
    Version = '1'   # the version of your dataset
    your_experiment = "raw_qc" # A string that is a key known for our desired experimnet that you wish to work on

New_experiment = "raw_qc" # A string that is a key known for the updated data saved by that that name

# %%
## Import Libraries
from __future__ import division
import pandas as pd

#single cell libraries
import scanpy as sc

#general
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

#plotting
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('talk')

# %%
import sys
sys.path.append("..")
import Templates.tools.DatasetDB as DB
import Templates.tools.RNA_Seq_QC as rnaqc
import Templates.tools.scProc as proc
try:
    import Templates.tools.rapids_modified as rp
except ImportError:
        pass

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Check if GPU device is available

# %%
GPU = rnaqc.pipeline_has_gpu()

# %%
GPU
# Out:
# True

# %% [markdown]
# ## Instantiate a dataset object given our dataset info

# %%
DS = DB.DATASET(DSID, DEV, title=title, description=description, name_space=name_space, organism=organism,
                       sources=sources, tech_name=tech_name, author=author)

# %%
adata, adatas = DS.load_dataset(Version, your_experiment, Corr=False)
# Out:
# 09:01:11 -> Collating dataset: 'DS000017727' metadata.
# 09:01:11 -> Retrieving all project: 'DS000017727@4' metadata.
# 09:01:11 -> Reading: 'DS000017727'.
#
# 09:01:11 -> Reading: 'DS000017727 -> Experiment: main'.
#
# 09:01:11 -> Reading: 'DS000017727 -> Experiment: main -> Alt. Exp.: crispr'.
# 09:01:11 -> Reading: 'DS000017727 -> Experiment: main -> Alt. Exp.: hashing'.
# 09:01:14 -> Reading: 'DS000017727 -> Experiment: crispr_hashing_harmonized'.
#
# 09:01:14 -> Reading: 'DS000017727 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: crispr'.
# 09:01:14 -> Reading: 'DS000017727 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: hashing'.

# %%
adata = rnaqc.load_data(adata,  alt_experiments)

# %%
adata.obs.head()
# Out:
#                                          Sample           Barcode  \
# SAM24456643_rep13-AAACCCAAGAGCATTA  SAM24456643  AAACCCAAGAGCATTA
# SAM24456643_rep13-AAACCCAAGCCGAATG  SAM24456643  AAACCCAAGCCGAATG
# SAM24456643_rep13-AAACCCAAGGGATCTG  SAM24456643  AAACCCAAGGGATCTG
# SAM24456643_rep13-AAACCCAAGGTGTGAC  SAM24456643  AAACCCAAGGTGTGAC
# SAM24456643_rep13-AAACCCAAGTATGGCG  SAM24456643  AAACCCAAGTATGGCG
#
#                                    DemuxType_crispr  \
# SAM24456643_rep13-AAACCCAAGAGCATTA          unknown
# SAM24456643_rep13-AAACCCAAGCCGAATG          doublet
# SAM24456643_rep13-AAACCCAAGGGATCTG          unknown
# SAM24456643_rep13-AAACCCAAGGTGTGAC          singlet
# SAM24456643_rep13-AAACCCAAGTATGGCG          doublet
#
#                                                  DemuxAssignment_crispr  \
# SAM24456643_rep13-AAACCCAAGAGCATTA                              unknown
# SAM24456643_rep13-AAACCCAAGCCGAATG  ENSG00000182613_1,ENSG00000161835_1
# ...

# %%
adata.var.head()
# Out:
#                                         ID                     Symbol  \
# Symbol
# 3xLinker                 3xLinker_3xLinker          3xLinker_3xLinker
# MIR1302-2HG  GRCh38-2020-A_ENSG00000243485  GRCh38-2020-A_MIR1302-2HG
# FAM138A      GRCh38-2020-A_ENSG00000237613      GRCh38-2020-A_FAM138A
# OR4F5        GRCh38-2020-A_ENSG00000186092        GRCh38-2020-A_OR4F5
# AL627309.1   GRCh38-2020-A_ENSG00000238009   GRCh38-2020-A_AL627309.1
#
#                         Type
# Symbol
# 3xLinker     Gene Expression
# MIR1302-2HG  Gene Expression
# FAM138A      Gene Expression
# OR4F5        Gene Expression
# AL627309.1   Gene Expression

# %% [markdown]
# ## Mapping Rate information

# %%
combined_df,agg,agg_percentage = rnaqc.Mapping_reads_info(Mapping_rate)

# %%
combined_df
# Out:
#                        Total number of reads  \
# LIB6238868_SAM24456643              93430882
# LIB6238844_SAM24456643              20671715
# LIB6238869_SAM24456643              89653129
# LIB6238845_SAM24456643              21096144
# LIB6238866_SAM24456643              99590506
# LIB6238842_SAM24456643              20480190
# LIB6238867_SAM24456643              80117591
# LIB6238843_SAM24456643              20663289
#
#                        Number of reads with valid cell barcodes  \
# LIB6238868_SAM24456643                        90733324 (97.11%)
# LIB6238844_SAM24456643                        19916651 (96.35%)
# LIB6238869_SAM24456643                        87115787 (97.17%)
# LIB6238845_SAM24456643                        20336962 (96.40%)
# LIB6238866_SAM24456643                        96866479 (97.26%)
# LIB6238842_SAM24456643                        19549213 (95.45%)
# LIB6238867_SAM24456643                        77898854 (97.23%)
# ...

# %%
#Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
agg.plot(kind='barh', ax=ax1, stacked=False, color=['midnightblue', 'blue', 'deepskyblue'], legend=False)
ax1.set_xlabel('Read Count')
agg_percentage.plot(kind='barh', ax=ax2, stacked=False, color=['midnightblue', 'blue', 'deepskyblue'])
ax2.set_xlabel('%Read Count')
ax2.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.suptitle('Mapping Rate', fontsize=25)
plt.show()

# %% [markdown]
# ## Doublet information

# %%
rnaqc.doublet_counter(adata)
# Out:
#                                                     Cell counts
# total Cells                                              113364
# cells after keeping singlets by hashing                   87590
# cells after keeping singlets by gRNA                      49036
# cells after keeping singlets by both hashing an...        43261

# %% [markdown]
# ### Sumarize counts

# %%
cnts_before = rnaqc.Summerize_counts(adata, groupby)

# %%
cnts_before
# Out:
#                 cnt    pct
# Sample
# SAM24456643  113364  100.0

# %% [markdown]
# ### calculate qc metrics

# %%
adata = proc.calc_qc_metrics(adata, organism)

# %%
LOWER,UPPER = rnaqc.upper_lower_limits(adata, groupby)

# %%
LOWER
# Out:
#              n_genes_by_counts  total_counts  pct_counts_mt  pct_counts_ribo
# SAM24456643             -882.0      -11078.5      -0.624372         4.740831

# %%
UPPER
# Out:
#              n_genes_by_counts  total_counts  pct_counts_mt  pct_counts_ribo
# SAM24456643             8806.0       33695.5      11.623188        28.100764

# %%
sc.pl.scatter(adata, 'n_genes_by_counts', 'total_counts', color='pct_counts_mt')

# %%
sc.pl.scatter(adata, 'pct_counts_mt', 'pct_counts_ribo', color='n_genes_by_counts')

# %%
sc.pl.violin(
    adata, 
    [
     'n_genes_by_counts', 
     'total_counts', 
     'pct_counts_mt'
     ],
    multi_panel=True
)

# %%
aggr = rnaqc.aggregation(adata, groupby, None, 'before')

# %%
adata.obs.head()
# Out:
#                                          Sample           Barcode  \
# SAM24456643_rep13-AAACCCAAGAGCATTA  SAM24456643  AAACCCAAGAGCATTA
# SAM24456643_rep13-AAACCCAAGCCGAATG  SAM24456643  AAACCCAAGCCGAATG
# SAM24456643_rep13-AAACCCAAGGGATCTG  SAM24456643  AAACCCAAGGGATCTG
# SAM24456643_rep13-AAACCCAAGGTGTGAC  SAM24456643  AAACCCAAGGTGTGAC
# SAM24456643_rep13-AAACCCAAGTATGGCG  SAM24456643  AAACCCAAGTATGGCG
#
#                                    DemuxType_crispr  \
# SAM24456643_rep13-AAACCCAAGAGCATTA          unknown
# SAM24456643_rep13-AAACCCAAGCCGAATG          doublet
# SAM24456643_rep13-AAACCCAAGGGATCTG          unknown
# SAM24456643_rep13-AAACCCAAGGTGTGAC          singlet
# SAM24456643_rep13-AAACCCAAGTATGGCG          doublet
#
#                                                  DemuxAssignment_crispr  \
# SAM24456643_rep13-AAACCCAAGAGCATTA                              unknown
# SAM24456643_rep13-AAACCCAAGCCGAATG  ENSG00000182613_1,ENSG00000161835_1
# ...

# %% [markdown]
# ## Instantiate a RapidsSingleCellPipeline object given our AnnData to prepare RAPIDS environment for other steps

# %%
RP = rp.RapidsSingleCellPipeline(adata)

# %% [markdown]
# ## Notice:
# - **RP._adata is adata before filtering**
# - **RP.adata_ is adata after filtering**
# - **Rp.adata is adata after normalization (and highly variable genes selected)**

# %%
max_cells = None
cell_batch_size = 100000
gene_batch_size = 1200
target_sum = 1e4
n_top_genes = 2000
counts_layer = "counts"
batch_key = "DemuxAssignment_hashing"

# %% [markdown]
# ## Apply filter using GPU

# %%
if GPU:
    RP.filter_data(
    groupby,
    min_genes=min_genes,
    max_genes=max_genes,
    max_cells=max_cells,
    cell_batch_size=cell_batch_size,
    min_cells=min_cells,
    gene_batch_size=gene_batch_size,
        ribo=ribo, 
        doublets=doublets,
        pct_mt=pct_mt, 
        total_counts=total_counts
)
# Out:
# starting with 113364 cells
# Filtering cells.
# Processed 0 cells..
# Processed 100000 cells..
# Filtering genes.
# Completed preprocessing.
# Calculating upper outliers
# Now 105608 cells after filtering max genes
# Calculating upper outliers
# Now 88628 cells after filtering pct mt
# Calculating upper outliers
# Now 85827 cells after filtering total counts
# Now 83899 cells after filtering pct ribo
# Now 68517 cells after keeping singlets by hashing
# Now 41925 cells after keeping singlets by gRNA
# Preprocessing took 36.380860805511475 seconds

# %%
RP._adata
# Out:
# AnnData object with n_obs × n_vars = 113364 × 36603
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo'
#     var: 'ID', 'Symbol', 'Type', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: '.internal'
#     layers: 'counts'

# %%
RP.adata_
# Out:
# View of AnnData object with n_obs × n_vars = 41925 × 31977
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo'
#     var: 'ID', 'Symbol', 'Type', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     layers: 'counts'

# %%
RP._adata.obs["qc_pass"] = RP._adata.obs.index.isin(RP.adata_.obs.index)

# %%
RP._adata.obs
# Out:
#                                          Sample           Barcode  \
# SAM24456643_rep13-AAACCCAAGAGCATTA  SAM24456643  AAACCCAAGAGCATTA
# SAM24456643_rep13-AAACCCAAGCCGAATG  SAM24456643  AAACCCAAGCCGAATG
# SAM24456643_rep13-AAACCCAAGGGATCTG  SAM24456643  AAACCCAAGGGATCTG
# SAM24456643_rep13-AAACCCAAGGTGTGAC  SAM24456643  AAACCCAAGGTGTGAC
# SAM24456643_rep13-AAACCCAAGTATGGCG  SAM24456643  AAACCCAAGTATGGCG
# ...                                         ...               ...
# SAM24456643_rep16-TTTGTTGGTTAAGGAT  SAM24456643  TTTGTTGGTTAAGGAT
# SAM24456643_rep16-TTTGTTGTCACTTATC  SAM24456643  TTTGTTGTCACTTATC
# SAM24456643_rep16-TTTGTTGTCGAGCTGC  SAM24456643  TTTGTTGTCGAGCTGC
# SAM24456643_rep16-TTTGTTGTCGATTGGT  SAM24456643  TTTGTTGTCGATTGGT
# SAM24456643_rep16-TTTGTTGTCTGGGCCA  SAM24456643  TTTGTTGTCTGGGCCA
#
#                                    DemuxType_crispr  \
# SAM24456643_rep13-AAACCCAAGAGCATTA          unknown
# SAM24456643_rep13-AAACCCAAGCCGAATG          doublet
# ...

# %% [markdown]
# ## Apply filter uisng CPU

# %%
if GPU==False:
    adata = proc.filter_adata(
    adata, 
    groupby, 
    min_cells, 
    min_genes, 
    ribo, 
    doublets=doublets, pct_mt=pct_mt)

# %%
sc.pl.scatter(RP.adata_, 'n_genes_by_counts', 'total_counts', color='pct_counts_mt')

# %%
sc.pl.scatter(RP.adata_, 'pct_counts_mt', 'pct_counts_ribo', color='n_genes_by_counts')

# %%
aggr = rnaqc.aggregation(RP.adata_, groupby,aggr, 'after')

# %%
#QC plots before and after
for k in ['n_genes_by_counts', 'total_counts', 'pct_counts_mt', 'pct_counts_ribo']:
    proc.plotQCSplit(aggr, groupby, k)

# %%
cnts_after = rnaqc.Summerize_counts(RP.adata_,groupby)

# %%
cnts_after
# Out:
#                cnt    pct
# Sample
# SAM24456643  41925  100.0

# %%
proc.aggCnts(cnts_before, cnts_after)
# Out:
#              before  after  pct left
# Sample
# SAM24456643  113364  41925      37.0

# %%
proc.plot_cell_left(cnts_before, cnts_after, groupby)

# %% [markdown]
# ## Run Normalize -> HGV -> PCA -> kNN -> Leiden -> UMAP

# %%
RP.proc(n_top_genes, norm=True, scale=True, regress=False, embedding=True, n_pcs=30, 
        n_neighbors=10, knn_n_pcs=30, batch_key=None)
# Out:
# normalizing
# Processed 0 cells..
# normalizing data.
# Completed preprocessing.
# Preprocessing took 4.725479364395142 seconds
# selecting highly variable genes
# Filtering to highly variable genes.
# Processed 0 genes..
# Processed 1200 genes..
# Processed 2400 genes..
# Processed 3600 genes..
# Processed 4800 genes..
# Processed 6000 genes..
# Processed 7200 genes..
# Processed 8400 genes..
# Processed 9600 genes..
# Processed 10800 genes..
# Processed 12000 genes..
# Processed 13200 genes..
# Processed 14400 genes..
# Processed 15600 genes..
# Processed 16800 genes..
# Processed 18000 genes..
# Processed 19200 genes..
# Processed 20400 genes..
# Processed 21600 genes..
# Processed 22800 genes..
# Processed 24000 genes..
# Processed 25200 genes..
# Processed 26400 genes..
# Processed 27600 genes..
# Processed 28800 genes..
# Processed 30000 genes..
# Processed 31200 genes..
# Completed preprocessing.
# Converting sparse GPU array to dense GPU array.
# ...

# %% [markdown]
# ## Batch Correction

# %%
#RP.run_scvi(counts_layer = "counts", batch_key = "DemuxAssignment_hashing")

# %%
#RP.adata.obsm["X_scVI"]

# %% [markdown]
# ## Plot PCA UMAP

# %%
if GPU:
    sc.pl.umap(RP.adata, color="leiden")

# %%
if GPU:
    sc.pl.umap(RP.adata, color=groupby)

# %%
if GPU:
    sc.pl.umap(RP.adata, color="DemuxAssignment_hashing")

# %%
#This is just to quickly check how the data looks. Cell cycle scores are added to main adata object, but normalized and processed object is not saved
if GPU==False:
    adata_tmp = adata.copy()

# %%
if GPU==False:
    adata_tmp = proc.proc(adata_tmp, 'auto', norm=True, scale=True, regress=False, embedding=True)
    sc.pl.umap(adata_tmp, color=groupby)

# %% [markdown]
# ## Add score cell cycle

# %%
if organism=='human':
    fcc =  '/gstore/data/cbfunge/data/CellCycleGenes/Homo_sapiens.csv'
elif organism == 'mouse':
    fcc = '/gstore/data/cbfunge/data/CellCycleGenes/Mus_musculus.csv'
    
if GPU:
    proc.compute_cellCycleScores(RP._adata, fcc)
else:
    proc.compute_cellCycleScores(adata_tmp, fcc)

# %%
RP._adata
# Out:
# AnnData object with n_obs × n_vars = 113364 × 36603
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'qc_pass', 'S_score', 'G2M_score', 'phase'
#     var: 'ID', 'Symbol', 'Type', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: '.internal'
#     layers: 'counts'

# %%
RP.adata
# Out:
# AnnData object with n_obs × n_vars = 41925 × 2000
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'leiden'
#     uns: 'neighbors', 'umap', 'leiden_colors', 'Sample_colors', 'DemuxAssignment_hashing_colors'
#     obsm: 'X_pca', 'X_umap'
#     obsp: 'distances', 'connectivities'

# %%
if GPU==False:
    adata.obs['phase'] = adata_tmp.obs['phase']
    adata.obs['G2M_score'] = adata_tmp.obs['G2M_score']
    adata.obs['S_score'] = adata_tmp.obs['S_score']
    adata.obs

# %%
if GPU==False:
    sc.pl.umap(adata_tmp, color='phase')

# %%
adatas
# Out:
# {'crispr': AnnData object with n_obs × n_vars = 113364 × 20345
#      uns: '.internal'
#      layers: 'counts',
#  'hashing': AnnData object with n_obs × n_vars = 113364 × 19
#      uns: '.internal'
#      layers: 'counts'}

# %%
adatas_updated = adatas.copy()
if GPU:
    adata_updated = RP._adata.copy()
else:
    adata_updated = adata.copy()

# %%
adata_updated
# Out:
# AnnData object with n_obs × n_vars = 113364 × 36603
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'qc_pass', 'S_score', 'G2M_score', 'phase'
#     var: 'ID', 'Symbol', 'Type', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: '.internal'
#     layers: 'counts'

# %%
adatas_updated
# Out:
# {'crispr': AnnData object with n_obs × n_vars = 113364 × 20345
#      uns: '.internal'
#      layers: 'counts',
#  'hashing': AnnData object with n_obs × n_vars = 113364 × 19
#      uns: '.internal'
#      layers: 'counts'}

# %% [markdown]
# ### Write h5ad version on the disk

# %%
# If you wish to write on the disk
#adata_updated.var.index.name = None
#adata_updated.write_h5ad(raw_qc)

# %% [markdown]
# ## Write h5ad file with embedings for Energy Distance analaysis

# %%
if GPU:
    RP.adata_.obsp = RP.adata.obsp.copy()
    RP.adata_.obsm = RP.adata.obsm.copy()
else:
    adata.obsp = adata_tmp.obsp.copy()
    adata.obsm = adata_tmp.obsm.copy()

# %%
if GPU:
    adata_embedding = RP.adata_.copy()
else:
    adata_embedding = adata.copy()

# %%
adata_embedding.write_h5ad(raw_embedding)

# %% [markdown]
# ## Update the dataset with new experiment "raw_qc"

# %%
if DS_test==False:
    dsid, version = DS.update_dataset(New_experiment, adata_updated, adatas_updated, test=False)
else:    
    dsid, version = DS.update_another_dataset(test_DatasetID, True, 1, New_experiment, adata_updated, adatas_updated, test=True)
# Out:
# 09:03:33 -> Collating dataset: 'DS000017727' metadata.
# 09:03:33 -> Retrieving all project: 'DS000017727@1' metadata.
#
# 09:03:33 -> Reading: 'DS000017727'.
#
# 09:03:33 -> Reading: 'DS000017727 -> Experiment: main'.
#
# 09:03:33 -> Reading: 'DS000017727 -> Experiment: main -> Alt. Exp.: crispr'.
# 09:03:34 -> Reading: 'DS000017727 -> Experiment: main -> Alt. Exp.: hashing'.
# PYDSDB:INFO: Experiment already contained metadata, overwriting.
# PYDSDB:INFO: Experiment already contained metadata, overwriting.
# PYDSDB:INFO: Experiment already contained metadata, overwriting.
# Retrieving cached token data.
# Successfully authenticated.
# 09:05:15 -> Retrieving all project: 'DS000017727@latest' metadata.
# 09:05:16 -> Collating and validating project resources.
# 09:05:16 -> Attempting upload.
# ...
# 100%|████████████████████████████████████████| 73/73 [02:02<00:00,  1.68s/file]
# Clearing upload info.
# 09:07:34 -> Upload completed.
# Processing...
# Processing...
# Processing...
# ...

# %%
dsid, version
# Out:
# ('DS000017727', '5')
