# %%
# Parameters
DatasetID = "DS000017726"
DEV = False
test_DatasetID = ""
DS_test = False
title = "Recursion DLD1 Library3- Screen2 (NGS5888)"
description = "Production scale screen in DLD-1 cells with 1/4 of the genome-wide CRISPR library (sub-lib-3, ~22K guides). 1 time point: Day-5. We performed 24 rxns of 10x 3' HT kit with an estimated loading of 52K cells. We performed a pilot study to test the library quality before the production-level sequencing. We will submit 72 libraries (24 GEX, 24 HTO and 24 sgRNA) We request 600M reads for GEX, 20M for HTO and 40M for sgRNA, after finishing QC sequencing of NGS5887. NGS has built the GEX and sgRNA libraries using automation, we will provide manually constructed HTO libraries."
name_space = [{"id": "GRCh38", "type": "genome"}]
sources = [{"id": "Siavash-1234", "name": "Geo-ID"}]
tech_name = "scRNA-seq"
author = "SG"
alt_experiments = ["crispr", "hashing"]
organism = "human"
groupby = "Sample"
min_cells = 3
min_genes = 500
max_genes = None
pct_mt = None
total_counts = None
n_top_genes = 2000
ribo = True
doublets = True
Mapping_rate = {"LIB6238870_SAM24456643": "Total number of reads: 88897531\nNumber of reads with valid cell barcodes: 86347016 (97.13%)\nNumber of reads with valid feature barcodes: 75401439 (84.82%)\nNumber of reads with valid cell and feature barcodes: 73646283 (82.84%)\n\nSection LIB6238870_SAM24456643.crispr\nNumber of valid cell barcodes: 184025\nNumber of valid reads (with matching cell and feature barcodes): 73646283\nMean number of valid reads per cell barcode: 400.20\nNumber of valid UMIs (with matching cell and feature barcodes): 2608395\nMean number of valid UMIs per cell barcode: 14.17\nSequencing saturation: 96.46%\n", "LIB6238846_SAM24456643": "Total number of reads: 20779019\nNumber of reads with valid cell barcodes: 20121426 (96.84%)\nNumber of reads with valid feature barcodes: 19470503 (93.70%)\nNumber of reads with valid cell and feature barcodes: 19010077 (91.49%)\n\nSection LIB6238846_SAM24456643.hashing\nNumber of valid cell barcodes: 808740\nNumber of valid reads (with matching cell and feature barcodes): 19010077\nMean number of valid reads per cell barcode: 23.51\nNumber of valid UMIs (with matching cell and feature barcodes): 16322327\nMean number of valid UMIs per cell barcode: 20.18\nSequencing saturation: 14.14%\n", "LIB6238872_SAM24456643": "Total number of reads: 87481459\nNumber of reads with valid cell barcodes: 85078246 (97.25%)\nNumber of reads with valid feature barcodes: 74205398 (84.82%)\nNumber of reads with valid cell and feature barcodes: 72526778 (82.91%)\n\nSection LIB6238872_SAM24456643.crispr\nNumber of valid cell barcodes: 162976\nNumber of valid reads (with matching cell and feature barcodes): 72526778\nMean number of valid reads per cell barcode: 445.02\nNumber of valid UMIs (with matching cell and feature barcodes): 2199616\nMean number of valid UMIs per cell barcode: 13.50\nSequencing saturation: 96.97%\n", "LIB6238848_SAM24456643": "Total number of reads: 20884156\nNumber of reads with valid cell barcodes: 20051170 (96.01%)\nNumber of reads with valid feature barcodes: 19168552 (91.79%)\nNumber of reads with valid cell and feature barcodes: 18744479 (89.75%)\n\nSection LIB6238848_SAM24456643.hashing\nNumber of valid cell barcodes: 838149\nNumber of valid reads (with matching cell and feature barcodes): 18744479\nMean number of valid reads per cell barcode: 22.36\nNumber of valid UMIs (with matching cell and feature barcodes): 15376867\nMean number of valid UMIs per cell barcode: 18.35\nSequencing saturation: 17.97%\n", "LIB6238871_SAM24456643": "Total number of reads: 51346241\nNumber of reads with valid cell barcodes: 50071323 (97.52%)\nNumber of reads with valid feature barcodes: 44290284 (86.26%)\nNumber of reads with valid cell and feature barcodes: 43338342 (84.40%)\n\nSection LIB6238871_SAM24456643.crispr\nNumber of valid cell barcodes: 162080\nNumber of valid reads (with matching cell and feature barcodes): 43338342\nMean number of valid reads per cell barcode: 267.39\nNumber of valid UMIs (with matching cell and feature barcodes): 1831953\nMean number of valid UMIs per cell barcode: 11.30\nSequencing saturation: 95.77%\n", "LIB6238847_SAM24456643": "Total number of reads: 20431626\nNumber of reads with valid cell barcodes: 19696740 (96.40%)\nNumber of reads with valid feature barcodes: 18946579 (92.73%)\nNumber of reads with valid cell and feature barcodes: 18482331 (90.46%)\n\nSection LIB6238847_SAM24456643.hashing\nNumber of valid cell barcodes: 662275\nNumber of valid reads (with matching cell and feature barcodes): 18482331\nMean number of valid reads per cell barcode: 27.91\nNumber of valid UMIs (with matching cell and feature barcodes): 15561036\nMean number of valid UMIs per cell barcode: 23.50\nSequencing saturation: 15.81%\n", "LIB6238873_SAM24456643": "Total number of reads: 72936912\nNumber of reads with valid cell barcodes: 70997350 (97.34%)\nNumber of reads with valid feature barcodes: 62282765 (85.39%)\nNumber of reads with valid cell and feature barcodes: 60905593 (83.50%)\n\nSection LIB6238873_SAM24456643.crispr\nNumber of valid cell barcodes: 159460\nNumber of valid reads (with matching cell and feature barcodes): 60905593\nMean number of valid reads per cell barcode: 381.95\nNumber of valid UMIs (with matching cell and feature barcodes): 2137119\nMean number of valid UMIs per cell barcode: 13.40\nSequencing saturation: 96.49%\n", "LIB6238849_SAM24456643": "Total number of reads: 20827140\nNumber of reads with valid cell barcodes: 20084826 (96.44%)\nNumber of reads with valid feature barcodes: 19265097 (92.50%)\nNumber of reads with valid cell and feature barcodes: 18825734 (90.39%)\n\nSection LIB6238849_SAM24456643.hashing\nNumber of valid cell barcodes: 770668\nNumber of valid reads (with matching cell and feature barcodes): 18825734\nMean number of valid reads per cell barcode: 24.43\nNumber of valid UMIs (with matching cell and feature barcodes): 15615949\nMean number of valid UMIs per cell barcode: 20.26\nSequencing saturation: 17.05%\n"}
raw_qc = "/gstore/scratch/u/ghaffars/Dataset/crc_NGS5888//DS000017726/raw_qc.h5ad"
raw_embedding = "/gstore/scratch/u/ghaffars/Dataset/crc_NGS5888//DS000017726/qc_embedding.h5ad"

# %% [markdown]
#  # QC analysis of single cell RNA-seq dataset: This notebook will guide you through the process of quality control analyis on a single-cell RNA sequencing dataset

# %%
# Different scenario for original dataset or test dataset
try:
    if DS_test==True:
        DSID = test_DatasetID
        Version = '2'   # the version of your dataset
        DEV = True
    elif len(alt_experiments)==2:
        DSID = DatasetID
        Version = '4'   # the version of your dataset
        your_experiment = "crispr_hashing_harmonized" # A string that is a key known for our desired experimnet that you wish to work on
    else:
        DSID = DatasetID
        Version = '2'   # the version of your dataset
        your_experiment = "main" # A string that is a key known for our desired experimnet that you wish to work on

except TypeError:
    DSID = DatasetID
    Version = '1'   # the version of your dataset
    your_experiment = "raw_qc" # A string that is a key known for our desired experimnet that you wish to work on

New_experiment = "raw_qc" # A string that is a key known for the updated data saved by that that name

# %%
## Import Libraries
from __future__ import division
import pandas as pd

#single cell libraries
import scanpy as sc

#general
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

#plotting
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('talk')

# %%
import sys
sys.path.append("..")
import Templates.tools.DatasetDB as DB
import Templates.tools.RNA_Seq_QC as rnaqc
import Templates.tools.scProc as proc
try:
    import Templates.tools.rapids_modified as rp
except ImportError:
        pass

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Check if GPU device is available

# %%
GPU = rnaqc.pipeline_has_gpu()

# %%
GPU
# Out:
# True

# %% [markdown]
# ## Instantiate a dataset object given our dataset info

# %%
DS = DB.DATASET(DSID, DEV, title=title, description=description, name_space=name_space, organism=organism,
                       sources=sources, tech_name=tech_name, author=author)

# %%
adata, adatas = DS.load_dataset(Version, your_experiment, Corr=False)
# Out:
# 09:08:31 -> Collating dataset: 'DS000017726' metadata.
# 09:08:31 -> Retrieving all project: 'DS000017726@4' metadata.
# 09:08:31 -> Reading: 'DS000017726'.
#
# 09:08:31 -> Reading: 'DS000017726 -> Experiment: main'.
#
# 09:08:31 -> Reading: 'DS000017726 -> Experiment: main -> Alt. Exp.: crispr'.
# 09:08:32 -> Reading: 'DS000017726 -> Experiment: main -> Alt. Exp.: hashing'.
# 09:08:34 -> Reading: 'DS000017726 -> Experiment: crispr_hashing_harmonized'.
#
# 09:08:34 -> Reading: 'DS000017726 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: crispr'.
# 09:08:34 -> Reading: 'DS000017726 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: hashing'.

# %%
adata = rnaqc.load_data(adata,  alt_experiments)

# %%
adata.obs.head()
# Out:
#                                          Sample           Barcode  \
# SAM24456643_rep17-AAACCCAAGAAGCGCT  SAM24456643  AAACCCAAGAAGCGCT
# SAM24456643_rep17-AAACCCAAGAGGTATT  SAM24456643  AAACCCAAGAGGTATT
# SAM24456643_rep17-AAACCCAAGCATGATA  SAM24456643  AAACCCAAGCATGATA
# SAM24456643_rep17-AAACCCAAGCGTTGTT  SAM24456643  AAACCCAAGCGTTGTT
# SAM24456643_rep17-AAACCCAAGGCACCAA  SAM24456643  AAACCCAAGGCACCAA
#
#                                    DemuxType_crispr  \
# SAM24456643_rep17-AAACCCAAGAAGCGCT          unknown
# SAM24456643_rep17-AAACCCAAGAGGTATT          singlet
# SAM24456643_rep17-AAACCCAAGCATGATA          singlet
# SAM24456643_rep17-AAACCCAAGCGTTGTT          singlet
# SAM24456643_rep17-AAACCCAAGGCACCAA          doublet
#
#                                                  DemuxAssignment_crispr  \
# SAM24456643_rep17-AAACCCAAGAAGCGCT                              unknown
# SAM24456643_rep17-AAACCCAAGAGGTATT                    ENSG00000103067_1
# SAM24456643_rep17-AAACCCAAGCATGATA                    ENSG00000164815_4
# SAM24456643_rep17-AAACCCAAGCGTTGTT                    ENSG00000211873_2
# SAM24456643_rep17-AAACCCAAGGCACCAA  ENSG00000256463_3,ENSG00000162745_1
#
#                                    DemuxType_hashing DemuxAssignment_hashing  \
# SAM24456643_rep17-AAACCCAAGAAGCGCT           unknown                 unknown
# SAM24456643_rep17-AAACCCAAGAGGTATT           singlet             SAM24439045
# SAM24456643_rep17-AAACCCAAGCATGATA           singlet             SAM24439044
# SAM24456643_rep17-AAACCCAAGCGTTGTT           singlet             SAM24439043
# SAM24456643_rep17-AAACCCAAGGCACCAA           singlet             SAM24439044
#
#                                    cellline timepoint      HTO   NGS_ID  \
# SAM24456643_rep17-AAACCCAAGAAGCGCT  unknown   unknown  unknown  unknown
# SAM24456643_rep17-AAACCCAAGAGGTATT     DLD1      day5   HTO-16  NGS5888
# SAM24456643_rep17-AAACCCAAGCATGATA     DLD1      day5   HTO-15  NGS5888
# SAM24456643_rep17-AAACCCAAGCGTTGTT     DLD1      day5   HTO-10  NGS5888
# SAM24456643_rep17-AAACCCAAGGCACCAA     DLD1      day5    HTO-5  NGS5888
#
#                                    Biological_replicate 10Xrun  \
# SAM24456643_rep17-AAACCCAAGAAGCGCT              unknown     17
# SAM24456643_rep17-AAACCCAAGAGGTATT          SAM24439045     17
# SAM24456643_rep17-AAACCCAAGCATGATA          SAM24439044     17
# SAM24456643_rep17-AAACCCAAGCGTTGTT          SAM24439043     17
# SAM24456643_rep17-AAACCCAAGGCACCAA          SAM24439044     17
#
#                                                                            sublibrary  \
# SAM24456643_rep17-AAACCCAAGAAGCGCT                                            unknown
# SAM24456643_rep17-AAACCCAAGAGGTATT  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
# SAM24456643_rep17-AAACCCAAGCATGATA  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
# SAM24456643_rep17-AAACCCAAGCGTTGTT  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
# SAM24456643_rep17-AAACCCAAGGCACCAA  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
#
#                                    gRNA_library_MOI  \
# SAM24456643_rep17-AAACCCAAGAAGCGCT          unknown
# SAM24456643_rep17-AAACCCAAGAGGTATT              0.5
# SAM24456643_rep17-AAACCCAAGCATGATA              0.5
# SAM24456643_rep17-AAACCCAAGCGTTGTT              0.5
# SAM24456643_rep17-AAACCCAAGGCACCAA              0.5
#
#                                                             gene_symbol  \
# SAM24456643_rep17-AAACCCAAGAAGCGCT                              unknown
# SAM24456643_rep17-AAACCCAAGAGGTATT                                ESRP2
# SAM24456643_rep17-AAACCCAAGCATGATA                                 ORC5
# SAM24456643_rep17-AAACCCAAGCGTTGTT                               TRAJ16
# SAM24456643_rep17-AAACCCAAGGCACCAA  ENSG00000256463_3,ENSG00000162745_1
#
#                                                                   class
# SAM24456643_rep17-AAACCCAAGAAGCGCT                              unknown
# SAM24456643_rep17-AAACCCAAGAGGTATT                               target
# SAM24456643_rep17-AAACCCAAGCATGATA                               target
# SAM24456643_rep17-AAACCCAAGCGTTGTT                               target
# SAM24456643_rep17-AAACCCAAGGCACCAA  ENSG00000256463_3,ENSG00000162745_1

# %%
adata.var.head()
# Out:
#                                         ID                     Symbol  \
# Symbol
# 3xLinker                 3xLinker_3xLinker          3xLinker_3xLinker
# MIR1302-2HG  GRCh38-2020-A_ENSG00000243485  GRCh38-2020-A_MIR1302-2HG
# FAM138A      GRCh38-2020-A_ENSG00000237613      GRCh38-2020-A_FAM138A
# OR4F5        GRCh38-2020-A_ENSG00000186092        GRCh38-2020-A_OR4F5
# AL627309.1   GRCh38-2020-A_ENSG00000238009   GRCh38-2020-A_AL627309.1
#
#                         Type
# Symbol
# 3xLinker     Gene Expression
# MIR1302-2HG  Gene Expression
# FAM138A      Gene Expression
# OR4F5        Gene Expression
# AL627309.1   Gene Expression

# %% [markdown]
# ## Mapping Rate information

# %%
combined_df,agg,agg_percentage = rnaqc.Mapping_reads_info(Mapping_rate)

# %%
combined_df
# Out:
#                        Total number of reads  \
# LIB6238870_SAM24456643              88897531
# LIB6238846_SAM24456643              20779019
# LIB6238872_SAM24456643              87481459
# LIB6238848_SAM24456643              20884156
# LIB6238871_SAM24456643              51346241
# LIB6238847_SAM24456643              20431626
# LIB6238873_SAM24456643              72936912
# LIB6238849_SAM24456643              20827140
#
#                        Number of reads with valid cell barcodes  \
# LIB6238870_SAM24456643                        86347016 (97.13%)
# LIB6238846_SAM24456643                        20121426 (96.84%)
# LIB6238872_SAM24456643                        85078246 (97.25%)
# LIB6238848_SAM24456643                        20051170 (96.01%)
#                        Sequencing saturation Experiment
# LIB6238870_SAM24456643                96.46%     crispr
# LIB6238846_SAM24456643                14.14%    hashing
# LIB6238872_SAM24456643                96.97%     crispr
# LIB6238848_SAM24456643                17.97%    hashing
# LIB6238871_SAM24456643                95.77%     crispr
# LIB6238847_SAM24456643                15.81%    hashing
# LIB6238873_SAM24456643                96.49%     crispr
# LIB6238849_SAM24456643                17.05%    hashing

# %%
#Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
agg.plot(kind='barh', ax=ax1, stacked=False, color=['midnightblue', 'blue', 'deepskyblue'], legend=False)
ax1.set_xlabel('Read Count')
agg_percentage.plot(kind='barh', ax=ax2, stacked=False, color=['midnightblue', 'blue', 'deepskyblue'])
ax2.set_xlabel('%Read Count')
ax2.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.suptitle('Mapping Rate', fontsize=25)
plt.show()

# %% [markdown]
# ## Doublet information

# %%
rnaqc.doublet_counter(adata)
# Out:
#                                                     Cell counts
# total Cells                                              105815
# cells after keeping singlets by hashing                   76129
# cells after keeping singlets by gRNA                      40738
# cells after keeping singlets by both hashing an...        36098

# %% [markdown]
# ### Sumarize counts

# %%
cnts_before = rnaqc.Summerize_counts(adata, groupby)

# %%
cnts_before
# Out:
#                 cnt    pct
# Sample
# SAM24456643  105815  100.0

# %% [markdown]
# ### calculate qc metrics

# %%
adata = proc.calc_qc_metrics(adata, organism)

# %%
LOWER,UPPER = rnaqc.upper_lower_limits(adata, groupby)

# %%
LOWER
# Out:
#              n_genes_by_counts  total_counts  pct_counts_mt  pct_counts_ribo
# SAM24456643            -1936.5      -13418.0      -0.919087         4.645388

# %%
UPPER
# Out:
#              n_genes_by_counts  total_counts  pct_counts_mt  pct_counts_ribo
# SAM24456643             9147.5       33350.0      11.838449        28.104419

# %%
sc.pl.scatter(adata, 'n_genes_by_counts', 'total_counts', color='pct_counts_mt')

# %%
sc.pl.scatter(adata, 'pct_counts_mt', 'pct_counts_ribo', color='n_genes_by_counts')

# %%
sc.pl.violin(
    adata, 
    [
     'n_genes_by_counts', 
     'total_counts', 
     'pct_counts_mt'
     ],
    multi_panel=True
)

# %%
aggr = rnaqc.aggregation(adata, groupby, None, 'before')

# %%
adata.obs.head()
# Out:
#                                          Sample           Barcode  \
# SAM24456643_rep17-AAACCCAAGAAGCGCT  SAM24456643  AAACCCAAGAAGCGCT
# SAM24456643_rep17-AAACCCAAGAGGTATT  SAM24456643  AAACCCAAGAGGTATT
# SAM24456643_rep17-AAACCCAAGCATGATA  SAM24456643  AAACCCAAGCATGATA
# SAM24456643_rep17-AAACCCAAGCGTTGTT  SAM24456643  AAACCCAAGCGTTGTT
# SAM24456643_rep17-AAACCCAAGGCACCAA  SAM24456643  AAACCCAAGGCACCAA
#
#                                    DemuxType_crispr  \
# SAM24456643_rep17-AAACCCAAGAAGCGCT          unknown
# SAM24456643_rep17-AAACCCAAGAGGTATT          singlet
# SAM24456643_rep17-AAACCCAAGCATGATA          singlet
# SAM24456643_rep17-AAACCCAAGCGTTGTT          singlet
# SAM24456643_rep17-AAACCCAAGGCACCAA          doublet
#
#                                                  DemuxAssignment_crispr  \
# SAM24456643_rep17-AAACCCAAGAAGCGCT                              unknown
# SAM24456643_rep17-AAACCCAAGAGGTATT                    ENSG00000103067_1
# SAM24456643_rep17-AAACCCAAGCATGATA                    ENSG00000164815_4
# SAM24456643_rep17-AAACCCAAGCGTTGTT                    ENSG00000211873_2
# SAM24456643_rep17-AAACCCAAGGCACCAA  ENSG00000256463_3,ENSG00000162745_1
#
#                                    DemuxType_hashing DemuxAssignment_hashing  \
# SAM24456643_rep17-AAACCCAAGAAGCGC
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Instantiate a RapidsSingleCellPipeline object given our AnnData to prepare RAPIDS environment for other steps

# %%
RP = rp.RapidsSingleCellPipeline(adata)

# %% [markdown]
# ## Notice:
# - **RP._adata is adata before filtering**
# - **RP.adata_ is adata after filtering**
# - **Rp.adata is adata after normalization (and highly variable genes selected)**

# %%
max_cells = None
cell_batch_size = 100000
gene_batch_size = 1200
target_sum = 1e4
n_top_genes = 2000
counts_layer = "counts"
batch_key = "DemuxAssignment_hashing"

# %% [markdown]
# ## Apply filter using GPU

# %%
if GPU:
    RP.filter_data(
    groupby,
    min_genes=min_genes,
    max_genes=max_genes,
    max_cells=max_cells,
    cell_batch_size=cell_batch_size,
    min_cells=min_cells,
    gene_batch_size=gene_batch_size,
        ribo=ribo, 
        doublets=doublets,
        pct_mt=pct_mt, 
        total_counts=total_counts
)
# Out:
# starting with 105815 cells
# Filtering cells.
# Processed 0 cells..
# Processed 100000 cells..
# Filtering genes.
# Completed preprocessing.
# Calculating upper outliers
# Now 98795 cells after filtering max genes
# Calculating upper outliers
# Now 83236 cells after filtering pct mt
# Calculating upper outliers
# Now 80324 cells after filtering total counts
# Now 78522 cells after filtering pct ribo
# Now 58272 cells after keeping singlets by hashing
# Now 34983 cells after keeping singlets by gRNA
# Preprocessing took 34.22645545005798 seconds

# %%
RP._adata
# Out:
# AnnData object with n_obs × n_vars = 105815 × 36603
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo'
#     var: 'ID', 'Symbol', 'Type', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: '.internal'
#     layers: 'counts'

# %%
RP.adata_
# Out:
# View of AnnData object with n_obs × n_vars = 34983 × 31711
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo'
#     var: 'ID', 'Symbol', 'Type', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     layers: 'counts'

# %%
RP._adata.obs["qc_pass"] = RP._adata.obs.index.isin(RP.adata_.obs.index)

# %%
RP._adata.obs
# Out:
#                                          Sample           Barcode  \
# SAM24456643_rep17-AAACCCAAGAAGCGCT  SAM24456643  AAACCCAAGAAGCGCT
# SAM24456643_rep17-AAACCCAAGAGGTATT  SAM24456643  AAACCCAAGAGGTATT
# SAM24456643_rep17-AAACCCAAGCATGATA  SAM24456643  AAACCCAAGCATGATA
# SAM24456643_rep17-AAACCCAAGCGTTGTT  SAM24456643  AAACCCAAGCGTTGTT
# SAM24456643_rep17-AAACCCAAGGCACCAA  SAM24456643  AAACCCAAGGCACCAA
# ...                                         ...               ...
# SAM24456643_rep20-TTTGTTGTCCTGTAGA  SAM24456643  TTTGTTGTCCTGTAGA
# SAM24456643_rep20-TTTGTTGTCGAAGAAT  SAM24456643  TTTGTTGTCGAAGAAT
# SAM24456643_rep20-TTTGTTGTCGACCAAT  SAM24456643  TTTGTTGTCGACCAAT
# SAM24456643_rep20-TTTGTTGTCGTAGCCG  SAM24456643  TTTGTTGTCGTAGCCG
# SAM24456643_rep20-TTTGTTGTCTCGGTCT  SAM24456643  TTTGTTGTCTCGGTCT
#
#                                    DemuxType_crispr  \
# SAM24456643_rep17-AAACCCAAGAAGCGCT          unknown
# SAM24456643_rep17-AAACCCAAGAGGTATT          singlet
# SAM24456643_rep17-AAACCCAAGCATGATA          singlet
# SAM24456643_rep17-AAACCCAAGCGTTGTT          singlet
# SAM24456643_rep17-AAACCCAAGGCACCAA          doublet
# ...                                             ...
# SAM24456643_rep20-TTTGTTGTCCTGTAGA          unknown
# SAM24456643_rep20-TTTGTTGTCGAAGAAT          unknown
# SAM24456643_rep20-TTTGTTGTCGACCAAT          unknown
# SAM24456643_rep20-TTTGTTGTCGTAGCCG          doublet
# SAM24456643_rep20-TTTGTTGTCTCGGTCT          singlet
#
#                                                                DemuxAssignment_crispr  \
# SAM24456643_rep17-AAACCCAAGAAGCGCT                                            unknown
# SAM24456643_rep17-AAACCCAAGAGGTATT                                  ENSG00000103067_1
# SAM24456643_rep17-AAACCCAAGCATGATA                                  ENSG00000164815_4
# SAM24456643_rep17-AAACCCAAGCGTTGTT                                  ENSG00000211873_2
# SAM24456643_rep17-AAACCCAAGGCACCAA                ENSG00000256463_3,ENSG00000162745_1
# ...                                                                               ...
# SAM24456643_rep20-TTTGTTGTCCTGTAGA                                            unknown
# SAM24456643_rep20-TTTGTTGTCGAAGAAT                                            unknown
# SAM24456643_rep20-TTTGTTGTCGACCAAT                                            unknown
# SAM24456643_rep20-TTTGTTGTCGTAGCCG  ENSG00000284554_3,ENSG00000181109_2,ENSG000001...
# SAM24456643_rep20-TTTGTTGTCTCGGTCT                                  ENSG00000184459_3
#
#                                    DemuxType_hashing  \
# SAM24456643_rep17-AAACCCAAGAAGCGCT           unknown
# SAM24456643_rep17-AAACCCAAGAGGTATT           singlet
# SAM24456643_rep17-AAACCCAAGCATGATA           singlet
# SAM24456643_rep17-AAACCCAAGCGTTGTT           singlet
# SAM24456643_rep17-AAACCCAAGGCACCAA           singlet
# ...                                              ...
# SAM24456643_rep20-TTTGTTGTCCTGTAGA           singlet
# SAM24456643_rep20-TTTGTTGTCGAAGAAT           singlet
# SAM24456643_rep20-TTTGTTGTCGACCAAT           singlet
# SAM24456643_rep20-TTTGTTGTCGTAGCCG           doublet
# SAM24456643_rep20-TTTGTTGTCTCGGTCT           unknown
#
#                                      DemuxAssignment_hashing  \
# SAM24456643_rep17-AAACCCAAGAAGCGCT                   unknown
# SAM24456643_rep17-AAACCCAAGAGGTATT               SAM24439045
# SAM24456643_rep17-AAACCCAAGCATGATA               SAM24439044
# SAM24456643_rep17-AAACCCAAGCGTTGTT               SAM24439043
# SAM24456643_rep17-AAACCCAAGGCACCAA               SAM24439044
# ...                                                      ...
# SAM24456643_rep20-TTTGTTGTCCTGTAGA               SAM24439044
# SAM24456643_rep20-TTTGTTGTCGAAGAAT               SAM24439044
# SAM24456643_rep20-TTTGTTGTCGACCAAT               SAM24439044
# SAM24456643_rep20-TTTGTTGTCGTAGCCG  HTO-7,HTO-5,HTO-8,HTO-13
# SAM24456643_rep20-TTTGTTGTCTCGGTCT                   unknown
#
#                                                     cellline  \
# SAM24456643_rep17-AAACCCAAGAAGCGCT                   unknown
# SAM24456643_rep17-AAACCCAAGAGGTATT                      DLD1
# SAM24456643_rep17-AAACCCAAGCATGATA                      DLD1
# SAM24456643_rep17-AAACCCAAGCGTTGTT                      DLD1
# SAM24456643_rep17-AAACCCAAGGCACCAA                      DLD1
# ...                                                      ...
# SAM24456643_rep20-TTTGTTGTCCTGTAGA                      DLD1
# SAM24456643_rep20-TTTGTTGTCGAAGAAT                      DLD1
# SAM24456643_rep20-TTTGTTGTCGACCAAT                      DLD1
# SAM24456643_rep20-TTTGTTGTCGTAGCCG  HTO-7,HTO-5,HTO-8,HTO-13
# SAM24456643_rep20-TTTGTTGTCTCGGTCT                   unknown
#
#                                                    timepoint  \
# SAM24456643_rep17-AAACCCAAGAAGCGCT                   unknown
# SAM24456643_rep17-AAACCCAAGAGGTATT                      day5
# SAM24456643_rep17-AAACCCAAGCATGATA                      day5
# SAM24456643_rep17-AAACCCAAGCGTTGTT                      day5
# SAM24456643_rep17-AAACCCAAGGCACCAA                      day5
# ...                                                      ...
# SAM24456643_rep20-TTTGTTGTCCTGTAGA                      day5
# SAM24456643_rep20-TTTGTTGTCGAAGAAT                      day5
# SAM24456643_rep20-TTTGTTGTCGACCAAT                      day5
# SAM24456643_rep20-TTTGTTGTCGTAGCCG  HTO-7,HTO-5,HTO-8,HTO-13
# SAM24456643_rep20-TTTGTTGTCTCGGTCT                   unknown
#
#                                                          HTO  \
# SAM24456643_rep17-AAACCCAAGAAGCGCT                   unknown
# SAM24456643_rep17-AAACCCAAGAGGTATT                    HTO-16
# SAM24456643_rep17-AAACCCAAGCATGATA                    HTO-15
# SAM24456643_rep17-AAACCCAAGCGTTGTT                    HTO-10
# SAM24456643_rep17-AAACCCAAGGCACCAA                     HTO-5
# ...                                                      ...
# SAM24456643_rep20-TTTGTTGTCCTGTAGA                     HTO-4
# SAM24456643_rep20-TTTGTTGTCGAAGAAT                     HTO-5
# SAM24456643_rep20-TTTGTTGTCGACCAAT                    HTO-15
# SAM24456643_rep20-TTTGTTGTCGTAGCCG  HTO-7,HTO-5,HTO-8,HTO-13
# SAM24456643_rep20-TTTGTTGTCTCGGTCT                   unknown
#
#                                                       NGS_ID  ...  \
# SAM24456643_rep17-AAACCCAAGAAGCGCT
\
# SAM24456643_rep17-AAACCCAAGAAGCGCT               0       0.000000
# SAM24456643_rep17-AAACCCAAGAGGTATT            1523       5.160962
# SAM24456643_rep17-AAACCCAAGCATGATA             735       5.020835
# SAM24456643_rep17-AAACCCAAGCGTTGTT             372       2.562336
# SAM24456643_rep17-AAACCCAAGGCACCAA             777      14.068441
# ...                                            ...            ...
# SAM24456643_rep20-TTTGTTGTCCTGTAGA             312       8.443843
# SAM24456643_rep20-TTTGTTGTCGAAGAAT             736      27.229005
# SAM24456643_rep20-TTTGTTGTCGACCAAT             342       3.292577
# SAM24456643_rep20-TTTGTTGTCGTAGCCG             587       6.918091
# SAM24456643_rep20-TTTGTTGTCTCGGTCT             558       4.225032
#
#                                     total_counts_ribo  pct_counts_ribo  \
# SAM24456643_rep17-AAACCCAAGAAGCGCT                  1        50.000000
# SAM24456643_rep17-AAACCCAAGAGGTATT               5520        18.705524
# SAM24456643_rep17-AAACCCAAGCATGATA               2399        16.387731
# SAM24456643_rep17-AAACCCAAGCGTTGTT               3064        21.104835
# SAM24456643_rep17-AAACCCAAGGCACCAA                179         3.240992
# ...                                               ...              ...
# SAM24456643_rep20-TTTGTTGTCCTGTAGA                855        23.139378
# SAM24456643_rep20-TTTGTTGTCGAAGAAT                 76         2.811691
# SAM24456643_rep20-TTTGTTGTCGACCAAT               2208        21.257341
# SAM24456643_rep20-TTTGTTGTCGTAGCCG               1774        20.907484
# SAM24456643_rep20-TTTGTTGTCTCGGTCT               2159        16.347392
#
#                                     qc_pass
# SAM24456643_rep17-AAACCCAAGAAGCGCT    False
# SAM24456643_rep17-AAACCCAAGAGGTATT     True
# SAM24456643_rep17-AAACCCAAGCATGATA     True
# SAM24456643_rep17-AAACCCAAGCGTTGTT     True
# SAM24456643_rep17-AAACCCAAGGCACCAA    False
# ...                                     ...
# SAM24456643_rep20-TTTGTTGTCCTGTAGA    False
# SAM24456643_rep20-TTTGTTGTCGAAGAAT    False
# SAM24456643_rep20-TTTGTTGTCGACCAAT    False
# SAM24456643_rep20-TTTGTTGTCGTAGCCG    False
# SAM24456643_rep20-TTTGTTGTCTCGGTCT    False
#
# [105815 rows x 23 columns]

# %% [markdown]
# ## Apply filter uisng CPU

# %%
if GPU==False:
    adata = proc.filter_adata(
    adata, 
    groupby, 
    min_cells, 
    min_genes, 
    ribo, 
    doublets=doublets, pct_mt=pct_mt)

# %%
sc.pl.scatter(RP.adata_, 'n_genes_by_counts', 'total_counts', color='pct_counts_mt')

# %%
sc.pl.scatter(RP.adata_, 'pct_counts_mt', 'pct_counts_ribo', color='n_genes_by_counts')

# %%
aggr = rnaqc.aggregation(RP.adata_, groupby,aggr, 'after')

# %%
#QC plots before and after
for k in ['n_genes_by_counts', 'total_counts', 'pct_counts_mt', 'pct_counts_ribo']:
    proc.plotQCSplit(aggr, groupby, k)

# %%
cnts_after = rnaqc.Summerize_counts(RP.adata_,groupby)

# %%
cnts_after
# Out:
#                cnt    pct
# Sample
# SAM24456643  34983  100.0

# %%
proc.aggCnts(cnts_before, cnts_after)
# Out:
#              before  after  pct left
# Sample
# SAM24456643  105815  34983      33.1

# %%
proc.plot_cell_left(cnts_before, cnts_after, groupby)

# %% [markdown]
# ## Run Normalize -> HGV -> PCA -> kNN -> Leiden -> UMAP

# %%
RP.proc(n_top_genes, norm=True, scale=True, regress=False, embedding=True, n_pcs=30, 
        n_neighbors=10, knn_n_pcs=30, batch_key=None)
# Out:
# normalizing
# Processed 0 cells..
# normalizing data.
# Completed preprocessing.
# Preprocessing took 4.1370463371276855 seconds
# selecting highly variable genes
# Filtering to highly variable genes.
# Processed 0 genes..
# Processed 1200 genes..
# Processed 2400 genes..
# Processed 3600 genes..
# Processed 4800 genes..
# Processed 6000 genes..
# Processed 7200 genes..
# Processed 8400 genes..
# Processed 9600 genes..
# Processed 10800 genes..
# Processed 12000 genes..
# Processed 13200 genes..
# Processed 14400 genes..
# Processed 15600 genes..
# Processed 16800 genes..
# Processed 18000 genes..
# Processed 19200 genes..
# Processed 20400 genes..
# Processed 21600 genes..
# Processed 22800 genes..
# Processed 24000 genes..
# Processed 25200 genes..
# Processed 26400 genes..
# Processed 27600 genes..
# Processed 28800 genes..
# Processed 30000 genes..
# Processed 31200 genes..
# Completed preprocessing.
# Converting sparse GPU array to dense GPU array.
# Preprocessing took 11.75889801979065 seconds
# scaling
# scaling took 0.8539972305297852 seconds
# computing PCA
# PCA took 0.6242654323577881 seconds
# kNN took 5.084766626358032 seconds
# computing UMAP
# WARNING: .obsp["connectivities"] have not been computed using umap
# UMAP took 0.24730682373046875 seconds
# computing Leiden clustering
# Leiden clustering took 0.10730624198913574 seconds

# %% [markdown]
# ## Batch Correction

# %%
#RP.run_scvi(counts_layer = "counts", batch_key = "DemuxAssignment_hashing")

# %%
#RP.adata.obsm["X_scVI"]

# %% [markdown]
# ## Plot PCA UMAP

# %%
if GPU:
    sc.pl.umap(RP.adata, color="leiden")

# %%
if GPU:
    sc.pl.umap(RP.adata, color=groupby)

# %%
if GPU:
    sc.pl.umap(RP.adata, color="DemuxAssignment_hashing")

# %%
#This is just to quickly check how the data looks. Cell cycle scores are added to main adata object, but normalized and processed object is not saved
if GPU==False:
    adata_tmp = adata.copy()

# %%
if GPU==False:
    adata_tmp = proc.proc(adata_tmp, 'auto', norm=True, scale=True, regress=False, embedding=True)
    sc.pl.umap(adata_tmp, color=groupby)

# %% [markdown]
# ## Add score cell cycle

# %%
if organism=='human':
    fcc =  '/gstore/data/cbfunge/data/CellCycleGenes/Homo_sapiens.csv'
elif organism == 'mouse':
    fcc = '/gstore/data/cbfunge/data/CellCycleGenes/Mus_musculus.csv'
    
if GPU:
    proc.compute_cellCycleScores(RP._adata, fcc)
else:
    proc.compute_cellCycleScores(adata_tmp, fcc)

# %%
RP._adata
# Out:
# AnnData object with n_obs × n_vars = 105815 × 36603
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'qc_pass', 'S_score', 'G2M_score', 'phase'
#     var: 'ID', 'Symbol', 'Type', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: '.internal'
#     layers: 'counts'

# %%
RP.adata
# Out:
# AnnData object with n_obs × n_vars = 34983 × 2000
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'leiden'
#     uns: 'neighbors', 'umap', 'leiden_colors', 'Sample_colors', 'DemuxAssignment_hashing_colors'
#     obsm: 'X_pca', 'X_umap'
#     obsp: 'distances', 'connectivities'

# %%
if GPU==False:
    adata.obs['phase'] = adata_tmp.obs['phase']
    adata.obs['G2M_score'] = adata_tmp.obs['G2M_score']
    adata.obs['S_score'] = adata_tmp.obs['S_score']
    adata.obs

# %%
if GPU==False:
    sc.pl.umap(adata_tmp, color='phase')

# %%
adatas
# Out:
# {'crispr': AnnData object with n_obs × n_vars = 105815 × 20345
#      uns: '.internal'
#      layers: 'counts',
#  'hashing': AnnData object with n_obs × n_vars = 105815 × 19
#      uns: '.internal'
#      layers: 'counts'}

# %%
adatas_updated = adatas.copy()
if GPU:
    adata_updated = RP._adata.copy()
else:
    adata_updated = adata.copy()

# %%
adata_updated
# Out:
# AnnData object with n_obs × n_vars = 105815 × 36603
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'qc_pass', 'S_score', 'G2M_score', 'phase'
#     var: 'ID', 'Symbol', 'Type', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: '.internal'
#     layers: 'counts'

# %%
adatas_updated
# Out:
# {'crispr': AnnData object with n_obs × n_vars = 105815 × 20345
#      uns: '.internal'
#      layers: 'counts',
#  'hashing': AnnData object with n_obs × n_vars = 105815 × 19
#      uns: '.internal'
#      layers: 'counts'}

# %% [markdown]
# ### Write h5ad version on the disk

# %%
# If you wish to write on the disk
#adata_updated.var.index.name = None
#adata_updated.write_h5ad(raw_qc)

# %% [markdown]
# ## Write h5ad file with embedings for Energy Distance analaysis

# %%
if GPU:
    RP.adata_.obsp = RP.adata.obsp.copy()
    RP.adata_.obsm = RP.adata.obsm.copy()
else:
    adata.obsp = adata_tmp.obsp.copy()
    adata.obsm = adata_tmp.obsm.copy()

# %%
if GPU:
    adata_embedding = RP.adata_.copy()
else:
    adata_embedding = adata.copy()

# %%
adata_embedding.write_h5ad(raw_embedding)

# %% [markdown]
# ## Update the dataset with new experiment "raw_qc"

# %%
if DS_test==False:
    dsid, version = DS.update_dataset(New_experiment, adata_updated, adatas_updated, test=False)
else:    
    dsid, version = DS.update_another_dataset(test_DatasetID, True, 1, New_experiment, adata_updated, adatas_updated, test=True)
# Out:
# 09:10:47 -> Collating dataset: 'DS000017726' metadata.
# 09:10:47 -> Retrieving all project: 'DS000017726@1' metadata.
#
# 09:10:47 -> Reading: 'DS000017726'.
#
# 09:10:47 -> Reading: 'DS000017726 -> Experiment: main'.
#
# 09:10:47 -> Reading: 'DS000017726 -> Experiment: main -> Alt. Exp.: crispr'.
# 09:10:47 -> Reading: 'DS000017726 -> Experiment: main -> Alt. Exp.: hashing'.
# PYDSDB:INFO: Experiment already contained metadata, overwriting.
# PYDSDB:INFO: Experiment already contained metadata, overwriting.
# PYDSDB:INFO: Experiment already contained metadata, overwriting.
# Retrieving cached token data.
# Successfully authenticated.
# 09:12:22 -> Retrieving all project: 'DS000017726@latest' metadata.
# 09:12:22 -> Collating and validating project resources.
# 09:12:23 -> Attempting upload.
#   0%|                                        | 0/73 [00:00<?, ?file/s]
#   1%|▌                                       | 1/73 [00:00<00:34,  2.08file/s]
#   4%|█▋                                      | 3/73 [00:00<00:14,  4.83file/s]
#   5%|██▏                                     | 4/73 [00:00<00:11,  5.79file/s]
#   8%|███▎                                    | 6/73 [00:00<00:08,  7.50file/s]
#  10%|███▊                                    | 7/73 [00:01<00:09,  7.10file/s]
#  12%|████▉                                   | 9/73 [00:01<00:09,  6.80file/s]
#  14%|█████▍                                  | 10/73 [00:01<00:08,  7.22file/s]
#  15%|██████                                  | 11/73 [00:01<00:12,  5.08file/s]
#  16%|██████▌                                 | 12/73 [00:02<00:11,  5.35file/s]
#  18%|███████                                 | 13/73 [00:02<00:14,  4.02file/s]
#  19%|███████▋                                | 14/73 [00:02<00:12,  4.60file/s]
#  21%|████████▏                               | 15/73 [00:02<00:11,  5.06file/s]
#  23%|█████████▎                              | 17/73 [00:03<00:08,  6.53file/s]
#  26%|██████████▍                             | 19/73 [00:03<00:07,  7.58file/s]
#  27%|██████████▉                             | 20/73 [00:03<00:06,  7.94file/s]
#  29%|███████████▌                            | 21/73 [00:03<00:06,  8.35file/s]
#  30%|████████████                            | 22/73 [00:03<00:05,  8.71file/s]
#  32%|████████████▌                           | 23/73 [00:32<06:24,  7.69s/file]
#  33%|█████████████▏                          | 24/73 [00:32<04:36,  5.64s/file]
#  36%|██████████████▏                         | 26/73 [00:32<02:30,  3.21s/file]
#  37%|██████████████▊                         | 27/73 [00:34<02:10,  2.84s/file]
#  38%|███████████████▎                        | 28/73 [00:34<01:39,  2.22s/file]
#  40%|███████████████▉                        | 29/73 [00:34<01:13,  1.67s/file]
#  42%|████████████████▉                       | 31/73 [00:35<00:46,  1.10s/file]
#  44%|█████████████████▌                      | 32/73 [00:35<00:35,  1.15file/s]
#  45%|██████████████████                      | 33/73 [00:35<00:27,  1.46file/s]
#  48%|███████████████████▏                    | 35/73 [00:35<00:16,  2.27file/s]
#  49%|███████████████████▋                    | 36/73 [00:36<00:13,  2.72file/s]
#  51%|████████████████████▎                   | 37/73 [00:36<00:11,  3.17file/s]
#  53%|█████████████████████▎                  | 39/73 [00:36<00:07,  4.37file/s]
#  55%|█████████████████████▉                  | 40/73 [00:36<00:06,  4.85file/s]
#  56%|██████████████████████▍                 | 41/73 [00:36<00:06,  5.14file/s]
#  59%|███████████████████████▌                | 43/73 [00:36<00:04,  6.14file/s]
#  62%|████████████████████████▋               | 45/73 [00:37<00:04,  6.71file/s]
#  64%|█████████████████████████▊              | 47/73 [00:37<00:03,  6.67file/s]
#  67%|██████████████████████████▊             | 49/73 [00:37<00:03,  6.86file/s]
#  70%|███████████████████████████▉            | 51/73 [00:37<00:02,  7.87file/s]
#  73%|█████████████████████████████           | 53/73 [00:38<00:03,  5.22file/s]
#  75%|██████████████████████████████▏         | 55/73 [00:39<00:04,  4.41file/s]
#  78%|███████████████████████████████▏        | 57/73 [00:40<00:06,  2.37file/s]
#  79%|███████████████████████████████▊        | 58/73 [00:41<00:05,  2.69file/s]
#  82%|████████████████████████████████▉       | 60/73 [00:41<00:03,  3.62file/s]
#  85%|█████████████████████████████████▉      | 62/73 [00:41<00:02,  4.54file/s]
#  86%|██████████████████████████████████▌     | 63/73 [00:41<00:02,  4.96file/s]
#  89%|███████████████████████████████████▌    | 65/73 [00:41<00:01,  6.20file/s]
#  90%|████████████████████████████████████▏   | 66/73 [00:42<00:01,  5.79file/s]
#  92%|████████████████████████████████████▋   | 67/73 [00:42<00:01,  5.46file/s]
#  95%|█████████████████████████████████████▊  | 69/73 [00:42<00:00,  7.26file/s]
#  96%|██████████████████████████████████████▎ | 70/73 [00:42<00:00,  7.10file/s]
#  97%|██████████████████████████████████████▉ | 71/73 [00:42<00:00,  7.13file/s]
#  99%|███████████████████████████████████████▍| 72/73 [00:43<00:00,  2.37file/s]
# 100%|████████████████████████████████████████| 73/73 [00:44<00:00,  2.91file/s]
# 100%|████████████████████████████████████████| 73/73 [00:44<00:00,  1.66file/s]
# Clearing upload info.
# 09:13:23 -> Upload completed.
# Processing...
# Processing...
# Processing...
# Upload successful, your DSID is 'DS000017726' and version is: '5'. Also written to 'upload_info.json' in staging dir.

# %%
dsid, version
# Out:
# ('DS000017726', '5')
