# %%
# Parameters
DatasetID = "DS000017732"
DEV = False
test_DatasetID = ""
DS_test = False
title = "Recursion DLD1 Library3- Screen2 (NGS5888)"
description = "Production scale screen in DLD-1 cells with 1/4 of the genome-wide CRISPR library (sub-lib-3, ~22K guides). 1 time point: Day-5. We performed 24 rxns of 10x 3' HT kit with an estimated loading of 52K cells. We performed a pilot study to test the library quality before the production-level sequencing. We will submit 72 libraries (24 GEX, 24 HTO and 24 sgRNA) We request 600M reads for GEX, 20M for HTO and 40M for sgRNA, after finishing QC sequencing of NGS5887. NGS has built the GEX and sgRNA libraries using automation, we will provide manually constructed HTO libraries."
name_space = [{"id": "GRCh38", "type": "genome"}]
sources = [{"id": "Siavash-1234", "name": "Geo-ID"}]
tech_name = "scRNA-seq"
author = "SG"
alt_experiments = ["crispr", "hashing"]
organism = "human"
groupby = "Sample"
min_cells = 3
min_genes = 500
max_genes = None
pct_mt = None
total_counts = None
n_top_genes = 2000
ribo = True
doublets = True
Mapping_rate = {"LIB6238857_SAM24456643": "Total number of reads: 73010043\nNumber of reads with valid cell barcodes: 71052354 (97.32%)\nNumber of reads with valid feature barcodes: 62539674 (85.66%)\nNumber of reads with valid cell and feature barcodes: 61120352 (83.71%)\n\nSection LIB6238857_SAM24456643.crispr\nNumber of valid cell barcodes: 148178\nNumber of valid reads (with matching cell and feature barcodes): 61120352\nMean number of valid reads per cell barcode: 412.48\nNumber of valid UMIs (with matching cell and feature barcodes): 2170151\nMean number of valid UMIs per cell barcode: 14.65\nSequencing saturation: 96.45%\n", "LIB6238833_SAM24456643": "Total number of reads: 22161355\nNumber of reads with valid cell barcodes: 21285172 (96.05%)\nNumber of reads with valid feature barcodes: 20500348 (92.50%)\nNumber of reads with valid cell and feature barcodes: 20057042 (90.50%)\n\nSection LIB6238833_SAM24456643.hashing\nNumber of valid cell barcodes: 690124\nNumber of valid reads (with matching cell and feature barcodes): 20057042\nMean number of valid reads per cell barcode: 29.06\nNumber of valid UMIs (with matching cell and feature barcodes): 17219293\nMean number of valid UMIs per cell barcode: 24.95\nSequencing saturation: 14.15%\n", "LIB6238856_SAM24456643": "Total number of reads: 87003824\nNumber of reads with valid cell barcodes: 84700894 (97.35%)\nNumber of reads with valid feature barcodes: 74313024 (85.41%)\nNumber of reads with valid cell and feature barcodes: 72654306 (83.51%)\n\nSection LIB6238856_SAM24456643.crispr\nNumber of valid cell barcodes: 173860\nNumber of valid reads (with matching cell and feature barcodes): 72654306\nMean number of valid reads per cell barcode: 417.89\nNumber of valid UMIs (with matching cell and feature barcodes): 2388402\nMean number of valid UMIs per cell barcode: 13.74\nSequencing saturation: 96.71%\n", "LIB6238832_SAM24456643": "Total number of reads: 29712851\nNumber of reads with valid cell barcodes: 28536683 (96.04%)\nNumber of reads with valid feature barcodes: 27459380 (92.42%)\nNumber of reads with valid cell and feature barcodes: 26879573 (90.46%)\n\nSection LIB6238832_SAM24456643.hashing\nNumber of valid cell barcodes: 1001658\nNumber of valid reads (with matching cell and feature barcodes): 26879573\nMean number of valid reads per cell barcode: 26.84\nNumber of valid UMIs (with matching cell and feature barcodes): 22346806\nMean number of valid UMIs per cell barcode: 22.31\nSequencing saturation: 16.86%\n", "LIB6238855_SAM24456643": "Total number of reads: 85247751\nNumber of reads with valid cell barcodes: 83019642 (97.39%)\nNumber of reads with valid feature barcodes: 72943441 (85.57%)\nNumber of reads with valid cell and feature barcodes: 71309373 (83.65%)\n\nSection LIB6238855_SAM24456643.crispr\nNumber of valid cell barcodes: 171123\nNumber of valid reads (with matching cell and feature barcodes): 71309373\nMean number of valid reads per cell barcode: 416.71\nNumber of valid UMIs (with matching cell and feature barcodes): 2450333\nMean number of valid UMIs per cell barcode: 14.32\nSequencing saturation: 96.56%\n", "LIB6238831_SAM24456643": "Total number of reads: 30531261\nNumber of reads with valid cell barcodes: 29422379 (96.37%)\nNumber of reads with valid feature barcodes: 28537346 (93.47%)\nNumber of reads with valid cell and feature barcodes: 27866099 (91.27%)\n\nSection LIB6238831_SAM24456643.hashing\nNumber of valid cell barcodes: 926913\nNumber of valid reads (with matching cell and feature barcodes): 27866099\nMean number of valid reads per cell barcode: 30.06\nNumber of valid UMIs (with matching cell and feature barcodes): 23606242\nMean number of valid UMIs per cell barcode: 25.47\nSequencing saturation: 15.29%\n", "LIB6238854_SAM24456643": "Total number of reads: 81093630\nNumber of reads with valid cell barcodes: 78927991 (97.33%)\nNumber of reads with valid feature barcodes: 69583540 (85.81%)\nNumber of reads with valid cell and feature barcodes: 67990768 (83.84%)\n\nSection LIB6238854_SAM24456643.crispr\nNumber of valid cell barcodes: 171344\nNumber of valid reads (with matching cell and feature barcodes): 67990768\nMean number of valid reads per cell barcode: 396.81\nNumber of valid UMIs (with matching cell and feature barcodes): 2354728\nMean number of valid UMIs per cell barcode: 13.74\nSequencing saturation: 96.54%\n", "LIB6238830_SAM24456643": "Total number of reads: 20501848\nNumber of reads with valid cell barcodes: 19499116 (95.11%)\nNumber of reads with valid feature barcodes: 18680885 (91.12%)\nNumber of reads with valid cell and feature barcodes: 18254762 (89.04%)\n\nSection LIB6238830_SAM24456643.hashing\nNumber of valid cell barcodes: 713674\nNumber of valid reads (with matching cell and feature barcodes): 18254762\nMean number of valid reads per cell barcode: 25.58\nNumber of valid UMIs (with matching cell and feature barcodes): 15479358\nMean number of valid UMIs per cell barcode: 21.69\nSequencing saturation: 15.20%\n"}
raw_qc = "/gstore/scratch/u/ghaffars/Dataset/crc_NGS5888//DS000017732/raw_qc.h5ad"
raw_embedding = "/gstore/scratch/u/ghaffars/Dataset/crc_NGS5888//DS000017732/qc_embedding.h5ad"

# %% [markdown]
#  # QC analysis of single cell RNA-seq dataset: This notebook will guide you through the process of quality control analyis on a single-cell RNA sequencing dataset

# %%
# Different scenario for original dataset or test dataset
try:
    if DS_test==True:
        DSID = test_DatasetID
        Version = '2'   # the version of your dataset
        DEV = True
    elif len(alt_experiments)==2:
        DSID = DatasetID
        Version = '4'   # the version of your dataset
        your_experiment = "crispr_hashing_harmonized" # A string that is a key known for our desired experimnet that you wish to work on
    else:
        DSID = DatasetID
        Version = '2'   # the version of your dataset
        your_experiment = "main" # A string that is a key known for our desired experimnet that you wish to work on

except TypeError:
    DSID = DatasetID
    Version = '1'   # the version of your dataset
    your_experiment = "raw_qc" # A string that is a key known for our desired experimnet that you wish to work on

New_experiment = "raw_qc" # A string that is a key known for the updated data saved by that that name

# %%
## Import Libraries
from __future__ import division
import pandas as pd

#single cell libraries
import scanpy as sc

#general
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

#plotting
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('talk')

# %%
import sys
sys.path.append("..")
import Templates.tools.DatasetDB as DB
import Templates.tools.RNA_Seq_QC as rnaqc
import Templates.tools.scProc as proc
try:
    import Templates.tools.rapids_modified as rp
except ImportError:
        pass

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Check if GPU device is available

# %%
GPU = rnaqc.pipeline_has_gpu()

# %%
GPU
# Out:
# True

# %% [markdown]
# ## Instantiate a dataset object given our dataset info

# %%
DS = DB.DATASET(DSID, DEV, title=title, description=description, name_space=name_space, organism=organism,
                       sources=sources, tech_name=tech_name, author=author)

# %%
adata, adatas = DS.load_dataset(Version, your_experiment, Corr=False)
# Out:
# 08:34:19 -> Collating dataset: 'DS000017732' metadata.
# 08:34:19 -> Retrieving all project: 'DS000017732@4' metadata.
# 08:34:20 -> Reading: 'DS000017732'.
#
# 08:34:20 -> Reading: 'DS000017732 -> Experiment: main'.
#
# 08:34:20 -> Reading: 'DS000017732 -> Experiment: main -> Alt. Exp.: crispr'.
# 08:34:20 -> Reading: 'DS000017732 -> Experiment: main -> Alt. Exp.: hashing'.
# 08:34:23 -> Reading: 'DS000017732 -> Experiment: crispr_hashing_harmonized'.
#
# 08:34:23 -> Reading: 'DS000017732 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: crispr'.
# 08:34:23 -> Reading: 'DS000017732 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: hashing'.

# %%
adata = rnaqc.load_data(adata,  alt_experiments)

# %%
adata.obs.head()
# Out:
#                                         Sample           Barcode  \
# SAM24456643_rep1-AAACCCAAGACGTCGA  SAM24456643  AAACCCAAGACGTCGA
# SAM24456643_rep1-AAACCCAAGATGATTG  SAM24456643  AAACCCAAGATGATTG
# SAM24456643_rep1-AAACCCAAGGATTCAA  SAM24456643  AAACCCAAGGATTCAA
# SAM24456643_rep1-AAACCCAAGGGCCCTT  SAM24456643  AAACCCAAGGGCCCTT
# SAM24456643_rep1-AAACCCAAGTCGGCCT  SAM24456643  AAACCCAAGTCGGCCT
#
#                                   DemuxType_crispr  \
# SAM24456643_rep1-AAACCCAAGACGTCGA          doublet
# SAM24456643_rep1-AAACCCAAGATGATTG          singlet
# SAM24456643_rep1-AAACCCAAGGATTCAA          singlet
# SAM24456643_rep1-AAACCCAAGGGCCCTT          singlet
# SAM24456643_rep1-AAACCCAAGTCGGCCT          doublet
#
#                                                 DemuxAssignment_crispr  \
# SAM24456643_rep1-AAACCCAAGACGTCGA  ENSG00000101890_3,ENSG00000174667_2
# SAM24456643_rep1-AAACCCAAGATGATTG                    ENSG00000139629_2
# SAM24456643_rep1-AAACCCAAGGATTCAA                    ENSG00000163568_4
# SAM24456643_rep1-AAACCCAAGGGCCCTT                    ENSG00000177463_4
# SAM24456643_rep1-AAACCCAAGTCGGCCT           ENSG00000126231_3,NTC_1225
#
#                                   DemuxType_hashing DemuxAssignment_hashing  \
# SAM24456643_rep1-AAACCCAAGACGTCGA           unknown                 unknown
# SAM24456643_rep1-AAACCCAAGATGATTG           singlet             SAM24439043
# SAM24456643_rep1-AAACCCAAGGATTCAA           singlet             SAM24439044
# SAM24456643_rep1-AAACCCAAGGGCCCTT           unknown                 unknown
# SAM24456643_rep1-AAACCCAAGTCGGCCT           doublet           HTO-15,HTO-12
#
#                                         cellline      timepoint  \
# SAM24456643_rep1-AAACCCAAGACGTCGA        unknown        unknown
# SAM24456643_rep1-AAACCCAAGATGATTG           DLD1           day5
# SAM24456643_rep1-AAACCCAAGGATTCAA           DLD1           day5
# SAM24456643_rep1-AAACCCAAGGGCCCTT        unknown        unknown
# SAM24456643_rep1-AAACCCAAGTCGGCCT  HTO-15,HTO-12  HTO-15,HTO-12
#
#                                              HTO         NGS_ID  \
# SAM24456643_rep1-AAACCCAAGACGTCGA        unknown        unknown
# SAM24456643_rep1-AAACCCAAGATGATTG          HTO-1        NGS5888
# SAM24456643_rep1-AAACCCAAGGATTCAA          HTO-6        NGS5888
# SAM24456643_rep1-AAACCCAAGGGCCCTT        unknown        unknown
# SAM24456643_rep1-AAACCCAAGTCGGCCT  HTO-15,HTO-12  HTO-15,HTO-12
#
#                                   Biological_replicate 10Xrun  \
# SAM24456643_rep1-AAACCCAAGACGTCGA              unknown      1
# SAM24456643_rep1-AAACCCAAGATGATTG          SAM24439043      1
# SAM24456643_rep1-AAACCCAAGGATTCAA          SAM24439044      1
# SAM24456643_rep1-AAACCCAAGGGCCCTT              unknown      1
# SAM24456643_rep1-AAACCCAAGTCGGCCT        HTO-15,HTO-12      1
#
#                                                                           sublibrary  \
# SAM24456643_rep1-AAACCCAAGACGTCGA                                            unknown
# SAM24456643_rep1-AAACCCAAGATGATTG  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
# SAM24456643_rep1-AAACCCAAGGATTCAA  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
# SAM24456643_rep1-AAACCCAAGGGCCCTT                                            unknown
# SAM24456643_rep1-AAACCCAAGTCGGCCT                                      HTO-15,HTO-12
#
#                                   gRNA_library_MOI  \
# SAM24456643_rep1-AAACCCAAGACGTCGA          unknown
# SAM24456643_rep1-AAACCCAAGATGATTG              0.5
# SAM24456643_rep1-AAACCCAAGGATTCAA              0.5
# SAM24456643_rep1-AAACCCAAGGGCCCTT          unknown
# SAM24456643_rep1-AAACCCAAGTCGGCCT    HTO-15,HTO-12
#
#                                                            gene_symbol  \
# SAM24456643_rep1-AAACCCAAGACGTCGA  ENSG00000101890_3,ENSG00000174667_2
# SAM24456643_rep1-AAACCCAAGATGATTG                               GALNT6
# SAM24456643_rep1-AAACCCAAGGATTCAA                                 AIM2
# SAM24456643_rep1-AAACCCAAGGGCCCTT                                NR2C2
# SAM24456643_rep1-AAACCCAAGTCGGCCT           ENSG00000126231_3,NTC_1225
#
#                                                                  class
# SAM24456643_rep1-AAACCCAAGACGTCGA  ENSG00000101890_3,ENSG00000174667_2
# SAM24456643_rep1-AAACCCAAGATGATTG                               target
# SAM24456643_rep1-AAACCCAAGGATTCAA                               target
# SAM24456643_rep1-AAACCCAAGGGCCCTT                               target
# SAM24456643_rep1-AAACCCAAGTCGGCCT           ENSG00000126231_3,NTC_1225

# %%
adata.var.head()
# Out:
#                                         ID                     Symbol  \
# Symbol
# 3xLinker                 3xLinker_3xLinker          3xLinker_3xLinker
# MIR1302-2HG  GRCh38-2020-A_ENSG00000243485  GRCh38-2020-A_MIR1302-2HG
# FAM138A      GRCh38-2020-A_ENSG00000237613      GRCh38-2020-A_FAM138A
# OR4F5        GRCh38-2020-A_ENSG00000186092        GRCh38-2020-A_OR4F5
# AL627309.1   GRCh38-2020-A_ENSG00000238009   GRCh38-2020-A_AL627309.1
#
#                         Type
# Symbol
# 3xLinker     Gene Expression
# MIR1302-2HG  Gene Expression
# FAM138A      Gene Expression
# OR4F5        Gene Expression
# AL627309.1   Gene Expression

# %% [markdown]
# ## Mapping Rate information

# %%
combined_df,agg,agg_percentage = rnaqc.Mapping_reads_info(Mapping_rate)

# %%
combined_df
# Out:
#                        Total number of reads  \
# LIB6238857_SAM24456643              73010043
# LIB6238833_SAM24456643              22161355
# LIB6238856_SAM24456643              87003824
# LIB6238832_SAM24456643              29712851
# LIB6238855_SAM24456643              85247751
# LIB6238831_SAM24456643              30531261
# LIB6238854_SAM24456643              81093630
# LIB6238830_SAM24456643              20501848
#
#                        Number of reads with valid cell barcodes  \
# LIB6238857_SAM24456643                        71052354 (97.32%)
# LIB6238833_SAM24456643                        21285172 (96.05%)
# LIB6238856_SAM24456643                        84700894 (97.35%)
# LIB6238832_SAM24456643                        28536683 (96.04%)
# LIB6238855_SAM24456643                        83019642 (97.39%)
# LIB6238831_SAM24456643                        29422379 (96.37%)
# LIB6238854_SAM24456643                        78927991 (97.33%)
# LIB6238830_SAM24456643                        19499116 (95.11%)
#
#                        Number of reads with valid feature barcodes  \
# LIB6238857_SAM24456643                           62539674 (85.66%)
# LIB6238833_SAM24456643                           20500348 (92.50%)
# LIB6238856_SAM24456643                           74313024 (85.41%)
# LIB6238832_SAM24456643                           27459380 (92.42%)
# LIB6238855_SAM24456643                           72943441 (85.57%)
# LIB6238831_SAM24456643                           28537346 (93.47%)
# LIB6238854_SAM24456643                           69583540 (85.81%)
# LIB6238830_SAM24456643                           18680885 (91.12%)
#
#                        Number of reads with valid cell and feature barcodes  \
# LIB6238857_SAM24456643                                  61120352 (83.71%)
# LIB6238833_SAM24456643                                  20057042 (90.50%)
# LIB6238856_SAM24456643                                  72654306 (83.51%)
# LIB6238832_SAM24456643                                  26879573 (90.46%)
# LIB6238855_SAM24456643                                  71309373 (83.65%)
# LIB6238831_SAM24456643                                  27866099 (91.27%)
# LIB6238854_SAM24456643                                  67990768 (83.84%)
# LIB6238830_SAM24456643                                  18254762 (89.04%)
#
#                        Number of valid cell barcodes  \
# LIB6238857_SAM24456643                        148178
# LIB6238833_SAM24456643                        690124
# LIB6238856_SAM24456643                        173860
# LIB6238832_SAM24456643                       1001658
# LIB6238855_SAM24456643                        171123
# LIB6238831_SAM24456643                        926913
# LIB6238854_SAM24456643                        171344
# LIB6238830_SAM24456643                        713674
#
#                        Number of valid reads (with matching cell and feature barcodes)  \
# LIB6238857_SAM24456643                                           61120352
# LIB6238833_SAM24456643                                           20057042
# LIB6238856_SAM24456643                                           72654306
# LIB6238832_SAM24456643                                           26879573
# LIB6238855_SAM24456643                                           71309373
# LIB6238831_SAM24456643                                           27866099
# LIB6238854_SAM24456643                                           67990768
# LIB6238830_SAM24456643                                           18254762
#
#                        Mean number of valid reads per cell barcode  \
# LIB6238857_SAM24456643                                      412.48
# LIB6238833_SAM24456643                                       29.06
# LIB6238856_SAM24456643                                      417.89
# LIB6238832_SAM24456643                                       26.84
# LIB6238855_SAM24456643                                      416.71
# LIB6238831_SAM24456643                                       30.06
# LIB6238854_SAM24456643                                      396.81
# LIB6238830_SAM24456643                                       25.58
#
#                        Number of valid UMIs (with matching cell and feature barcodes)  \
# LIB6238857_SAM24456643                                            2170151
# LIB6238833_SAM24456643                                           17219293
# LIB6238856_SAM24456643                                            2388402
# LIB6238832_SAM24456643                                           22346806
# LIB6238855_SAM24456643                                            2450333
# LIB6238831_SAM24456643                                           23606242
# LIB6238854_SAM24456643                                            2354728
# LIB6238830_SAM24456643                                           15479358
#
#                        Mean number of valid UMIs per cell barcode  \
# LIB6238857_SAM24456643                                      14.65
# LIB6238833_SAM24456643                                      24.95
# LIB6238856_SAM24456643                                      13.74
# LIB6238832_SAM24456643                                      22.31
# LIB6238855_SAM24456643                                      14.32
# LIB6238831_SAM24456643                                      25.47
# LIB6238854_SAM24456643                                      13.74
# LIB6238830_SAM24456643                                      21.69
#
#                        Sequencing saturation Experiment
# LIB6238857_SAM24456643                96.45%     crispr
# LIB6238833_SAM24456643                14.15%    hashing
# LIB6238856_SAM24456643                96.71%     crispr
# LIB6238832_SAM24456643                16.86%    hashing
# LIB6238855_SAM24456643                96.56%     crispr
# LIB6238831_SAM24456643                15.29%    hashing
# LIB6238854_SAM24456643                96.54%     crispr
# LIB6238830_SAM24456643                15.20%    hashing

# %%
#Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
agg.plot(kind='barh', ax=ax1, stacked=False, color=['midnightblue', 'blue', 'deepskyblue'], legend=False)
ax1.set_xlabel('Read Count')
agg_percentage.plot(kind='barh', ax=ax2, stacked=False, color=['midnightblue', 'blue', 'deepskyblue'])
ax2.set_xlabel('%Read Count')
ax2.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.suptitle('Mapping Rate', fontsize=25)
plt.show()

# %% [markdown]
# ## Doublet information

# %%
rnaqc.doublet_counter(adata)
# Out:
#                                                     Cell counts
# total Cells                                              108556
# cells after keeping singlets by hashing                   87711
# cells after keeping singlets by gRNA                      49116
# cells after keeping singlets by both hashing an...        43703

# %% [markdown]
# ### Sumarize counts

# %%
cnts_before = rnaqc.Summerize_counts(adata, groupby)

# %%
cnts_before
# Out:
#                 cnt    pct
# Sample
# SAM24456643  108556  100.0

# %% [markdown]
# ### calculate qc metrics

# %%
adata = proc.calc_qc_metrics(adata, organism)

# %%
LOWER,UPPER = rnaqc.upper_lower_limits(adata, groupby)

# %%
LOWER
# Out:
#              n_genes_by_counts  total_counts  pct_counts_mt  pct_counts_ribo
# SAM24456643              -24.5       -8280.0      -0.446466         4.926123

# %%
UPPER
# Out:
#              n_genes_by_counts  total_counts  pct_counts_mt  pct_counts_ribo
# SAM24456643             8667.5       34192.0      10.955006        27.236081

# %%
sc.pl.scatter(adata, 'n_genes_by_counts', 'total_counts', color='pct_counts_mt')

# %%
sc.pl.scatter(adata, 'pct_counts_mt', 'pct_counts_ribo', color='n_genes_by_counts')

# %%
sc.pl.violin(
    adata, 
    [
     'n_genes_by_counts', 
     'total_counts', 
     'pct_counts_mt'
     ],
    multi_panel=True
)

# %%
aggr = rnaqc.aggregation(adata, groupby, None, 'before')

# %%
adata.obs.head()
# Out:
#                                         Sample           Barcode  \
# SAM24456643_rep1-AAACCCAAGACGTCGA  SAM24456643  AAACCCAAGACGTCGA
# SAM24456643_rep1-AAACCCAAGATGATTG  SAM24456643  AAACCCAAGATGATTG
# SAM24456643_rep1-AAACCCAAGGATTCAA  SAM24456643  AAACCCAAGGATTCAA
# SAM24456643_rep1-AAACCCAAGGGCCCTT  SAM24456643  AAACCCAAGGGCCCTT
# SAM24456643_rep1-AAACCCAAGTCGGCCT  SAM24456643  AAACCCAAGTCGGCCT
#
#                                   DemuxType_crispr  \
# SAM24456643_rep1-AAACCCAAGACGTCGA          doublet
# SAM24456643_rep1-AAACCCAAGATGATTG          singlet
# SAM24456643_rep1-AAACCCAAGGATTCAA          singlet
# SAM24456643_rep1-AAACCCAAGGGCCCTT          singlet
# SAM24456643_rep1-AAACCCAAGTCGGCCT          doublet
#
#                                                 DemuxAssignment_crispr  \
# SAM24456643_rep1-AAACCCAAGACGTCGA  ENSG00000101890_3,ENSG00000174667_2
# SAM24456643_rep1-AAACCCAAGATGATTG                    ENSG00000139629_2
# SAM24456643_rep1-AAACCCAAGGATTCAA                    ENSG00000163568_4
# SAM24456643_rep1-AAACCCAAGGGCCCTT                    ENSG00000177463_4
# SAM24456643_rep1-AAACCCAAGTCGGCCT           ENSG00000126231_3,NTC_1225
#
#                                   DemuxType_hashing DemuxAssignment_hashing  \
# SAM24456643_rep1-AAACCCAAGACGTCGA           unknown                 unknown
# SAM24456643_rep1-AAACCCAAGATGATTG           singlet             SAM24439043
# SAM24456643_rep1-AAACCCAAGGATTCAA           singlet             SAM24439044
# SAM24456643_rep1-AAACCCAAGGGCCCTT           unknown                 unknown
# SAM24456643_rep1-AAACCCAAGTCGGCCT           doublet           HTO-15,HTO-12
#
#                                         cellline      timepoint  \
# SAM24456643_rep1-AAACCCAAGACGTCGA        unknown        unknown
# SAM24456643_rep1-AAACCCAAGATGATTG           DLD1           day5
# SAM24456643_rep1-AAACCCAAGGATTCAA           DLD1           day5
# SAM24456643_rep1-AAACCCAAGGGCCCTT        unknown        unknown
# SAM24456643_rep1-AAACCCAAGTCGGCCT  HTO-15,HTO-12  HTO-15,HTO-12
#
#                                              HTO         NGS_ID  ...  \
# SAM24456643_rep1-AAACCCAAGACGTCGA        unknown        unknown  ...
# SAM24456643_rep1-AAACCCAAGATGATTG          HTO-1        NGS5888  ...
# SAM24456643_rep1-AAACCCAAGGATTCAA          HTO-6        NGS5888  ...
# SAM24456643_rep1-AAACCCAAGGGCCCTT        unknown        unknown  ...
# SAM24456643_rep1-AAACCCAAGTCGGCCT  HTO-15,HTO-12  HTO-15,HTO-12  ...
#
#                                                                           sublibrary  \
# SAM24456643_rep1-AAACCCAAGACGTCGA                                            unknown
# SAM24456643_rep1-AAACCCAAGATGATTG  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
# SAM24456643_rep1-AAACCCAAGGATTCAA  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
# SAM24456643_rep1-AAACCCAAGGGCCCTT                                            unknown
# SAM24456643_rep1-AAACCCAAGTCGGCCT                                      HTO-15,HTO-12
#
#                                   gRNA_library_MOI  \
# SAM24456643_rep1-AAACCCAAGACGTCGA          unknown
# SAM24456643_rep1-AAACCCAAGATGATTG              0.5
# SAM24456643_rep1-AAACCCAAGGATTCAA              0.5
# SAM24456643_rep1-AAACCCAAGGGCCCTT          unknown
# SAM24456643_rep1-AAACCCAAGTCGGCCT    HTO-15,HTO-12
#
#                                                            gene_symbol  \
# SAM24456643_rep1-AAACCCAAGACGTCGA  ENSG00000101890_3,ENSG00000174667_2
# SAM24456643_rep1-AAACCCAAGATGATTG                               GALNT6
# SAM24456643_rep1-AAACCCAAGGATTCAA                                 AIM2
# SAM24456643_rep1-AAACCCAAGGGCCCTT                                NR2C2
# SAM24456643_rep1-AAACCCAAGTCGGCCT           ENSG00000126231_3,NTC_1225
#
#                                                                  class  \
# SAM24456643_rep1-AAACCCAAGACGTCGA  ENSG00000101890_3,ENSG00000174667_2
# SAM24456643_rep1-AAACCCAAGATGATTG                               target
# SAM24456643_rep1-AAACCCAAGGATTCAA                               target
# SAM24456643_rep1-AAACCCAAGGGCCCTT                               target
# SAM24456643_rep1-AAACCCAAGTCGGCCT           ENSG00000126231_3,NTC_1225
#
#                                   n_genes_by_counts total_counts  \
# SAM24456643_rep1-AAACCCAAGACGTCGA              5002        17742
# SAM24456643_rep1-AAACCCAAGATGATTG              5611        21041
# SAM24456643_rep1-AAACCCAAGGATTCAA              4570        12919
# SAM24456643_rep1-AAACCCAAGGGCCCTT              5359        18541
# SAM24456643_rep1-AAACCCAAGTCGGCCT              7894        39997
#
#                                    total_counts_mt  pct_counts_mt  \
# SAM24456643_rep1-AAACCCAAGACGTCGA              940       5.298163
# SAM24456643_rep1-AAACCCAAGATGATTG             1180       5.608098
# SAM24456643_rep1-AAACCCAAGGATTCAA              790       6.115024
# SAM24456643_rep1-AAACCCAAGGGCCCTT              877       4.730058
# SAM24456643_rep1-AAACCCAAGTCGGCCT             1577       3.942796
#
#                                    total_counts_ribo  pct_counts_ribo
# SAM24456643_rep1-AAACCCAAGACGTCGA               3386        19.084658
# SAM24456643_rep1-AAACCCAAGATGATTG               4148        19.713892
# SAM24456643_rep1-AAACCCAAGGATTCAA               2103        16.278350
# SAM24456643_rep1-AAACCCAAGGGCCCTT               3312        17.863114
# SAM24456643_rep1-AAACCCAAGTCGGCCT               6486        16.216216
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Instantiate a RapidsSingleCellPipeline object given our AnnData to prepare RAPIDS environment for other steps

# %%
RP = rp.RapidsSingleCellPipeline(adata)

# %% [markdown]
# ## Notice:
# - **RP._adata is adata before filtering**
# - **RP.adata_ is adata after filtering**
# - **Rp.adata is adata after normalization (and highly variable genes selected)**

# %%
max_cells = None
cell_batch_size = 100000
gene_batch_size = 1200
target_sum = 1e4
n_top_genes = 2000
counts_layer = "counts"
batch_key = "DemuxAssignment_hashing"

# %% [markdown]
# ## Apply filter using GPU

# %%
if GPU:
    RP.filter_data(
    groupby,
    min_genes=min_genes,
    max_genes=max_genes,
    max_cells=max_cells,
    cell_batch_size=cell_batch_size,
    min_cells=min_cells,
    gene_batch_size=gene_batch_size,
        ribo=ribo, 
        doublets=doublets,
        pct_mt=pct_mt, 
        total_counts=total_counts
)
# Out:
# starting with 108556 cells
# Filtering cells.
# Processed 0 cells..
# Processed 100000 cells..
# Filtering genes.
# Completed preprocessing.
# Calculating upper outliers
# Now 101210 cells after filtering max genes
# Calculating upper outliers
# Now 85531 cells after filtering pct mt
# Calculating upper outliers
# Now 82694 cells after filtering total counts
# Now 80661 cells after filtering pct ribo
# Now 68390 cells after keeping singlets by hashing
# Now 42401 cells after keeping singlets by gRNA
# Preprocessing took 81.04082822799683 seconds

# %%
RP._adata
# Out:
# AnnData object with n_obs × n_vars = 108556 × 36603
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo'
#     var: 'ID', 'Symbol', 'Type', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: '.internal'
#     layers: 'counts'

# %%
RP.adata_
# Out:
# View of AnnData object with n_obs × n_vars = 42401 × 32267
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo'
#     var: 'ID', 'Symbol', 'Type', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     layers: 'counts'

# %%
RP._adata.obs["qc_pass"] = RP._adata.obs.index.isin(RP.adata_.obs.index)

# %%
RP._adata.obs
# Out:
#                                         Sample           Barcode  \
# SAM24456643_rep1-AAACCCAAGACGTCGA  SAM24456643  AAACCCAAGACGTCGA
# SAM24456643_rep1-AAACCCAAGATGATTG  SAM24456643  AAACCCAAGATGATTG
# SAM24456643_rep1-AAACCCAAGGATTCAA  SAM24456643  AAACCCAAGGATTCAA
# SAM24456643_rep1-AAACCCAAGGGCCCTT  SAM24456643  AAACCCAAGGGCCCTT
# SAM24456643_rep1-AAACCCAAGTCGGCCT  SAM24456643  AAACCCAAGTCGGCCT
# ...                                        ...               ...
# SAM24456643_rep4-TTTGTTGTCGTAGCCG  SAM24456643  TTTGTTGTCGTAGCCG
# SAM24456643_rep4-TTTGTTGTCGTTCCTG  SAM24456643  TTTGTTGTCGTTCCTG
# SAM24456643_rep4-TTTGTTGTCTCCCATG  SAM24456643  TTTGTTGTCTCCCATG
# SAM24456643_rep4-TTTGTTGTCTGCATAG  SAM24456643  TTTGTTGTCTGCATAG
# SAM24456643_rep4-TTTGTTGTCTTACCAT  SAM24456643  TTTGTTGTCTTACCAT
#
#                                   DemuxType_crispr  \
# SAM24456643_rep1-AAACCCAAGACGTCGA          doublet
# SAM24456643_rep1-AAACCCAAGATGATTG          singlet
# SAM24456643_rep1-AAACCCAAGGATTCAA          singlet
# SAM24456643_rep1-AAACCCAAGGGCCCTT          singlet
# SAM24456643_rep1-AAACCCAAGTCGGCCT          doublet
# ...                                            ...
# SAM24456643_rep4-TTTGTTGTCGTAGCCG          singlet
# SAM24456643_rep4-TTTGTTGTCGTTCCTG          unknown
# SAM24456643_rep4-TTTGTTGTCTCCCATG          doublet
# SAM24456643_rep4-TTTGTTGTCTGCATAG          singlet
# SAM24456643_rep4-TTTGTTGTCTTACCAT          unknown
#
#                                                 DemuxAssignment_crispr  \
# SAM24456643_rep1-AAACCCAAGACGTCGA  ENSG00000101890_3,ENSG00000174667_2
# SAM24456643_rep1-AAACCCAAGATGATTG                    ENSG00000139629_2
# SAM24456643_rep1-AAACCCAAGGATTCAA                    ENSG00000163568_4
# SAM24456643_rep1-AAACCCAAGGGCCCTT                    ENSG00000177463_4
# SAM24456643_rep1-AAACCCAAGTCGGCCT           ENSG00000126231_3,NTC_1225
# ...                                                                ...
# SAM24456643_rep4-TTTGTTGTCGTAGCCG                    ENSG00000133318_4
# SAM24456643_rep4-TTTGTTGTCGTTCCTG                              unknown
# SAM24456643_rep4-TTTGTTGTCTCCCATG  ENSG00000186334_2,ENSG00000163661_2
# SAM24456643_rep4-TTTGTTGTCTGCATAG                    ENSG00000121774_4
# SAM24456643_rep4-TTTGTTGTCTTACCAT                              unknown
#
#                                   DemuxType_hashing DemuxAssignment_hashing  \
# SAM24456643_rep1-AAACCCAAGACGTCGA           unknown                 unknown
# SAM24456643_rep1-AAACCCAAGATGATTG           singlet             SAM24439043
# SAM24456643_rep1-AAACCCAAGGATTCAA           singlet             SAM24439044
# SAM24456643_rep1-AAACCCAAGGGCCCTT           unknown                 unknown
# SAM24456643_rep1-AAACCCAAGTCGGCCT           doublet           HTO-15,HTO-12
# ...                                             ...                     ...
# SAM24456643_rep4-TTTGTTGTCGTAGCCG           singlet             SAM24439043
# SAM24456643_rep4-TTTGTTGTCGTTCCTG           singlet             SAM24439044
# SAM24456643_rep4-TTTGTTGTCTCCCATG           singlet             SAM24439044
# SAM24456643_rep4-TTTGTTGTCTGCATAG           singlet             SAM24439045
# SAM24456643_rep4-TTTGTTGTCTTACCAT           singlet             SAM24439044
#
#                                         cellline      timepoint  \
# SAM24456643_rep1-AAACCCAAGACGTCGA        unknown        unknown
# SAM24456643_rep1-AAACCCAAGATGATTG           DLD1           day5
# SAM24456643_rep1-AAACCCAAGGATTCAA           DLD1           day5
# SAM24456643_rep1-AAACCCAAGGGCCCTT        unknown        unknown
# SAM24456643_rep1-AAACCCAAGTCGGCCT  HTO-15,HTO-12  HTO-15,HTO-12
# ...                                          ...            ...
# SAM24456643_rep4-TTTGTTGTCGTAGCCG           DLD1           day5
# SAM24456643_rep4-TTTGTTGTCGTTCCTG           DLD1           day5
# SAM24456643_rep4-TTTGTTGTCTCCCATG           DLD1           day5
# SAM24456643_rep4-TTTGTTGTCTGCATAG           DLD1           day5
# SAM24456643_rep4-TTTGTTGTCTTACCAT           DLD1           day5
#
#                                              HTO         NGS_ID  ...  \
# SAM24456643_rep1-AAACCCAAGACGTCGA        unknown        unknown  ...
# SAM24456643_rep1-AAACCCAAGATGATTG          HTO-1        NGS5888  ...
# SAM24456643_rep1-AAACCCAAGGATTCAA          HTO-6        NGS5888  ...
# SAM24456643_rep1-AAACCCAAGGGCCCTT        unknown        unknown  ...
# SAM24456643_rep1-AAACCCAAGTCGGCCT  HTO-15,HTO-12  HTO-15,HTO-12  ...
# ...                                          ...            ...  ...
# SAM24456643_rep4-TTTGTTGTCGTAGCCG         HTO-10        NGS5888  ...
# SAM24456643_rep4-TTTGTTGTCGTTCCTG         HTO-14        NGS5888  ...
# SAM24456643_rep4-TTTGTTGTCTCCCATG          HTO-5        NGS5888  ...
# SAM24456643_rep4-TTTGTTGTCTGCATAG          HTO-9        NGS5888  ...
# SAM24456643_rep4-TTTGTTGTCTTACCAT         HTO-14        NGS5888  ...
#
#                                   gRNA_library_MOI  \
# SAM24456643_rep1-AAACCCAAGACGTCGA          unknown
# SAM24456643_rep1-AAACCCAAGATGATTG              0.5
# SAM24456643_rep1-AAACCCAAGGATTCAA              0.5
# SAM24456643_rep1-AAACCCAAGGGCCCTT          unknown
# SAM24456643_rep1-AAACCCAAGTCGGCCT    HTO-15,HTO-12
# ...                                            ...
# SAM24456643_rep4-TTTGTTGTCGTAGCCG              0.5
# SAM24456643_rep4-TTTGTTGTCGTTCCTG              0.5
# SAM24456643_rep4-TTTGTTGTCTCCCATG              0.5
# SAM24456643_rep4-TTTGTTGTCTGCATAG              0.5
# SAM24456643_rep4-TTTGTTGTCTTACCAT              0.5
#
#                                                            gene_symbol  \
# SAM24456643_rep1-AAACCCAAGACGTCGA  ENSG00000101890_3,ENSG00000174667_2
# SAM24456643_rep1-AAACCCAAGATGATTG                               GALNT6
# SAM24456643_rep1-AAACCCAAGGATTCAA                                 AIM2
# SAM24456643_rep1-AAACCCAAGGGCCCTT                                NR2C2
# SAM24456643_rep1-AAACCCAAGTCGGCCT           ENSG00000126231_3,NTC_1225
# ...                                                                ...
# SAM24456643_rep4-TTTGTTGTCGTAGCCG                                 RTN3
# SAM24456643_rep4-TTTGTTGTCGTTCCTG                              unknown
# SAM24456643_rep4-TTTGTTGTCTCCCATG  ENSG00000186334_2,ENSG00000163661_2
# SAM24456643_rep4-TTTGTTGTCTGCATAG                              KHDRBS1
# SAM24456643_rep4-TTTGTTGTCTTACCAT                              unknown
#
#                                                                  class  \
# SAM24456643_rep1-AAACCCAAGACGTCGA  ENSG00000101890_3,ENSG00000174667_2
# SAM24456643_rep1-AAACCCAAGATGATTG                               target
# SAM24456643_rep1-AAACCCAAGGATTCAA                               target
# SAM24456643_rep1-AAACCCAAGGGCCCTT                               target
# SAM24456643_rep1-AAACCCAAGTCGGCCT           ENSG00000126231_3,NTC_1225
# ...                                                                ...
# SAM24456643_rep4-TTTGTTGTCGTAGCCG                               target
# SAM24456643_rep4-TTTGTTGTCGTTCCTG                              unknown
# SAM24456643_rep4-TTTGTTGTCTCCCATG  ENSG00000186334_2,ENSG00000163661_2
# SAM24456643_rep4-TTTGTTGTCTGCATAG                               target
# SAM24456643_rep4-TTTGTTGTCTTACCAT                              unknown
#
#                                   n_genes_by_counts total_counts  \
# SAM24456643_rep1-AAACCCAAGACGTCGA              5002        17742
# SAM24456643_rep1-AAACCCAAGATGATTG              5611        21041
# SAM24456643_rep1-AAACCCAAGGATTCAA              4570        12919
# SAM24456643_rep1-AAACCCAAGGGCCCTT              5359        18541
# SAM24456643_rep1-AAACCCAAGTCGGCCT              7894        39997
# ...                                             ...          ...
# SAM24456643_rep4-TTTGTTGTCGTAGCCG              3062         7779
# SAM24456643_rep4-TTTGTTGTCGTTCCTG              4432        10674
# SAM24456643_rep4-TTTGTTGTCTCCCATG              5170        16116
# SAM24456643_rep4-TTTGTTGTCTGCATAG              4285        11368
# SAM24456643_rep4-TTTGTTGTCTTACCAT              2758         5511
#
#                                   total_counts_mt  pct_counts_mt  \
# SAM24456643_rep1-AAACCCAAGACGTCGA             940       5.298163
# SAM24456643_rep1-AAACCCAAGATGATTG            1180       5.608098
# SAM24456643_rep1-AAACCCAAGGATTCAA             790       6.115024
# SAM24456643_rep1-AAACCCAAGGGCCCTT             877       4.730058
# SAM24456643_rep1-AAACCCAAGTCGGCCT            1577       3.942796
# ...                                           ...            ...
# SAM24456643_rep4-TTTGTTGTCGTAGCCG             354       4.550713
# SAM24456643_rep4-TTTGTTGTCGTTCCTG             458       4.290800
# SAM24456643_rep4-TTTGTTGTCTCCCATG             452       2.804666
# SAM24456643_rep4-TTTGTTGTCTGCATAG             563       4.952498
# SAM24456643_rep4-TTTGTTGTCTTACCAT             888      16.113228
#
#                                    total_counts_ribo  pct_counts_ribo  qc_pass
# SAM24456643_rep1-AAACCCAAGACGTCGA               3386        19.084658    False
# SAM24456643_rep1-AAACCCAAGATGATTG               4148        19.713892     True
# SAM24456643_rep1-AAACCCAAGGATTCAA               2103        16.278350     True
# SAM24456643_rep1-AAACCCAAGGGCCCTT               3312        17.863114    False
# SAM24456643_rep1-AAACCCAAGTCGGCCT               6486        16.216216    False
# ...                                              ...              ...      ...
# SAM24456643_rep4-TTTGTTGTCGTAGCCG               1611        20.709603     True
# SAM24456643_rep4-TTTGTTGTCGTTCCTG               1540        14.427581    False
# SAM24456643_rep4-TTTGTTGTCTCCCATG               2869        17.802184    False
# SAM24456643_rep4-TTTGTTGTCTGCATAG               1788        15.728360     True
# SAM24456643_rep4-TTTGTTGTCTTACCAT                 49         0.889131    False
#
# [108556 rows x 23 columns]

# %% [markdown]
# ## Apply filter uisng CPU

# %%
if GPU==False:
    adata = proc.filter_adata(
    adata, 
    groupby, 
    min_cells, 
    min_genes, 
    ribo, 
    doublets=doublets, pct_mt=pct_mt)

# %%
sc.pl.scatter(RP.adata_, 'n_genes_by_counts', 'total_counts', color='pct_counts_mt')

# %%
sc.pl.scatter(RP.adata_, 'pct_counts_mt', 'pct_counts_ribo', color='n_genes_by_counts')

# %%
aggr = rnaqc.aggregation(RP.adata_, groupby,aggr, 'after')

# %%
#QC plots before and after
for k in ['n_genes_by_counts', 'total_counts', 'pct_counts_mt', 'pct_counts_ribo']:
    proc.plotQCSplit(aggr, groupby, k)

# %%
cnts_after = rnaqc.Summerize_counts(RP.adata_,groupby)

# %%
cnts_after
# Out:
#                cnt    pct
# Sample
# SAM24456643  42401  100.0

# %%
proc.aggCnts(cnts_before, cnts_after)
# Out:
#              before  after  pct left
# Sample
# SAM24456643  108556  42401      39.1

# %%
proc.plot_cell_left(cnts_before, cnts_after, groupby)

# %% [markdown]
# ## Run Normalize -> HGV -> PCA -> kNN -> Leiden -> UMAP

# %%
RP.proc(n_top_genes, norm=True, scale=True, regress=False, embedding=True, n_pcs=30, 
        n_neighbors=10, knn_n_pcs=30, batch_key=None)
# Out:
# normalizing
# Processed 0 cells..
# normalizing data.
# Completed preprocessing.
# Preprocessing took 4.739813804626465 seconds
# selecting highly variable genes
# Filtering to highly variable genes.
# Processed 0 genes..
# Processed 1200 genes..
# Processed 2400 genes..
# Processed 3600 genes..
# Processed 4800 genes..
# Processed 6000 genes..
# Processed 7200 genes..
# Processed 8400 genes..
# Processed 9600 genes..
# Processed 10800 genes..
# Processed 12000 genes..
# Processed 13200 genes..
# Processed 14400 genes..
# Processed 15600 genes..
# Processed 16800 genes..
# Processed 18000 genes..
# Processed 19200 genes..
# Processed 20400 genes..
# Processed 21600 genes..
# Processed 22800 genes..
# Processed 24000 genes..
# Processed 25200 genes..
# Processed 26400 genes..
# Processed 27600 genes..
# Processed 28800 genes..
# Processed 30000 genes..
# Processed 31200 genes..
# Completed preprocessing.
# Converting sparse GPU array to dense GPU array.
# Preprocessing took 14.384960174560547 seconds
# scaling
# scaling took 1.0644240379333496 seconds
# computing PCA
# PCA took 19.91359281539917 seconds
# kNN took 6.601768732070923 seconds
# computing UMAP
# WARNING: .obsp["connectivities"] have not been computed using umap
# UMAP took 1.3768908977508545 seconds
# computing Leiden clustering
# Leiden clustering took 0.18098735809326172 seconds

# %% [markdown]
# ## Batch Correction

# %%
#RP.run_scvi(counts_layer = "counts", batch_key = "DemuxAssignment_hashing")

# %%
#RP.adata.obsm["X_scVI"]

# %% [markdown]
# ## Plot PCA UMAP

# %%
if GPU:
    sc.pl.umap(RP.adata, color="leiden")

# %%
if GPU:
    sc.pl.umap(RP.adata, color=groupby)

# %%
if GPU:
    sc.pl.umap(RP.adata, color="DemuxAssignment_hashing")

# %%
#This is just to quickly check how the data looks. Cell cycle scores are added to main adata object, but normalized and processed object is not saved
if GPU==False:
    adata_tmp = adata.copy()

# %%
if GPU==False:
    adata_tmp = proc.proc(adata_tmp, 'auto', norm=True, scale=True, regress=False, embedding=True)
    sc.pl.umap(adata_tmp, color=groupby)

# %% [markdown]
# ## Add score cell cycle

# %%
if organism=='human':
    fcc =  '/gstore/data/cbfunge/data/CellCycleGenes/Homo_sapiens.csv'
elif organism == 'mouse':
    fcc = '/gstore/data/cbfunge/data/CellCycleGenes/Mus_musculus.csv'
    
if GPU:
    proc.compute_cellCycleScores(RP._adata, fcc)
else:
    proc.compute_cellCycleScores(adata_tmp, fcc)

# %%
RP._adata
# Out:
# AnnData object with n_obs × n_vars = 108556 × 36603
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'qc_pass', 'S_score', 'G2M_score', 'phase'
#     var: 'ID', 'Symbol', 'Type', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: '.internal'
#     layers: 'counts'

# %%
RP.adata
# Out:
# AnnData object with n_obs × n_vars = 42401 × 2000
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'leiden'
#     uns: 'neighbors', 'umap', 'leiden_colors', 'Sample_colors', 'DemuxAssignment_hashing_colors'
#     obsm: 'X_pca', 'X_umap'
#     obsp: 'distances', 'connectivities'

# %%
if GPU==False:
    adata.obs['phase'] = adata_tmp.obs['phase']
    adata.obs['G2M_score'] = adata_tmp.obs['G2M_score']
    adata.obs['S_score'] = adata_tmp.obs['S_score']
    adata.obs

# %%
if GPU==False:
    sc.pl.umap(adata_tmp, color='phase')

# %%
adatas
# Out:
# {'crispr': AnnData object with n_obs × n_vars = 108556 × 20345
#      uns: '.internal'
#      layers: 'counts',
#  'hashing': AnnData object with n_obs × n_vars = 108556 × 19
#      uns: '.internal'
#      layers: 'counts'}

# %%
adatas_updated = adatas.copy()
if GPU:
    adata_updated = RP._adata.copy()
else:
    adata_updated = adata.copy()

# %%
adata_updated
# Out:
# AnnData object with n_obs × n_vars = 108556 × 36603
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'qc_pass', 'S_score', 'G2M_score', 'phase'
#     var: 'ID', 'Symbol', 'Type', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: '.internal'
#     layers: 'counts'

# %%
adatas_updated
# Out:
# {'crispr': AnnData object with n_obs × n_vars = 108556 × 20345
#      uns: '.internal'
#      layers: 'counts',
#  'hashing': AnnData object with n_obs × n_vars = 108556 × 19
#      uns: '.internal'
#      layers: 'counts'}

# %% [markdown]
# ### Write h5ad version on the disk

# %%
# If you wish to write on the disk
#adata_updated.var.index.name = None
#adata_updated.write_h5ad(raw_qc)

# %% [markdown]
# ## Write h5ad file with embedings for Energy Distance analaysis

# %%
if GPU:
    RP.adata_.obsp = RP.adata.obsp.copy()
    RP.adata_.obsm = RP.adata.obsm.copy()
else:
    adata.obsp = adata_tmp.obsp.copy()
    adata.obsm = adata_tmp.obsm.copy()

# %%
if GPU:
    adata_embedding = RP.adata_.copy()
else:
    adata_embedding = adata.copy()

# %%
adata_embedding.write_h5ad(raw_embedding)

# %% [markdown]
# ## Update the dataset with new experiment "raw_qc"

# %%
if DS_test==False:
    dsid, version = DS.update_dataset(New_experiment, adata_updated, adatas_updated, test=False)
else:    
    dsid, version = DS.update_another_dataset(test_DatasetID, True, 1, New_experiment, adata_updated, adatas_updated, test=True)
# Out:
# 08:37:50 -> Collating dataset: 'DS000017732' metadata.
# 08:37:50 -> Retrieving all project: 'DS000017732@1' metadata.
# 08:37:51 -> Reading: 'DS000017732'.
#
# 08:37:51 -> Reading: 'DS000017732 -> Experiment: main'.
#
# 08:37:51 -> Reading: 'DS000017732 -> Experiment: main -> Alt. Exp.: crispr'.
# 08:37:51 -> Reading: 'DS000017732 -> Experiment: main -> Alt. Exp.: hashing'.
# PYDSDB:INFO: Experiment already contained metadata, overwriting.
# PYDSDB:INFO: Experiment already contained metadata, overwriting.
# PYDSDB:INFO: Experiment already contained metadata, overwriting.
# Retrieving cached token data.
# Successfully authenticated.
# 08:39:25 -> Retrieving all project: 'DS000017732@latest' metadata.
# 08:39:26 -> Collating and validating project resources.
# 08:39:26 -> Attempting upload.
#   0%|                                        | 0/73 [00:00<?, ?file/s]
#   1%|▌                                       | 1/73 [00:01<01:49,  1.52s/file]
#   4%|█▋                                      | 3/73 [00:01<00:32,  2.18file/s]
#   7%|██▋                                     | 5/73 [00:01<00:19,  3.53file/s]
#   8%|███▎                                    | 6/73 [00:02<00:16,  4.07file/s]
#  11%|████▍                                   | 8/73 [00:02<00:11,  5.49file/s]
#  12%|████▉                                   | 9/73 [00:04<00:36,  1.73file/s]
#  14%|█████▍                                  | 10/73 [00:04<00:33,  1.89file/s]
#  15%|██████                                  | 11/73 [00:04<00:27,  2.23file/s]
#  16%|██████▌                                 | 12/73 [00:04<00:21,  2.82file/s]
#  19%|███████▋                                | 14/73 [00:05<00:17,  3.41file/s]
#  21%|████████▏                               | 15/73 [00:05<00:18,  3.11file/s]
#  22%|████████▊                               | 16/73 [00:07<00:37,  1.54file/s]
#  23%|█████████▎                              | 17/73 [00:07<00:34,  1.64file/s]
#  25%|█████████▊                              | 18/73 [00:07<00:26,  2.07file/s]
#  26%|██████████▍                             | 19/73 [00:08<00:20,  2.59file/s]
#  29%|███████████▌                            | 21/73 [00:08<00:16,  3.24file/s]
#  30%|████████████                            | 22/73 [00:08<00:13,  3.78file/s]
#  32%|████████████▌                           | 23/73 [01:58<23:39, 28.39s/file]
#  33%|█████████████▏                          | 24/73 [01:59<17:07, 20.98s/file]
#  36%|██████████████▏                         | 26/73 [01:59<09:19, 11.90s/file]
#  37%|██████████████▊                         | 27/73 [02:04<07:50, 10.22s/file]
#  38%|███████████████▎                        | 28/73 [02:04<05:48,  7.75s/file]
#  40%|███████████████▉                        | 29/73 [02:04<04:14,  5.78s/file]
#  41%|████████████████▍                       | 30/73 [02:05<03:02,  4.24s/file]
#  42%|████████████████▉                       | 31/73 [02:06<02:28,  3.54s/file]
#  44%|█████████████████▌                      | 32/73 [02:07<01:55,  2.81s/file]
#  45%|██████████████████                      | 33/73 [02:07<01:21,  2.03s/file]
#  47%|██████████████████▋                     | 34/73 [02:08<00:57,  1.47s/file]
#  49%|███████████████████▋                    | 36/73 [02:08<00:33,  1.10file/s]
#  51%|████████████████████▎                   | 37/73 [02:08<00:26,  1.38file/s]
#  52%|████████████████████▊                   | 38/73 [02:08<00:20,  1.70file/s]
#  53%|█████████████████████▎                  | 39/73 [02:09<00:22,  1.51file/s]
#  55%|█████████████████████▉                  | 40/73 [02:09<00:17,  1.89file/s]
#  56%|██████████████████████▍                 | 41/73 [02:10<00:13,  2.31file/s]
#  58%|███████████████████████                 | 42/73 [02:10<00:10,  2.94file/s]
#  60%|████████████████████████                | 44/73 [02:10<00:08,  3.38file/s]
#  62%|████████████████████████▋               | 45/73 [02:10<00:07,  3.87file/s]
#  63%|█████████████████████████▏              | 46/73 [02:10<00:06,  4.48file/s]
#  66%|██████████████████████████▎             | 48/73 [02:11<00:04,  6.18file/s]
#  67%|██████████████████████████▊             | 49/73 [02:11<00:03,  6.22file/s]
#  68%|███████████████████████████▍            | 50/73 [02:11<00:05,  4.34file/s]
#  70%|███████████████████████████▉            | 51/73 [02:11<00:04,  4.99file/s]
#  71%|████████████████████████████▍           | 52/73 [02:12<00:05,  3.99file/s]
#  73%|█████████████████████████████           | 53/73 [02:15<00:22,  1.13s/file]
#  74%|█████████████████████████████▌          | 54/73 [02:15<00:16,  1.17file/s]
#  75%|██████████████████████████████▏         | 55/73 [02:19<00:27,  1.54s/file]
#  77%|██████████████████████████████▋         | 56/73 [02:19<00:19,  1.14s/file]
#  78%|███████████████████████████████▏        | 57/73 [02:38<01:42,  6.42s/file]
#  79%|███████████████████████████████▊        | 58/73 [02:38<01:08,  4.56s/file]
#  82%|████████████████████████████████▉       | 60/73 [02:38<00:33,  2.55s/file]
#  85%|█████████████████████████████████▉      | 62/73 [02:38<00:17,  1.58s/file]
#  86%|██████████████████████████████████▌     | 63/73 [02:39<00:12,  1.26s/file]
#  88%|███████████████████████████████████     | 64/73 [02:39<00:08,  1.00file/s]
#  90%|████████████████████████████████████▏   | 66/73 [02:39<00:04,  1.59file/s]
#  92%|████████████████████████████████████▋   | 67/73 [02:39<00:03,  1.91file/s]
#  93%|█████████████████████████████████████▎  | 68/73 [02:39<00:02,  2.25file/s]
#  95%|█████████████████████████████████████▊  | 69/73 [02:39<00:01,  2.74file/s]
#  96%|██████████████████████████████████████▎ | 70/73 [02:40<00:01,  2.78file/s]
#  97%|██████████████████████████████████████▉ | 71/73 [02:40<00:00,  3.34file/s]
#  99%|███████████████████████████████████████▍| 72/73 [03:00<00:05,  5.82s/file]
# 100%|████████████████████████████████████████| 73/73 [03:00<00:00,  4.17s/file]
# 100%|████████████████████████████████████████| 73/73 [03:00<00:00,  2.47s/file]
# Clearing upload info.
# 08:42:43 -> Upload completed.
# Processing...
# Processing...
# Processing...
# Processing...
# Upload successful, your DSID is 'DS000017732' and version is: '5'. Also written to 'upload_info.json' in staging dir.

# %%
dsid, version
# Out:
# ('DS000017732', '5')
