# %%
# Parameters
DatasetID = "DS000017729"
DEV = False
test_DatasetID = ""
DS_test = False
title = "Recursion DLD1 Library3- Screen2 (NGS5888)"
description = "Production scale screen in DLD-1 cells with 1/4 of the genome-wide CRISPR library (sub-lib-3, ~22K guides). 1 time point: Day-5. We performed 24 rxns of 10x 3' HT kit with an estimated loading of 52K cells. We performed a pilot study to test the library quality before the production-level sequencing. We will submit 72 libraries (24 GEX, 24 HTO and 24 sgRNA) We request 600M reads for GEX, 20M for HTO and 40M for sgRNA, after finishing QC sequencing of NGS5887. NGS has built the GEX and sgRNA libraries using automation, we will provide manually constructed HTO libraries."
name_space = [{"id": "GRCh38", "type": "genome"}]
sources = [{"id": "Siavash-1234", "name": "Geo-ID"}]
tech_name = "scRNA-seq"
author = "SG"
alt_experiments = ["crispr", "hashing"]
organism = "human"
groupby = "Sample"
min_cells = 3
min_genes = 500
max_genes = None
pct_mt = None
total_counts = None
n_top_genes = 2000
ribo = True
doublets = True
Mapping_rate = {"LIB6238874_SAM24456643": "Total number of reads: 89623760\nNumber of reads with valid cell barcodes: 87319284 (97.43%)\nNumber of reads with valid feature barcodes: 76712881 (85.59%)\nNumber of reads with valid cell and feature barcodes: 75040086 (83.73%)\n\nSection LIB6238874_SAM24456643.crispr\nNumber of valid cell barcodes: 192257\nNumber of valid reads (with matching cell and feature barcodes): 75040086\nMean number of valid reads per cell barcode: 390.31\nNumber of valid UMIs (with matching cell and feature barcodes): 2205386\nMean number of valid UMIs per cell barcode: 11.47\nSequencing saturation: 97.06%\n", "LIB6238850_SAM24456643": "Total number of reads: 19980251\nNumber of reads with valid cell barcodes: 19275520 (96.47%)\nNumber of reads with valid feature barcodes: 18470388 (92.44%)\nNumber of reads with valid cell and feature barcodes: 18048831 (90.33%)\n\nSection LIB6238850_SAM24456643.hashing\nNumber of valid cell barcodes: 980848\nNumber of valid reads (with matching cell and feature barcodes): 18048831\nMean number of valid reads per cell barcode: 18.40\nNumber of valid UMIs (with matching cell and feature barcodes): 14771281\nMean number of valid UMIs per cell barcode: 15.06\nSequencing saturation: 18.16%\n", "LIB6238877_SAM24456643": "Total number of reads: 71834738\nNumber of reads with valid cell barcodes: 69635135 (96.94%)\nNumber of reads with valid feature barcodes: 61271305 (85.29%)\nNumber of reads with valid cell and feature barcodes: 59692954 (83.10%)\n\nSection LIB6238877_SAM24456643.crispr\nNumber of valid cell barcodes: 183820\nNumber of valid reads (with matching cell and feature barcodes): 59692954\nMean number of valid reads per cell barcode: 324.74\nNumber of valid UMIs (with matching cell and feature barcodes): 1907203\nMean number of valid UMIs per cell barcode: 10.38\nSequencing saturation: 96.80%\n", "LIB6238853_SAM24456643": "Total number of reads: 21036097\nNumber of reads with valid cell barcodes: 20246638 (96.25%)\nNumber of reads with valid feature barcodes: 19373008 (92.09%)\nNumber of reads with valid cell and feature barcodes: 18926888 (89.97%)\n\nSection LIB6238853_SAM24456643.hashing\nNumber of valid cell barcodes: 917185\nNumber of valid reads (with matching cell and feature barcodes): 18926888\nMean number of valid reads per cell barcode: 20.64\nNumber of valid UMIs (with matching cell and feature barcodes): 15437344\nMean number of valid UMIs per cell barcode: 16.83\nSequencing saturation: 18.44%\n", "LIB6238876_SAM24456643": "Total number of reads: 82066591\nNumber of reads with valid cell barcodes: 79742167 (97.17%)\nNumber of reads with valid feature barcodes: 70481418 (85.88%)\nNumber of reads with valid cell and feature barcodes: 68746387 (83.77%)\n\nSection LIB6238876_SAM24456643.crispr\nNumber of valid cell barcodes: 188064\nNumber of valid reads (with matching cell and feature barcodes): 68746387\nMean number of valid reads per cell barcode: 365.55\nNumber of valid UMIs (with matching cell and feature barcodes): 2227205\nMean number of valid UMIs per cell barcode: 11.84\nSequencing saturation: 96.76%\n", "LIB6238852_SAM24456643": "Total number of reads: 20554875\nNumber of reads with valid cell barcodes: 19773079 (96.20%)\nNumber of reads with valid feature barcodes: 18874687 (91.83%)\nNumber of reads with valid cell and feature barcodes: 18439328 (89.71%)\n\nSection LIB6238852_SAM24456643.hashing\nNumber of valid cell barcodes: 751068\nNumber of valid reads (with matching cell and feature barcodes): 18439328\nMean number of valid reads per cell barcode: 24.55\nNumber of valid UMIs (with matching cell and feature barcodes): 14992853\nMean number of valid UMIs per cell barcode: 19.96\nSequencing saturation: 18.69%\n", "LIB6238875_SAM24456643": "Total number of reads: 85568099\nNumber of reads with valid cell barcodes: 83411824 (97.48%)\nNumber of reads with valid feature barcodes: 73482604 (85.88%)\nNumber of reads with valid cell and feature barcodes: 71905874 (84.03%)\n\nSection LIB6238875_SAM24456643.crispr\nNumber of valid cell barcodes: 183960\nNumber of valid reads (with matching cell and feature barcodes): 71905874\nMean number of valid reads per cell barcode: 390.88\nNumber of valid UMIs (with matching cell and feature barcodes): 2226245\nMean number of valid UMIs per cell barcode: 12.10\nSequencing saturation: 96.90%\n", "LIB6238851_SAM24456643": "Total number of reads: 21101935\nNumber of reads with valid cell barcodes: 20335778 (96.37%)\nNumber of reads with valid feature barcodes: 19554718 (92.67%)\nNumber of reads with valid cell and feature barcodes: 19084087 (90.44%)\n\nSection LIB6238851_SAM24456643.hashing\nNumber of valid cell barcodes: 862905\nNumber of valid reads (with matching cell and feature barcodes): 19084087\nMean number of valid reads per cell barcode: 22.12\nNumber of valid UMIs (with matching cell and feature barcodes): 15869184\nMean number of valid UMIs per cell barcode: 18.39\nSequencing saturation: 16.85%\n"}
raw_qc = "/gstore/scratch/u/ghaffars/Dataset/crc_NGS5888//DS000017729/raw_qc.h5ad"
raw_embedding = "/gstore/scratch/u/ghaffars/Dataset/crc_NGS5888//DS000017729/qc_embedding.h5ad"

# %% [markdown]
#  # QC analysis of single cell RNA-seq dataset: This notebook will guide you through the process of quality control analyis on a single-cell RNA sequencing dataset

# %%
# Different scenario for original dataset or test dataset
try:
    if DS_test==True:
        DSID = test_DatasetID
        Version = '2'   # the version of your dataset
        DEV = True
    elif len(alt_experiments)==2:
        DSID = DatasetID
        Version = '4'   # the version of your dataset
        your_experiment = "crispr_hashing_harmonized" # A string that is a key known for our desired experimnet that you wish to work on
    else:
        DSID = DatasetID
        Version = '2'   # the version of your dataset
        your_experiment = "main" # A string that is a key known for our desired experimnet that you wish to work on

except TypeError:
    DSID = DatasetID
    Version = '1'   # the version of your dataset
    your_experiment = "raw_qc" # A string that is a key known for our desired experimnet that you wish to work on

New_experiment = "raw_qc" # A string that is a key known for the updated data saved by that that name

# %%
## Import Libraries
from __future__ import division
import pandas as pd

#single cell libraries
import scanpy as sc

#general
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

#plotting
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('talk')

# %%
import sys
sys.path.append("..")
import Templates.tools.DatasetDB as DB
import Templates.tools.RNA_Seq_QC as rnaqc
import Templates.tools.scProc as proc
try:
    import Templates.tools.rapids_modified as rp
except ImportError:
        pass

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Check if GPU device is available

# %%
GPU = rnaqc.pipeline_has_gpu()

# %%
GPU
# Out:
# True

# %% [markdown]
# ## Instantiate a dataset object given our dataset info

# %%
DS = DB.DATASET(DSID, DEV, title=title, description=description, name_space=name_space, organism=organism,
                       sources=sources, tech_name=tech_name, author=author)

# %%
adata, adatas = DS.load_dataset(Version, your_experiment, Corr=False)
# Out:
# 09:14:19 -> Collating dataset: 'DS000017729' metadata.
# 09:14:19 -> Retrieving all project: 'DS000017729@4' metadata.
# 09:14:19 -> Reading: 'DS000017729'.
#
# 09:14:19 -> Reading: 'DS000017729 -> Experiment: main'.
#
# 09:14:19 -> Reading: 'DS000017729 -> Experiment: main -> Alt. Exp.: crispr'.
# 09:14:20 -> Reading: 'DS000017729 -> Experiment: main -> Alt. Exp.: hashing'.
# 09:14:23 -> Reading: 'DS000017729 -> Experiment: crispr_hashing_harmonized'.
#
# 09:14:23 -> Reading: 'DS000017729 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: crispr'.
# 09:14:23 -> Reading: 'DS000017729 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: hashing'.

# %%
adata = rnaqc.load_data(adata,  alt_experiments)

# %%
adata.obs.head()
# Out:
#                                          Sample           Barcode  \
# SAM24456643_rep21-AAACCCAAGCCATTTG  SAM24456643  AAACCCAAGCCATTTG
# SAM24456643_rep21-AAACCCAAGGAAAGGT  SAM24456643  AAACCCAAGGAAAGGT
# SAM24456643_rep21-AAACCCAAGGCTCTAT  SAM24456643  AAACCCAAGGCTCTAT
# SAM24456643_rep21-AAACCCAAGGGTTAAT  SAM24456643  AAACCCAAGGGTTAAT
# SAM24456643_rep21-AAACCCAAGTCCCTAA  SAM24456643  AAACCCAAGTCCCTAA
#
#                                    DemuxType_crispr  \
# SAM24456643_rep21-AAACCCAAGCCATTTG          doublet
# SAM24456643_rep21-AAACCCAAGGAAAGGT          doublet
# SAM24456643_rep21-AAACCCAAGGCTCTAT          singlet
# SAM24456643_rep21-AAACCCAAGGGTTAAT          singlet
# SAM24456643_rep21-AAACCCAAGTCCCTAA          singlet
#
#                                                  DemuxAssignment_crispr  \
# SAM24456643_rep21-AAACCCAAGCCATTTG  ENSG00000124374_3,ENSG00000078487_2
# SAM24456643_rep21-AAACCCAAGGAAAGGT  ENSG00000225698_3,ENSG00000005421_2
# SAM24456643_rep21-AAACCCAAGGCTCTAT                             NTC_1109
# SAM24456643_rep21-AAACCCAAGGGTTAAT                    ENSG00000173578_3
# SAM24456643_rep21-AAACCCAAGTCCCTAA                    ENSG00000168928_2
#
#                                    DemuxType_hashing DemuxAssignment_hashing  \
# SAM24456643_rep21-AAACCCAAGCCATTTG           singlet             SAM24439045
# SAM24456643_rep21-AAACCCAAGGAAAGGT           singlet             SAM24439043
# SAM24456643_rep21-AAACCCAAGGCTCTAT           singlet             SAM24439045
# SAM24456643_rep21-AAACCCAAGGGTTAAT           singlet             SAM24439044
# SAM24456643_rep21-AAACCCAAGTCCCTAA           doublet             HTO-7,HTO-4
#
#                                        cellline    timepoint          HTO  \
# SAM24456643_rep21-AAACCCAAGCCATTTG         DLD1         day5       HTO-18
# SAM24456643_rep21-AAACCCAAGGAAAGGT         DLD1         day5        HTO-3
# SAM24456643_rep21-AAACCCAAGGCTCTAT         DLD1         day5        HTO-7
# SAM24456643_rep21-AAACCCAAGGGTTAAT         DLD1         day5        HTO-6
# SAM24456643_rep21-AAACCCAAGTCCCTAA  HTO-7,HTO-4  HTO-7,HTO-4  HTO-7,HTO-4
#
#                                          NGS_ID Biological_replicate 10Xrun  \
# SAM24456643_rep21-AAACCCAAGCCATTTG      NGS5888          SAM24439045     21
# SAM24456643_rep21-AAACCCAAGGAAAGGT      NGS5888          SAM24439043     21
# SAM24456643_rep21-AAACCCAAGGCTCTAT      NGS5888          SAM24439045     21
# SAM24456643_rep21-AAACCCAAGGGTTAAT      NGS5888          SAM24439044     21
# SAM24456643_rep21-AAACCCAAGTCCCTAA  HTO-7,HTO-4          HTO-7,HTO-4     21
#
#                                                                            sublibrary  \
# SAM24456643_rep21-AAACCCAAGCCATTTG  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
# SAM24456643_rep21-AAACCCAAGGAAAGGT  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
# SAM24456643_rep21-AAACCCAAGGCTCTAT  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
# SAM24456643_rep21-AAACCCAAGGGTTAAT  GMTY210:cropseq.crisprko.cas9.human.lib3.conce...
# SAM24456643_rep21-AAACCCAAGTCCCTAA                                        HTO-7,HTO-4
#
#                                    gRNA_library_MOI  \
# SAM24456643_rep21-AAACCCAAGCCATTTG              0.5
# SAM24456643_rep21-AAACCCAAGGAAAGGT              0.5
# SAM24456643_rep21-AAACCCAAGGCTCTAT              0.5
# SAM24456643_rep21-AAACCCAAGGGTTAAT              0.5
# SAM24456643_rep21-AAACCCAAGTCCCTAA      HTO-7,HTO-4
#
#                                                             gene_symbol  \
# SAM24456643_rep21-AAACCCAAGCCATTTG  ENSG00000124374_3,ENSG00000078487_2
# SAM24456643_rep21-AAACCCAAGGAAAGGT  ENSG00000225698_3,ENSG00000005421_2
# SAM24456643_rep21-AAACCCAAGGCTCTAT                                  NTC
# SAM24456643_rep21-AAACCCAAGGGTTAAT                                 XCR1
# SAM24456643_rep21-AAACCCAAGTCCCTAA                                CTRB2
#
#                                                                   class
# SAM24456643_rep21-AAACCCAAGCCATTTG  ENSG00000124374_3,ENSG00000078487_2
# SAM24456643_rep21-AAACCCAAGGAAAGGT  ENSG00000225698_3,ENSG00000005421_2
# SAM24456643_rep21-AAACCCAAGGCTCTAT                                  ntc
# SAM24456643_rep21-AAACCCAAGGGTTAAT                               target
# SAM24456643_rep21-AAACCCAAGTCCCTAA                               target

# %%
adata.var.head()
# Out:
#                                         ID                     Symbol  \
# Symbol
# 3xLinker                 3xLinker_3xLinker          3xLinker_3xLinker
# MIR1302-2HG  GRCh38-2020-A_ENSG00000243485  GRCh38-2020-A_MIR1302-2HG
# FAM138A      GRCh38-2020-A_ENSG00000237613      GRCh38-2020-A_FAM138A
# OR4F5        GRCh38-2020-A_ENSG00000186092        GRCh38-2020-A_OR4F5
# LIB6238853_SAM24456643                                       20.64
# LIB6238876_SAM24456643                                      365.55
# LIB6238852_SAM24456643                                       24.55
# LIB6238875_SAM24456643                                      390.88
# LIB6238851_SAM24456643                                       22.12
#
#                        Number of valid UMIs (with matching cell and feature barcodes)  \
# LIB6238874_SAM24456643                                            2205386
# LIB6238850_SAM24456643                                           14771281
# LIB6238877_SAM24456643                                            1907203
# LIB6238853_SAM24456643                                           15437344
# LIB6238876_SAM24456643                                            2227205
# LIB6238852_SAM24456643                                           14992853
# LIB6238875_SAM24456643                                            2226245
# LIB6238851_SAM24456643                                           15869184
#
#                        Mean number of valid UMIs per cell barcode  \
# LIB6238874_SAM24456643                                      11.47
# LIB6238850_SAM24456643                                      15.06
# LIB6238877_SAM24456643                                      10.38
# LIB6238853_SAM24456643                                      16.83
# LIB6238876_SAM24456643                                      11.84
# LIB6238852_SAM24456643                                      19.96
# LIB6238875_SAM24456643                                      12.10
# LIB6238851_SAM24456643                                      18.39
#
#                        Sequencing saturation Experiment
# LIB6238874_SAM24456643                97.06%     crispr
# LIB6238850_SAM24456643                18.16%    hashing
# LIB6238877_SAM24456643                96.80%     crispr
# LIB6238853_SAM24456643                18.44%    hashing
# LIB6238876_SAM24456643                96.76%     crispr
# LIB6238852_SAM24456643                18.69%    hashing
# LIB6238875_SAM24456643                96.90%     crispr
# LIB6238851_SAM24456643                16.85%    hashing

# %%
#Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
agg.plot(kind='barh', ax=ax1, stacked=False, color=['midnightblue', 'blue', 'deepskyblue'], legend=False)
ax1.set_xlabel('Read Count')
agg_percentage.plot(kind='barh', ax=ax2, stacked=False, color=['midnightblue', 'blue', 'deepskyblue'])
ax2.set_xlabel('%Read Count')
ax2.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.suptitle('Mapping Rate', fontsize=25)
plt.show()

# %% [markdown]
# ## Doublet information

# %%
rnaqc.doublet_counter(adata)
# Out:
#                                                     Cell counts
# total Cells                                               85186
# cells after keeping singlets by hashing                   68243
# cells after keeping singlets by gRNA                      36687
# cells after keeping singlets by both hashing an...        32780

# %% [markdown]
# ### Sumarize counts

# %%
cnts_before = rnaqc.Summerize_counts(adata, groupby)

# %%
cnts_before
# Out:
#                cnt    pct
# Sample
# SAM24456643  85186  100.0

# %% [markdown]
# ### calculate qc metrics

# %%
adata = proc.calc_qc_metrics(adata, organism)

# %%
LOWER,UPPER = rnaqc.upper_lower_limits(adata, groupby)

# %%
LOWER
# Out:
#              n_genes_by_counts  total_counts  pct_counts_mt  pct_counts_ribo
# SAM24456643            -1498.5    -15194.125      -2.079306        -8.686948

# %%
UPPER
# Out:
#              n_genes_by_counts  total_counts  pct_counts_mt  pct_counts_ribo
# SAM24456643             9785.5     40248.875      13.805714        35.967239

# %%
sc.pl.scatter(adata, 'n_genes_by_counts', 'total_counts', color='pct_counts_mt')

# %%
sc.pl.scatter(adata, 'pct_counts_mt', 'pct_counts_ribo', color='n_genes_by_counts')

# %%
sc.pl.violin(
    adata, 
    [
     'n_genes_by_counts', 
     'total_counts', 
     'pct_counts_mt'
     ],
    multi_panel=True
)

# %%
aggr = rnaqc.aggregation(adata, groupby, None, 'before')

# %%
adata.obs.head()
# Out:
#                                          Sample           Barcode  \
# SAM24456643_rep21-AAACCCAAGCCATTTG
\
# SAM24456643_rep21-AAACCCAAGCCATTTG  ENSG00000124374_3,ENSG00000078487_2
# SAM24456643_rep21-AAACCCAAGGAAAGGT  ENSG00000225698_3,ENSG00000005421_2
# SAM24456643_rep21-AAACCCAAGGCTCTAT                                  NTC
# SAM24456643_rep21-AAACCCAAGGGTTAAT                                 XCR1
# SAM24456643_rep21-AAACCCAAGTCCCTAA                                CTRB2
#
#                                                                   class  \
# SAM24456643_rep21-AAACCCAAGCCATTTG  ENSG00000124374_3,ENSG00000078487_2
# SAM24456643_rep21-AAACCCAAGGAAAGGT  ENSG00000225698_3,ENSG00000005421_2
# SAM24456643_rep21-AAACCCAAGGCTCTAT                                  ntc
# SAM24456643_rep21-AAACCCAAGGGTTAAT                               target
# SAM24456643_rep21-AAACCCAAGTCCCTAA                               target
#
#                                    n_genes_by_counts total_counts  \
# SAM24456643_rep21-AAACCCAAGCCATTTG              4826        15905
# SAM24456643_rep21-AAACCCAAGGAAAGGT              3852        12547
# SAM24456643_rep21-AAACCCAAGGCTCTAT              4654        14708
# SAM24456643_rep21-AAACCCAAGGGTTAAT              5643        18754
# SAM24456643_rep21-AAACCCAAGTCCCTAA              5865        22521
#
#                                     total_counts_mt  pct_counts_mt  \
# SAM24456643_rep21-AAACCCAAGCCATTTG              954       5.998114
# SAM24456643_rep21-AAACCCAAGGAAAGGT              414       3.299594
# SAM24456643_rep21-AAACCCAAGGCTCTAT              640       4.351373
# SAM24456643_rep21-AAACCCAAGGGTTAAT              768       4.095126
# SAM24456643_rep21-AAACCCAAGTCCCTAA             1063       4.720039
#
#                                     total_counts_ribo  pct_counts_ribo
# SAM24456643_rep21-AAACCCAAGCCATTTG               3291        20.691606
# SAM24456643_rep21-AAACCCAAGGAAAGGT               3312        26.396748
# SAM24456643_rep21-AAACCCAAGGCTCTAT               2597        17.657057
# SAM24456643_rep21-AAACCCAAGGGTTAAT               2878        15.346060
# SAM24456643_rep21-AAACCCAAGTCCCTAA               3988        17.707917
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Instantiate a RapidsSingleCellPipeline object given our AnnData to prepare RAPIDS environment for other steps

# %%
RP = rp.RapidsSingleCellPipeline(adata)

# %% [markdown]
# ## Notice:
# - **RP._adata is adata before filtering**
# - **RP.adata_ is adata after filtering**
# - **Rp.adata is adata after normalization (and highly variable genes selected)**

# %%
max_cells = None
cell_batch_size = 100000
gene_batch_size = 1200
target_sum = 1e4
n_top_genes = 2000
counts_layer = "counts"
batch_key = "DemuxAssignment_hashing"

# %% [markdown]
# ## Apply filter using GPU

# %%
if GPU:
    RP.filter_data(
    groupby,
    min_genes=min_genes,
    max_genes=max_genes,
    max_cells=max_cells,
    cell_batch_size=cell_batch_size,
    min_cells=min_cells,
    gene_batch_size=gene_batch_size,
        ribo=ribo, 
        doublets=doublets,
        pct_mt=pct_mt, 
        total_counts=total_counts
)
# Out:
# starting with 85186 cells
# Filtering cells.
# Processed 0 cells..
# Filtering genes.
# Completed preprocessing.
# Calculating upper outliers
# Now 78162 cells after filtering max genes
# Calculating upper outliers
# Now 63574 cells after filtering pct mt
# Calculating upper outliers
# Now 62147 cells after filtering total counts
# Now 62078 cells after filtering pct ribo
# Now 52808 cells after keeping singlets by hashing
# Now 31928 cells after keeping singlets by gRNA
# Preprocessing took 28.075148820877075 seconds

# %%
RP._adata
# Out:
# AnnData object with n_obs × n_vars = 85186 × 36603
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo'
#     var: 'ID', 'Symbol', 'Type', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: '.internal'
#     layers: 'counts'

# %%
RP.adata_
# Out:
# View of AnnData object with n_obs × n_vars = 31928 × 31695
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo'
#     var: 'ID', 'Symbol', 'Type', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     layers: 'counts'

# %%
RP._adata.obs["qc_pass"] = RP._adata.obs.index.isin(RP.adata_.obs.index)

# %%
RP._adata.obs
# Out:
#                                          Sample           Barcode  \
# SAM24456643_rep21-AAACCCAAGCCATTTG  SAM24456643  AAACCCAAGCCATTTG
# SAM24456643_rep21-AAACCCAAGGAAAGGT  SAM24456643  AAACCCAAGGAAAGGT
# SAM24456643_rep21-AAACCCAAGGCTCTAT  SAM24456643  AAACCCAAGGCTCTAT
# SAM24456643_rep21-AAACCCAAGGGTTAAT  SAM24456643  AAACCCAAGGGTTAAT
# SAM24456643_rep21-AAACCCAAGTCCCTAA  SAM24456643  AAACCCAAGTCCCTAA
# ...                                         ...               ...
# SAM24456643_rep24-TTTGTTGTCTACCATC  SAM24456643  TTTGTTGTCTACCATC
# SAM24456643_rep24-TTTGTTGTCTCCTGCA  SAM24456643  TTTGTTGTCTCCTGCA
# SAM24456643_rep24-TTTGTTGTCTCTTAAC  SAM24456643  TTTGTTGTCTCTTAAC
# SAM24456643_rep24-TTTGTTGTCTGCGGAC  SAM24456643  TTTGTTGTCTGCGGAC
# SAM24456643_rep24-TTTGTTGTCTTGAGCA  SAM24456643  TTTGTTGTCTTGAGCA
#
#                                    DemuxType_crispr  \
# SAM24456643_rep21-AAACCCAAGCCATTTG          doublet
# SAM24456643_rep21-AAACCCAAGGAAAGGT          doublet
# SAM24456643_rep21-AAACCCAAGGCTCTAT          singlet
# SAM24456643_rep21-AAACCCAAGGGTTAAT          singlet
# SAM24456643_rep21-AAACCCAAGTCCCTAA          singlet
# ...                                             ...
# SAM24456643_rep24-TTTGTTGTCTACCATC          unknown
# SAM24456643_rep24-TTTGTTGTCTCCTGCA          singlet
# SAM24456643_rep24-TTTGTTGTCTCTTAAC          singlet
# SAM24456643_rep24-TTTGTTGTCTGCGGAC          singlet
# SAM24456643_rep24-TTTGTTGTCTTGAGCA          doublet
#
#                                                  DemuxAssignment_crispr  \
# SAM24456643_rep21-AAACCCAAGCCATTTG  ENSG00000124374_3,ENSG00000078487_2
# SAM24456643_rep21-AAACCCAAGGAAAGGT  ENSG00000225698_3,ENSG00000005421_2
# SAM24456643_rep21-AAACCCAAGGCTCTAT                             NTC_1109
# SAM24456643_rep21-AAACCCAAGGGTTAAT                    ENSG00000173578_3
# SAM24456643_rep21-AAACCCAAGTCCCTAA                    ENSG00000168928_2
# ...                                                                 ...
# SAM24456643_rep24-TTTGTTGTCTACCATC                              unknown
# SAM24456643_rep24-TTTGTTGTCTCCTGCA                    ENSG00000061273_1
# SAM24456643_rep24-TTTGTTGTCTCTTAAC                    ENSG00000203783_2
# SAM24456643_rep24-TTTGTTGTCTGCGGAC                    ENSG00000104998_3
# SAM24456643_rep21-AAACCCAAGGAAAGGT               3312        26.396748
# SAM24456643_rep21-AAACCCAAGGCTCTAT               2597        17.657057
# SAM24456643_rep21-AAACCCAAGGGTTAAT               2878        15.346060
# SAM24456643_rep21-AAACCCAAGTCCCTAA               3988        17.707917
# ...                                               ...              ...
# SAM24456643_rep24-TTTGTTGTCTACCATC                  0         0.000000
# SAM24456643_rep24-TTTGTTGTCTCCTGCA               2926        14.930095
# SAM24456643_rep24-TTTGTTGTCTCTTAAC               2465        15.404324
# SAM24456643_rep24-TTTGTTGTCTGCGGAC               4277        17.788222
# SAM24456643_rep24-TTTGTTGTCTTGAGCA               1576        13.730615
#
#                                     qc_pass
# SAM24456643_rep21-AAACCCAAGCCATTTG    False
# SAM24456643_rep21-AAACCCAAGGAAAGGT    False
# SAM24456643_rep21-AAACCCAAGGCTCTAT     True
# SAM24456643_rep21-AAACCCAAGGGTTAAT     True
# SAM24456643_rep21-AAACCCAAGTCCCTAA    False
# ...                                     ...
# SAM24456643_rep24-TTTGTTGTCTACCATC    False
# SAM24456643_rep24-TTTGTTGTCTCCTGCA     True
# SAM24456643_rep24-TTTGTTGTCTCTTAAC     True
# SAM24456643_rep24-TTTGTTGTCTGCGGAC     True
# SAM24456643_rep24-TTTGTTGTCTTGAGCA    False
#
# [85186 rows x 23 columns]

# %% [markdown]
# ## Apply filter uisng CPU

# %%
if GPU==False:
    adata = proc.filter_adata(
    adata, 
    groupby, 
    min_cells, 
    min_genes, 
    ribo, 
    doublets=doublets, pct_mt=pct_mt)

# %%
sc.pl.scatter(RP.adata_, 'n_genes_by_counts', 'total_counts', color='pct_counts_mt')

# %%
sc.pl.scatter(RP.adata_, 'pct_counts_mt', 'pct_counts_ribo', color='n_genes_by_counts')

# %%
aggr = rnaqc.aggregation(RP.adata_, groupby,aggr, 'after')

# %%
#QC plots before and after
for k in ['n_genes_by_counts', 'total_counts', 'pct_counts_mt', 'pct_counts_ribo']:
    proc.plotQCSplit(aggr, groupby, k)

# %%
cnts_after = rnaqc.Summerize_counts(RP.adata_,groupby)

# %%
cnts_after
# Out:
#                cnt    pct
# Sample
# SAM24456643  31928  100.0

# %%
proc.aggCnts(cnts_before, cnts_after)
# Out:
#              before  after  pct left
# Sample
# SAM24456643   85186  31928      37.5

# %%
proc.plot_cell_left(cnts_before, cnts_after, groupby)

# %% [markdown]
# ## Run Normalize -> HGV -> PCA -> kNN -> Leiden -> UMAP

# %%
RP.proc(n_top_genes, norm=True, scale=True, regress=False, embedding=True, n_pcs=30, 
        n_neighbors=10, knn_n_pcs=30, batch_key=None)
# Out:
# normalizing
# Processed 0 cells..
# normalizing data.
# Completed preprocessing.
# Preprocessing took 4.168945074081421 seconds
# selecting highly variable genes
# Filtering to highly variable genes.
# Processed 0 genes..
# Processed 1200 genes..
# Processed 2400 genes..
# Processed 3600 genes..
# Processed 4800 genes..
# Processed 6000 genes..
# Processed 7200 genes..
# Processed 8400 genes..
# Processed 9600 genes..
# Processed 10800 genes..
# Processed 12000 genes..
# Processed 13200 genes..
# Processed 14400 genes..
# Processed 15600 genes..
# Processed 16800 genes..
# Processed 18000 genes..
# Processed 19200 genes..
# Processed 20400 genes..
# Processed 21600 genes..
# Processed 22800 genes..
# Processed 24000 genes..
# Processed 25200 genes..
# Processed 26400 genes..
# Processed 27600 genes..
# Processed 28800 genes..
# Processed 30000 genes..
# Processed 31200 genes..
# Completed preprocessing.
# Converting sparse GPU array to dense GPU array.
# Preprocessing took 11.637202978134155 seconds
# scaling
# scaling took 0.686765193939209 seconds
# computing PCA
# PCA took 0.5971090793609619 seconds
# kNN took 5.027477025985718 seconds
# computing UMAP
# WARNING: .obsp["connectivities"] have not been computed using umap
# UMAP took 0.21674013137817383 seconds
# computing Leiden clustering
# Leiden clustering took 0.08407402038574219 seconds

# %% [markdown]
# ## Batch Correction

# %%
#RP.run_scvi(counts_layer = "counts", batch_key = "DemuxAssignment_hashing")

# %%
#RP.adata.obsm["X_scVI"]

# %% [markdown]
# ## Plot PCA UMAP

# %%
if GPU:
    sc.pl.umap(RP.adata, color="leiden")

# %%
if GPU:
    sc.pl.umap(RP.adata, color=groupby)

# %%
if GPU:
    sc.pl.umap(RP.adata, color="DemuxAssignment_hashing")

# %%
#This is just to quickly check how the data looks. Cell cycle scores are added to main adata object, but normalized and processed object is not saved
if GPU==False:
    adata_tmp = adata.copy()

# %%
if GPU==False:
    adata_tmp = proc.proc(adata_tmp, 'auto', norm=True, scale=True, regress=False, embedding=True)
    sc.pl.umap(adata_tmp, color=groupby)

# %% [markdown]
# ## Add score cell cycle

# %%
if organism=='human':
    fcc =  '/gstore/data/cbfunge/data/CellCycleGenes/Homo_sapiens.csv'
elif organism == 'mouse':
    fcc = '/gstore/data/cbfunge/data/CellCycleGenes/Mus_musculus.csv'
    
if GPU:
    proc.compute_cellCycleScores(RP._adata, fcc)
else:
    proc.compute_cellCycleScores(adata_tmp, fcc)

# %%
RP._adata
# Out:
# AnnData object with n_obs × n_vars = 85186 × 36603
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'qc_pass', 'S_score', 'G2M_score', 'phase'
#     var: 'ID', 'Symbol', 'Type', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: '.internal'
#     layers: 'counts'

# %%
RP.adata
# Out:
# AnnData object with n_obs × n_vars = 31928 × 2000
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'leiden'
#     uns: 'neighbors', 'umap', 'leiden_colors', 'Sample_colors', 'DemuxAssignment_hashing_colors'
#     obsm: 'X_pca', 'X_umap'
#     obsp: 'distances', 'connectivities'

# %%
if GPU==False:
    adata.obs['phase'] = adata_tmp.obs['phase']
    adata.obs['G2M_score'] = adata_tmp.obs['G2M_score']
    adata.obs['S_score'] = adata_tmp.obs['S_score']
    adata.obs

# %%
if GPU==False:
    sc.pl.umap(adata_tmp, color='phase')

# %%
adatas
# Out:
# {'crispr': AnnData object with n_obs × n_vars = 85186 × 20345
#      uns: '.internal'
#      layers: 'counts',
#  'hashing': AnnData object with n_obs × n_vars = 85186 × 19
#      uns: '.internal'
#      layers: 'counts'}

# %%
adatas_updated = adatas.copy()
if GPU:
    adata_updated = RP._adata.copy()
else:
    adata_updated = adata.copy()

# %%
adata_updated
# Out:
# AnnData object with n_obs × n_vars = 85186 × 36603
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'qc_pass', 'S_score', 'G2M_score', 'phase'
#     var: 'ID', 'Symbol', 'Type', 'mt', 'ribo', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts'
#     uns: '.internal'
#     layers: 'counts'

# %%
adatas_updated
# Out:
# {'crispr': AnnData object with n_obs × n_vars = 85186 × 20345
#      uns: '.internal'
#      layers: 'counts',
#  'hashing': AnnData object with n_obs × n_vars = 85186 × 19
#      uns: '.internal'
#      layers: 'counts'}

# %% [markdown]
# ### Write h5ad version on the disk

# %%
# If you wish to write on the disk
#adata_updated.var.index.name = None
#adata_updated.write_h5ad(raw_qc)

# %% [markdown]
# ## Write h5ad file with embedings for Energy Distance analaysis

# %%
if GPU:
    RP.adata_.obsp = RP.adata.obsp.copy()
    RP.adata_.obsm = RP.adata.obsm.copy()
else:
    adata.obsp = adata_tmp.obsp.copy()
    adata.obsm = adata_tmp.obsm.copy()

# %%
if GPU:
    adata_embedding = RP.adata_.copy()
else:
    adata_embedding = adata.copy()

# %%
adata_embedding.write_h5ad(raw_embedding)

# %% [markdown]
# ## Update the dataset with new experiment "raw_qc"

# %%
if DS_test==False:
    dsid, version = DS.update_dataset(New_experiment, adata_updated, adatas_updated, test=False)
else:    
    dsid, version = DS.update_another_dataset(test_DatasetID, True, 1, New_experiment, adata_updated, adatas_updated, test=True)
# Out:
# 09:16:22 -> Collating dataset: 'DS000017729' metadata.
# 09:16:22 -> Retrieving all project: 'DS000017729@1' metadata.
#
# 09:16:22 -> Reading: 'DS000017729'.
#
# 09:16:22 -> Reading: 'DS000017729 -> Experiment: main'.
#
# 09:16:22 -> Reading: 'DS000017729 -> Experiment: main -> Alt. Exp.: crispr'.
# 09:16:22 -> Reading: 'DS000017729 -> Experiment: main -> Alt. Exp.: hashing'.
# PYDSDB:INFO: Experiment already contained metadata, overwriting.
# PYDSDB:INFO: Experiment already contained metadata, overwriting.
# PYDSDB:INFO: Experiment already contained metadata, overwriting.
# Retrieving cached token data.
# Successfully authenticated.
# 09:17:45 -> Retrieving all project: 'DS000017729@latest' metadata.
# 09:17:46 -> Collating and validating project resources.
# 09:17:46 -> Attempting upload.
#   0%|                                        | 0/73 [00:00<?, ?file/s]
#   1%|▌                                       | 1/73 [00:00<00:15,  4.67file/s]
#   4%|█▋                                      | 3/73 [00:00<00:07,  8.90file/s]
#   5%|██▏                                     | 4/73 [00:00<00:09,  6.91file/s]
#   7%|██▋                                     | 5/73 [00:00<00:10,  6.77file/s]
#   8%|███▎                                    | 6/73 [00:00<00:09,  7.23file/s]
#  11%|████▍                                   | 8/73 [00:01<00:07,  8.21file/s]
#  12%|████▉                                   | 9/73 [00:01<00:08,  7.67file/s]
#  15%|██████                                  | 11/73 [00:01<00:07,  8.74file/s]
#  16%|██████▌                                 | 12/73 [00:01<00:06,  8.72file/s]
#  19%|███████▋                                | 14/73 [00:01<00:06,  8.66file/s]
#  21%|████████▏                               | 15/73 [00:02<00:09,  6.20file/s]
#  22%|████████▊                               | 16/73 [00:02<00:08,  6.71file/s]
#  23%|█████████▎                              | 17/73 [00:02<00:07,  7.18file/s]
#  26%|██████████▍                             | 19/73 [00:02<00:07,  7.41file/s]
#  27%|██████████▉                             | 20/73 [00:02<00:06,  7.63file/s]
#  30%|████████████                            | 22/73 [00:02<00:05,  8.78file/s]
#  32%|████████████▌                           | 23/73 [00:07<00:55,  1.12s/file]
