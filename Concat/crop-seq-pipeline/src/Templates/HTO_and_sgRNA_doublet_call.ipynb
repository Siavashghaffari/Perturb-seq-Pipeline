# %% [markdown]
# # QC analysis of single cell barcode dataset: This notebook will guide you through the process of quality control analyis on a single-cell RNA sequencing barcode dataset

# %%
# Parameters
DEV = False
test_DatasetID = ""
DS_test = False
title = "Recursion DLD1 Library4 Screen Day 5- combination of NGS 5570 and NGS 5704"
description = "Production scale screen in DLD-1 cells with 1/4 of the genome-wide CRISPR library (sub-lib-4, ~22K guides). 1 time point: Day-5. We performed 12 rxns of 10x 3' HT kit with an estimated loading of 52K cells.We performed a pilot study to test the library quality before the production-level sequencing(NGS5703). We will submit 36 libraries (12 GEX, 12 HTO and 12 sgRNA) We estimate needing - 600M per GEX, - 20M per HTO and - 50M per sgRNA libraries now that we have analyzed the QC run. This run is to add additional cells needed for analysis."
name_space = [{"id": "GRCh38", "type": "genome"}]
sources = [{"id": "sublib4", "name": "Recursion DLD1"}]
tech_name = "scRNA-seq"
author = "SG"
organism = "human"
experiment = "crispr"
topBarcodesToPlot = 5
bottomBarcodesToPlot = 5
fix_barcodes = False
valid_assignments = None
alt_experiments = ["crispr", "hashing"]

# %%
# Different scenario for original dataset or test dataset

if DS_test==False:
    #DSID = DatasetID
    Version = '4'   # the version of your dataset
else:
    #DSID = test_DatasetID
    Version = '2'   # the version of your dataset
    DEV = True
your_experiment = "crispr_hashing_harmonized"

# %%
if experiment== "hashing":
    columns_1 = ["DemuxType_crispr","DemuxAssignment_crispr"]
    columns_2 = ["DemuxType_hashing","DemuxAssignment_hashing"]
    ALT = "HTO"
else:
    columns_2 = ["DemuxType_crispr","DemuxAssignment_crispr"]
    columns_1 = ["DemuxType_hashing","DemuxAssignment_hashing"]
    ALT = "gRNA"

# %%
out_file = f"/gstore/scratch/u/ghaffars/Dataset/sublib4/{ALT}_complete.h5ad"
OUT = f"/gstore/project/crc_recursion_gw/DLD1_Sublib4/DS000016763/gRNA_HTO_rawcounts/{ALT}_complete.h5ad"

# %%
## Import Libraries
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('talk')
# %matplotlib inline 

#single cell libraries
import anndata as ad 
import pandas as pd
import numpy as np
import scanpy as sc

# %%
import sys
sys.path.append("..")
import Templates.tools.DatasetDB as DB
import Templates.tools.scBarcodeProc as Bproc
import Templates.tools.Barcode_Count_QC as bar

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Instantiate a dataset object given our dataset info

# %%
dsdbs= ['DS000016289','DS000016291','DS000016294','DS000016296','DS000016293',
 'DS000016295','DS000016632', 'DS000016634', 'DS000016633', 'DS000016631']

# %%
adata_s = []

for i in dsdbs:
    DSID = i
    DS = DB.DATASET(DSID, DEV, title=title, description=description, name_space=name_space, organism=organism,
                       sources=sources, tech_name=tech_name, author=author)
    adata, adatas = DS.load_dataset(Version, your_experiment, Corr=False)
    bdata= adata.copy()
    adata = bar.adata_cleaner (adata, adatas, experiment=experiment, fix_barcodes=fix_barcodes,alt_experiments=alt_experiments)
    df = adata.obs.join(bdata.obs[columns_1])
    adata.obs= df.copy()
    adata.obs = adata.obs.rename(columns={"demux_type":columns_2[0],"assignment":columns_2[1]})
    adata_s.append(adata)
# Out:
# 10:21:37 -> Collating dataset: 'DS000016289' metadata.
# 10:21:37 -> Retrieving all project: 'DS000016289@4' metadata.
#
# 10:21:38 -> Reading: 'DS000016289'.
#
# 10:21:38 -> Reading: 'DS000016289 -> Experiment: main'.
#
# 10:21:38 -> Reading: 'DS000016289 -> Experiment: main -> Alt. Exp.: crispr'.
#
# 10:21:38 -> Reading: 'DS000016289 -> Experiment: main -> Alt. Exp.: hashing'.
#
# 10:21:41 -> Reading: 'DS000016289 -> Experiment: crispr_hashing_harmonized'.
#
# 10:21:41 -> Reading: 'DS000016289 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: crispr'.
#
# 10:21:42 -> Reading: 'DS000016289 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: hashing'.
# /gstore/home/ghaffars/.local/lib/python3.10/site-packages/pydsdb/download/utils.py:245: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frame = cast(DataFrame, read_csv(path, **kwargs))
# 10:21:52 -> Collating dataset: 'DS000016291' metadata.
# 10:21:52 -> Retrieving all project: 'DS000016291@4' metadata.
#
# 10:21:52 -> Reading: 'DS000016291'.
#
# 10:21:52 -> Reading: 'DS000016291 -> Experiment: main'.
#
# 10:21:52 -> Reading: 'DS000016291 -> Experiment: main -> Alt. Exp.: crispr'.
#
# 10:21:53 -> Reading: 'DS000016291 -> Experiment: main -> Alt. Exp.: hashing'.
#
# 10:21:56 -> Reading: 'DS000016291 -> Experiment: crispr_hashing_harmonized'.
#
# 10:21:56 -> Reading: 'DS000016291 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: crispr'.
#
# 10:21:56 -> Reading: 'DS000016291 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: hashing'.
# /gstore/home/ghaffars/.local/lib/python3.10/site-packages/pydsdb/download/utils.py:245: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frame = cast(DataFrame, read_csv(path, **kwargs))
# 10:22:07 -> Collating dataset: 'DS000016294' metadata.
# 10:22:07 -> Retrieving all project: 'DS000016294@4' metadata.
#
# 10:22:07 -> Reading: 'DS000016294'.
#
# 10:22:07 -> Reading: 'DS000016294 -> Experiment: main'.
#
# 10:22:07 -> Reading: 'DS000016294 -> Experiment: main -> Alt. Exp.: crispr'.
#
# 10:22:07 -> Reading: 'DS000016294 -> Experiment: main -> Alt. Exp.: hashing'.
#
# 10:22:11 -> Reading: 'DS000016294 -> Experiment: crispr_hashing_harmonized'.
#
# 10:22:11 -> Reading: 'DS000016294 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: crispr'.
#
# 10:22:11 -> Reading: 'DS000016294 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: hashing'.
# /gstore/home/ghaffars/.local/lib/python3.10/site-packages/pydsdb/download/utils.py:245: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frame = cast(DataFrame, read_csv(path, **kwargs))
# 10:22:21 -> Collating dataset: 'DS000016296' metadata.
# 10:22:21 -> Retrieving all project: 'DS000016296@4' metadata.
#
# 10:22:22 -> Reading: 'DS000016296'.
#
# 10:22:22 -> Reading: 'DS000016296 -> Experiment: main'.
#
# 10:22:22 -> Reading: 'DS000016296 -> Experiment: main -> Alt. Exp.: crispr'.
#
# 10:22:22 -> Reading: 'DS000016296 -> Experiment: main -> Alt. Exp.: hashing'.
#
# 10:22:27 -> Reading: 'DS000016296 -> Experiment: crispr_hashing_harmonized'.
#
# 10:22:27 -> Reading: 'DS000016296 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: crispr'.
#
# 10:22:27 -> Reading: 'DS000016296 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: hashing'.
#
# 10:22:37 -> Collating dataset: 'DS000016293' metadata.
# 10:22:37 -> Retrieving all project: 'DS000016293@4' metadata.
#
# 10:22:37 -> Reading: 'DS000016293'.
#
# 10:22:37 -> Reading: 'DS000016293 -> Experiment: main'.
#
# 10:22:37 -> Reading: 'DS000016293 -> Experiment: main -> Alt. Exp.: crispr'.
#
# 10:22:37 -> Reading: 'DS000016293 -> Experiment: main -> Alt. Exp.: hashing'.
#
# 10:22:40 -> Reading: 'DS000016293 -> Experiment: crispr_hashing_harmonized'.
#
# 10:22:40 -> Reading: 'DS000016293 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: crispr'.
#
# 10:22:41 -> Reading: 'DS000016293 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: hashing'.
#
# 10:22:50 -> Collating dataset: 'DS000016295' metadata.
# 10:22:50 -> Retrieving all project: 'DS000016295@4' metadata.
#
# 10:22:50 -> Reading: 'DS000016295'.
#
# 10:22:50 -> Reading: 'DS000016295 -> Experiment: main'.
#
# 10:22:50 -> Reading: 'DS000016295 -> Experiment: main -> Alt. Exp.: crispr'.
#
# 10:22:51 -> Reading: 'DS000016295 -> Experiment: main -> Alt. Exp.: hashing'.
#
# 10:22:54 -> Reading: 'DS000016295 -> Experiment: crispr_hashing_harmonized'.
#
# 10:22:54 -> Reading: 'DS000016295 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: crispr'.
#
# 10:22:54 -> Reading: 'DS000016295 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: hashing'.
#
# 10:23:05 -> Collating dataset: 'DS000016632' metadata.
# 10:23:05 -> Retrieving all project: 'DS000016632@4' metadata.
#
# 10:23:05 -> Reading: 'DS000016632'.
#
# 10:23:05 -> Reading: 'DS000016632 -> Experiment: main'.
#
# 10:23:05 -> Reading: 'DS000016632 -> Experiment: main -> Alt. Exp.: crispr'.
#
# 10:23:06 -> Reading: 'DS000016632 -> Experiment: main -> Alt. Exp.: hashing'.
#
# 10:23:09 -> Reading: 'DS000016632 -> Experiment: crispr_hashing_harmonized'.
#
# 10:23:09 -> Reading: 'DS000016632 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: crispr'.
#
# 10:23:09 -> Reading: 'DS000016632 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: hashing'.
# /gstore/home/ghaffars/.local/lib/python3.10/site-packages/pydsdb/download/utils.py:245: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frame = cast(DataFrame, read_csv(path, **kwargs))
# 10:23:20 -> Collating dataset: 'DS000016634' metadata.
# 10:23:20 -> Retrieving all project: 'DS000016634@4' metadata.
#
# 10:23:20 -> Reading: 'DS000016634'.
#
# 10:23:20 -> Reading: 'DS000016634 -> Experiment: main'.
#
# 10:23:20 -> Reading: 'DS000016634 -> Experiment: main -> Alt. Exp.: crispr'.
#
# 10:23:20 -> Reading: 'DS000016634 -> Experiment: main -> Alt. Exp.: hashing'.
#
# 10:23:24 -> Reading: 'DS000016634 -> Experiment: crispr_hashing_harmonized'.
#
# 10:23:24 -> Reading: 'DS000016634 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: crispr'.
#
# 10:23:24 -> Reading: 'DS000016634 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: hashing'.
#
# 10:23:34 -> Collating dataset: 'DS000016633' metadata.
# 10:23:34 -> Retrieving all project: 'DS000016633@4' metadata.
#
# 10:23:34 -> Reading: 'DS000016633'.
#
# 10:23:34 -> Reading: 'DS000016633 -> Experiment: main'.
#
# 10:23:34 -> Reading: 'DS000016633 -> Experiment: main -> Alt. Exp.: crispr'.
#
# 10:23:35 -> Reading: 'DS000016633 -> Experiment: main -> Alt. Exp.: hashing'.
#
# 10:23:38 -> Reading: 'DS000016633 -> Experiment: crispr_hashing_harmonized'.
#
# 10:23:38 -> Reading: 'DS000016633 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: crispr'.
#
# 10:23:39 -> Reading: 'DS000016633 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: hashing'.
#
# 10:23:50 -> Collating dataset: 'DS000016631' metadata.
# 10:23:50 -> Retrieving all project: 'DS000016631@4' metadata.
#
# 10:23:51 -> Reading: 'DS000016631'.
#
# 10:23:51 -> Reading: 'DS000016631 -> Experiment: main'.
#
# 10:23:51 -> Reading: 'DS000016631 -> Experiment: main -> Alt. Exp.: crispr'.
#
# 10:23:51 -> Reading: 'DS000016631 -> Experiment: main -> Alt. Exp.: hashing'.
#
# 10:23:54 -> Reading: 'DS000016631 -> Experiment: crispr_hashing_harmonized'.
#
# 10:23:54 -> Reading: 'DS000016631 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: crispr'.
#
# 10:23:55 -> Reading: 'DS000016631 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: hashing'.
# /gstore/home/ghaffars/.local/lib/python3.10/site-packages/pydsdb/download/utils.py:245: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frame = cast(DataFrame, read_csv(path, **kwargs))

# %%
adata_s
# Out:
# [AnnData object with n_obs × n_vars = 132704 × 20872
#      obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing'
#      uns: '.internal'
#      layers: 'counts',
#  AnnData object with n_obs × n_vars = 135567 × 20872
#      obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing'
#      uns: '.internal'
#      layers: 'counts',
#  AnnData object with n_obs × n_vars = 136545 × 20872
#      obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing'
#      uns: '.internal'
#      layers: 'counts',
#  AnnData object with n_obs × n_vars = 121068 × 20872
#      obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing'
#      uns: '.internal'
#      layers: 'counts',
#  AnnData object with n_obs × n_vars = 109486 × 20872
#      obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing'
#      uns: '.internal'
#      layers: 'counts',
#  AnnData object with n_obs × n_vars = 126160 × 20872
#      obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing'
#      uns: '.internal'
#      layers: 'counts',
#  AnnData object with n_obs × n_vars = 133055 × 20872
#      obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing'
#      uns: '.internal'
#      layers: 'counts',
#  AnnData object with n_obs × n_vars = 126765 × 20872
#      obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing'
#      uns: '.internal'
#      layers: 'counts',
#  AnnData object with n_obs × n_vars = 129641 × 20872
#      obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing'
#      uns: '.internal'
#      layers: 'counts',
#  AnnData object with n_obs × n_vars = 138283 × 20872
#      obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing'
#      uns: '.internal'
#      layers: 'counts']

# %%
concat = ad.concat(adata_s)

# %%
concat
# Out:
# AnnData object with n_obs × n_vars = 1289274 × 20872
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing'
#     layers: 'counts'

# %%
concat.write_h5ad(out_file)

# %%
concat = sc.read(out_file)

# %%
concat
# Out:
# AnnData object with n_obs × n_vars = 1289274 × 20872
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing'
#     layers: 'counts'

# %% [markdown]
# ## Combine all obs

# %%
df_s = []

for i in dsdbs:
    DSID = i
    DS = DB.DATASET(DSID, DEV, title=title, description=description, name_space=name_space, organism=organism,
                       sources=sources, tech_name=tech_name, author=author)
    adata, adatas = DS.load_dataset(Version, your_experiment, Corr=False)
    df = adata.obs.copy()
    df_s.append(df)
# Out:
# 10:59:37 -> Collating dataset: 'DS000016289' metadata.
# 10:59:37 -> Retrieving all project: 'DS000016289@4' metadata.
#
# 10:59:38 -> Reading: 'DS000016289'.
#
# 10:59:38 -> Reading: 'DS000016289 -> Experiment: main'.
#
# 10:59:38 -> Reading: 'DS000016289 -> Experiment: main -> Alt. Exp.: crispr'.
#
# 10:59:38 -> Reading: 'DS000016289 -> Experiment: main -> Alt. Exp.: hashing'.
#
# 10:59:41 -> Reading: 'DS000016289 -> Experiment: crispr_hashing_harmonized'.
#
# 10:59:41 -> Reading: 'DS000016289 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: crispr'.
#
# 10:59:41 -> Reading: 'DS000016289 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: hashing'.
# /gstore/home/ghaffars/.local/lib/python3.10/site-packages/pydsdb/download/utils.py:245: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frame = cast(DataFrame, read_csv(path, **kwargs))
# 10:59:47 -> Collating dataset: 'DS000016291' metadata.
# 10:59:47 -> Retrieving all project: 'DS000016291@4' metadata.
#
# 10:59:47 -> Reading: 'DS000016291'.
#
# 10:59:47 -> Reading: 'DS000016291 -> Experiment: main'.
#
# 10:59:47 -> Reading: 'DS000016291 -> Experiment: main -> Alt. Exp.: crispr'.
#
# 10:59:48 -> Reading: 'DS000016291 -> Experiment: main -> Alt. Exp.: hashing'.
#
# 10:59:51 -> Reading: 'DS000016291 -> Experiment: crispr_hashing_harmonized'.
#
# 10:59:51 -> Reading: 'DS000016291 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: crispr'.
#
# 10:59:51 -> Reading: 'DS000016291 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: hashing'.
# /gstore/home/ghaffars/.local/lib/python3.10/site-packages/pydsdb/download/utils.py:245: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frame = cast(DataFrame, read_csv(path, **kwargs))
# 10:59:57 -> Collating dataset: 'DS000016294' metadata.
# 10:59:57 -> Retrieving all project: 'DS000016294@4' metadata.
#
# 10:59:57 -> Reading: 'DS000016294'.
#
# 10:59:57 -> Reading: 'DS000016294 -> Experiment: main'.
#
# 10:59:57 -> Reading: 'DS000016294 -> Experiment: main -> Alt. Exp.: crispr'.
#
# 10:59:57 -> Reading: 'DS000016294 -> Experiment: main -> Alt. Exp.: hashing'.
#
# 11:00:01 -> Reading: 'DS000016294 -> Experiment: crispr_hashing_harmonized'.
#
# 11:00:01 -> Reading: 'DS000016294 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: crispr'.
#
# 11:00:01 -> Reading: 'DS000016294 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: hashing'.
# /gstore/home/ghaffars/.local/lib/python3.10/site-packages/pydsdb/download/utils.py:245: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frame = cast(DataFrame, read_csv(path, **kwargs))
# 11:00:07 -> Collating dataset: 'DS000016296' metadata.
# 11:00:07 -> Retrieving all project: 'DS000016296@4' metadata.
#
# 11:00:07 -> Reading: 'DS000016296'.
#
# 11:00:07 -> Reading: 'DS000016296 -> Experiment: main'.
#
# 11:00:07 -> Reading: 'DS000016296 -> Experiment: main -> Alt. Exp.: crispr'.
#
# 11:00:08 -> Reading: 'DS000016296 -> Experiment: main -> Alt. Exp.: hashing'.
#
# 11:00:11 -> Reading: 'DS000016296 -> Experiment: crispr_hashing_harmonized'.
#
# 11:00:11 -> Reading: 'DS000016296 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: crispr'.
#
# 11:00:11 -> Reading: 'DS000016296 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: hashing'.
#
# 11:00:16 -> Collating dataset: 'DS000016293' metadata.
# 11:00:16 -> Retrieving all project: 'DS000016293@4' metadata.
#
# 11:00:17 -> Reading: 'DS000016293'.
#
# 11:00:17 -> Reading: 'DS000016293 -> Experiment: main'.
#
# 11:00:17 -> Reading: 'DS000016293 -> Experiment: main -> Alt. Exp.: crispr'.
#
# 11:00:17 -> Reading: 'DS000016293 -> Experiment: main -> Alt. Exp.: hashing'.
#
# 11:00:20 -> Reading: 'DS000016293 -> Experiment: crispr_hashing_harmonized'.
#
# 11:00:20 -> Reading: 'DS000016293 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: crispr'.
#
# 11:00:20 -> Reading: 'DS000016293 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: hashing'.
#
# 11:00:25 -> Collating dataset: 'DS000016295' metadata.
# 11:00:25 -> Retrieving all project: 'DS000016295@4' metadata.
#
# 11:00:26 -> Reading: 'DS000016295'.
#
# 11:00:26 -> Reading: 'DS000016295 -> Experiment: main'.
#
# 11:00:26 -> Reading: 'DS000016295 -> Experiment: main -> Alt. Exp.: crispr'.
#
# 11:00:26 -> Reading: 'DS000016295 -> Experiment: main -> Alt. Exp.: hashing'.
#
# 11:00:29 -> Reading: 'DS000016295 -> Experiment: crispr_hashing_harmonized'.
#
# 11:00:29 -> Reading: 'DS000016295 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: crispr'.
#
# 11:00:29 -> Reading: 'DS000016295 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: hashing'.
#
# 11:00:35 -> Collating dataset: 'DS000016632' metadata.
# 11:00:35 -> Retrieving all project: 'DS000016632@4' metadata.
#
# 11:00:36 -> Reading: 'DS000016632'.
#
# 11:00:36 -> Reading: 'DS000016632 -> Experiment: main'.
#
# 11:00:36 -> Reading: 'DS000016632 -> Experiment: main -> Alt. Exp.: crispr'.
#
# 11:00:36 -> Reading: 'DS000016632 -> Experiment: main -> Alt. Exp.: hashing'.
#
# 11:00:40 -> Reading: 'DS000016632 -> Experiment: crispr_hashing_harmonized'.
#
# 11:00:40 -> Reading: 'DS000016632 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: crispr'.
#
# 11:00:40 -> Reading: 'DS000016632 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: hashing'.
# /gstore/home/ghaffars/.local/lib/python3.10/site-packages/pydsdb/download/utils.py:245: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frame = cast(DataFrame, read_csv(path, **kwargs))
# 11:00:46 -> Collating dataset: 'DS000016634' metadata.
# 11:00:46 -> Retrieving all project: 'DS000016634@4' metadata.
#
# 11:00:47 -> Reading: 'DS000016634'.
#
# 11:00:47 -> Reading: 'DS000016634 -> Experiment: main'.
#
# 11:00:47 -> Reading: 'DS000016634 -> Experiment: main -> Alt. Exp.: crispr'.
#
# 11:00:47 -> Reading: 'DS000016634 -> Experiment: main -> Alt. Exp.: hashing'.
#
# 11:00:50 -> Reading: 'DS000016634 -> Experiment: crispr_hashing_harmonized'.
#
# 11:00:50 -> Reading: 'DS000016634 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: crispr'.
#
# 11:00:50 -> Reading: 'DS000016634 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: hashing'.
#
# 11:00:56 -> Collating dataset: 'DS000016633' metadata.
# 11:00:56 -> Retrieving all project: 'DS000016633@4' metadata.
#
# 11:00:56 -> Reading: 'DS000016633'.
#
# 11:00:56 -> Reading: 'DS000016633 -> Experiment: main'.
#
# 11:00:56 -> Reading: 'DS000016633 -> Experiment: main -> Alt. Exp.: crispr'.
#
# 11:00:56 -> Reading: 'DS000016633 -> Experiment: main -> Alt. Exp.: hashing'.
#
# 11:01:00 -> Reading: 'DS000016633 -> Experiment: crispr_hashing_harmonized'.
#
# 11:01:00 -> Reading: 'DS000016633 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: crispr'.
#
# 11:01:00 -> Reading: 'DS000016633 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: hashing'.
#
# 11:01:06 -> Collating dataset: 'DS000016631' metadata.
# 11:01:06 -> Retrieving all project: 'DS000016631@4' metadata.
#
# 11:01:06 -> Reading: 'DS000016631'.
#
# 11:01:06 -> Reading: 'DS000016631 -> Experiment: main'.
#
# 11:01:06 -> Reading: 'DS000016631 -> Experiment: main -> Alt. Exp.: crispr'.
#
# 11:01:06 -> Reading: 'DS000016631 -> Experiment: main -> Alt. Exp.: hashing'.
#
# 11:01:09 -> Reading: 'DS000016631 -> Experiment: crispr_hashing_harmonized'.
#
# 11:01:09 -> Reading: 'DS000016631 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: crispr'.
#
# 11:01:10 -> Reading: 'DS000016631 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: hashing'.
# /gstore/home/ghaffars/.local/lib/python3.10/site-packages/pydsdb/download/utils.py:245: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_frame = cast(DataFrame, read_csv(path, **kwargs))

# %%
combine_obs=pd.concat(df_s)

# %%
combine_obs
# Out:
#                                          Sample           Barcode  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   SAM24443678  AAACCCAAGAATTTGG
# SAM24443678_rep1-AAACCCAAGATACCAA   SAM24443678  AAACCCAAGATACCAA
# SAM24443678_rep1-AAACCCAAGCATTTCG   SAM24443678  AAACCCAAGCATTTCG
# SAM24443678_rep1-AAACCCAAGCGACCCT   SAM24443678  AAACCCAAGCGACCCT
# SAM24443678_rep1-AAACCCAAGCGCTGAA   SAM24443678  AAACCCAAGCGCTGAA
# ...                                         ...               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT  SAM24449114  TTTGTTGTCTAGAGCT
# SAM24449114_rep12-TTTGTTGTCTAGTTCT  SAM24449114  TTTGTTGTCTAGTTCT
# SAM24449114_rep12-TTTGTTGTCTCAACCC  SAM24449114  TTTGTTGTCTCAACCC
# SAM24449114_rep12-TTTGTTGTCTGGACCG  SAM24449114  TTTGTTGTCTGGACCG
# SAM24449114_rep12-TTTGTTGTCTTAATCC  SAM24449114  TTTGTTGTCTTAATCC
#
#                                    DemuxType_crispr  \
# SAM24443678_rep1-AAACCCAAGAATTTGG           doublet
# SAM24443678_rep1-AAACCCAAGATACCAA           doublet
# SAM24443678_rep1-AAACCCAAGCATTTCG           doublet
# SAM24443678_rep1-AAACCCAAGCGACCCT           unknown
# SAM24443678_rep1-AAACCCAAGCGCTGAA           unknown
# ...                                             ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT          unknown
# SAM24449114_rep12-TTTGTTGTCTAGTTCT          unknown
# SAM24449114_rep12-TTTGTTGTCTCAACCC          unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG          unknown
# SAM24449114_rep12-TTTGTTGTCTTAATCC          unknown
#
#                                                                DemuxAssignment_crispr  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   ENSG00000104936_3,ENSG00000184545_1,ENSG000001...
# SAM24443678_rep1-AAACCCAAGATACCAA                 ENSG00000065320_1,ENSG00000144824_1
# SAM24443678_rep1-AAACCCAAGCATTTCG                 ENSG00000104290_1,ENSG00000128218_1
# SAM24443678_rep1-AAACCCAAGCGACCCT                                             unknown
# SAM24443678_rep1-AAACCCAAGCGCTGAA                                             unknown
# ...                                                                               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTAGTTCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTCAACCC                                            unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG                                            unknown
# SAM24449114_rep12-TTTGTTGTCTTAATCC                                            unknown
#
#                                    DemuxType_hashing DemuxAssignment_hashing  \
# SAM24443678_rep1-AAACCCAAGAATTTGG            singlet             SAM24439044
# SAM24443678_rep1-AAACCCAAGATACCAA            singlet             SAM24439043
# SAM24443678_rep1-AAACCCAAGCATTTCG            singlet             SAM24439043
# SAM24443678_rep1-AAACCCAAGCGACCCT            singlet             SAM24439043
# SAM24443678_rep1-AAACCCAAGCGCTGAA            singlet             SAM24439043
# ...                                              ...                     ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT           singlet             SAM24439044
# SAM24449114_rep12-TTTGTTGTCTAGTTCT           singlet             SAM24439044
# SAM24449114_rep12-TTTGTTGTCTCAACCC           unknown                 unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG           singlet             SAM24439044
# SAM24449114_rep12-TTTGTTGTCTTAATCC           doublet            HTO-10,HTO-7
#
#                                         cellline     timepoint           HTO  \
# SAM24443678_rep1-AAACCCAAGAATTTGG           DLD1          day5        HTO-14
# SAM24443678_rep1-AAACCCAAGATACCAA           DLD1          day5        HTO-10
# SAM24443678_rep1-AAACCCAAGCATTTCG           DLD1          day5         HTO-3
# SAM24443678_rep1-AAACCCAAGCGACCCT           DLD1          day5        HTO-10
# SAM24443678_rep1-AAACCCAAGCGCTGAA           DLD1          day5         HTO-2
# ...                                          ...           ...           ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT          DLD1          day5        HTO-15
# SAM24449114_rep12-TTTGTTGTCTAGTTCT          DLD1          day5        HTO-14
# SAM24449114_rep12-TTTGTTGTCTCAACCC       unknown       unknown       unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG          DLD1          day5         HTO-5
# SAM24449114_rep12-TTTGTTGTCTTAATCC  HTO-10,HTO-7  HTO-10,HTO-7  HTO-10,HTO-7
#
#                                           NGS_ID Biological_replicate 10Xrun  \
# SAM24443678_rep1-AAACCCAAGAATTTGG        NGS5569          REPLICATE_2      1
# SAM24443678_rep1-AAACCCAAGATACCAA        NGS5569          REPLICATE_1      1
# SAM24443678_rep1-AAACCCAAGCATTTCG        NGS5569          REPLICATE_1      1
# SAM24443678_rep1-AAACCCAAGCGACCCT        NGS5569          REPLICATE_1      1
# SAM24443678_rep1-AAACCCAAGCGCTGAA        NGS5569          REPLICATE_1      1
# ...                                          ...                  ...    ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT       NGS5704          REPLICATE_2     12
# SAM24449114_rep12-TTTGTTGTCTAGTTCT       NGS5704          REPLICATE_2     12
# SAM24449114_rep12-TTTGTTGTCTCAACCC       unknown              unknown     12
# SAM24449114_rep12-TTTGTTGTCTGGACCG       NGS5704          REPLICATE_2     12
# SAM24449114_rep12-TTTGTTGTCTTAATCC  HTO-10,HTO-7         HTO-10,HTO-7     12
#
#                                                                            sublibrary  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24443678_rep1-AAACCCAAGATACCAA   GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24443678_rep1-AAACCCAAGCATTTCG   GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24443678_rep1-AAACCCAAGCGACCCT   GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24443678_rep1-AAACCCAAGCGCTGAA   GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# ...                                                                               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT  GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24449114_rep12-TTTGTTGTCTAGTTCT  GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24449114_rep12-TTTGTTGTCTCAACCC                                            unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG  GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24449114_rep12-TTTGTTGTCTTAATCC                                       HTO-10,HTO-7
#
#                                    gRNA_library_MOI  \
# SAM24443678_rep1-AAACCCAAGAATTTGG               0.4
# SAM24443678_rep1-AAACCCAAGATACCAA               0.4
# SAM24443678_rep1-AAACCCAAGCATTTCG               0.4
# SAM24443678_rep1-AAACCCAAGCGACCCT               0.4
# SAM24443678_rep1-AAACCCAAGCGCTGAA               0.4
# ...                                             ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT              0.4
# SAM24449114_rep12-TTTGTTGTCTAGTTCT              0.4
# SAM24449114_rep12-TTTGTTGTCTCAACCC          unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG              0.4
# SAM24449114_rep12-TTTGTTGTCTTAATCC     HTO-10,HTO-7
#
#                                                                           gene_symbol  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   ENSG00000104936_3,ENSG00000184545_1,ENSG000001...
# SAM24443678_rep1-AAACCCAAGATACCAA                 ENSG00000065320_1,ENSG00000144824_1
# SAM24443678_rep1-AAACCCAAGCATTTCG                 ENSG00000104290_1,ENSG00000128218_1
# SAM24443678_rep1-AAACCCAAGCGACCCT                                             unknown
# SAM24443678_rep1-AAACCCAAGCGCTGAA                                             unknown
# ...                                                                               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTAGTTCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTCAACCC                                            unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG                                            unknown
# SAM24449114_rep12-TTTGTTGTCTTAATCC                                            unknown
#
#                                                                                 class
# SAM24443678_rep1-AAACCCAAGAATTTGG   ENSG00000104936_3,ENSG00000184545_1,ENSG000001...
# SAM24443678_rep1-AAACCCAAGATACCAA                 ENSG00000065320_1,ENSG00000144824_1
# SAM24443678_rep1-AAACCCAAGCATTTCG                 ENSG00000104290_1,ENSG00000128218_1
# SAM24443678_rep1-AAACCCAAGCGACCCT                                             unknown
# SAM24443678_rep1-AAACCCAAGCGCTGAA                                             unknown
# ...                                                                               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTAGTTCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTCAACCC                                            unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG                                            unknown
# SAM24449114_rep12-TTTGTTGTCTTAATCC                                            unknown
#
# [1289274 rows x 16 columns]

# %%
QC = sc.read("/gstore/scratch/u/ghaffars/Dataset/sublib4/raw_qc.h5ad")

# %%
QC
# Out:
# AnnData object with n_obs × n_vars = 446413 × 36603
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'qc_pass', 'S_score', 'G2M_score', 'phase', 'SCN_class'
#     var: 'Symbol'
#     layers: 'counts'

# %%
combine_obs["qc_pass"] = combine_obs.index.isin(QC.obs.index)

# %%
combine_obs["NGS_ID"]=combine_obs["NGS_ID"].replace("NGS5569","NGS5570")

# %%
combine_obs['gene_symbol'] = np.where(combine_obs['gene_symbol']=='unknown', 
                                    combine_obs['DemuxAssignment_crispr'].apply(lambda x:x.split('_')[0]),combine_obs['gene_symbol'])

# %%
combine_obs
# Out:
#                                          Sample           Barcode  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   SAM24443678  AAACCCAAGAATTTGG
# SAM24443678_rep1-AAACCCAAGATACCAA   SAM24443678  AAACCCAAGATACCAA
# SAM24443678_rep1-AAACCCAAGCATTTCG   SAM24443678  AAACCCAAGCATTTCG
# SAM24443678_rep1-AAACCCAAGCGACCCT   SAM24443678  AAACCCAAGCGACCCT
# SAM24443678_rep1-AAACCCAAGCGCTGAA   SAM24443678  AAACCCAAGCGCTGAA
# ...                                         ...               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT  SAM24449114  TTTGTTGTCTAGAGCT
# SAM24449114_rep12-TTTGTTGTCTAGTTCT  SAM24449114  TTTGTTGTCTAGTTCT
# SAM24449114_rep12-TTTGTTGTCTCAACCC  SAM24449114  TTTGTTGTCTCAACCC
# SAM24449114_rep12-TTTGTTGTCTGGACCG  SAM24449114  TTTGTTGTCTGGACCG
# SAM24449114_rep12-TTTGTTGTCTTAATCC  SAM24449114  TTTGTTGTCTTAATCC
#
#                                    DemuxType_crispr  \
# SAM24443678_rep1-AAACCCAAGAATTTGG           doublet
# SAM24443678_rep1-AAACCCAAGATACCAA           doublet
# SAM24443678_rep1-AAACCCAAGCATTTCG           doublet
# SAM24443678_rep1-AAACCCAAGCGACCCT           unknown
# SAM24443678_rep1-AAACCCAAGCGCTGAA           unknown
# ...                                             ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT          unknown
# SAM24449114_rep12-TTTGTTGTCTAGTTCT          unknown
# SAM24449114_rep12-TTTGTTGTCTCAACCC          unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG          unknown
# SAM24449114_rep12-TTTGTTGTCTTAATCC          unknown
#
#                                                                DemuxAssignment_crispr  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   ENSG00000104936_3,ENSG00000184545_1,ENSG000001...
# SAM24443678_rep1-AAACCCAAGATACCAA                 ENSG00000065320_1,ENSG00000144824_1
# SAM24443678_rep1-AAACCCAAGCATTTCG                 ENSG00000104290_1,ENSG00000128218_1
# SAM24443678_rep1-AAACCCAAGCGACCCT                                             unknown
# SAM24443678_rep1-AAACCCAAGCGCTGAA                                             unknown
# ...                                                                               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTAGTTCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTCAACCC                                            unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG                                            unknown
# SAM24449114_rep12-TTTGTTGTCTTAATCC                                            unknown
#
#                                    DemuxType_hashing DemuxAssignment_hashing  \
# SAM24443678_rep1-AAACCCAAGAATTTGG            singlet             SAM24439044
# SAM24443678_rep1-AAACCCAAGATACCAA            singlet             SAM24439043
# SAM24443678_rep1-AAACCCAAGCATTTCG            singlet             SAM24439043
# SAM24443678_rep1-AAACCCAAGCGACCCT            singlet             SAM24439043
# SAM24443678_rep1-AAACCCAAGCGCTGAA            singlet             SAM24439043
# ...                                              ...                     ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT           singlet             SAM24439044
# SAM24449114_rep12-TTTGTTGTCTAGTTCT           singlet             SAM24439044
# SAM24449114_rep12-TTTGTTGTCTCAACCC           unknown                 unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG           singlet             SAM24439044
# SAM24449114_rep12-TTTGTTGTCTTAATCC           doublet            HTO-10,HTO-7
#
#                                         cellline     timepoint           HTO  \
# SAM24443678_rep1-AAACCCAAGAATTTGG           DLD1          day5        HTO-14
# SAM24443678_rep1-AAACCCAAGATACCAA           DLD1          day5        HTO-10
# SAM24443678_rep1-AAACCCAAGCATTTCG           DLD1          day5         HTO-3
# SAM24443678_rep1-AAACCCAAGCGACCCT           DLD1          day5        HTO-10
# SAM24443678_rep1-AAACCCAAGCGCTGAA           DLD1          day5         HTO-2
# ...                                          ...           ...           ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT          DLD1          day5        HTO-15
# SAM24449114_rep12-TTTGTTGTCTAGTTCT          DLD1          day5        HTO-14
# SAM24449114_rep12-TTTGTTGTCTCAACCC       unknown       unknown       unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG          DLD1          day5         HTO-5
# SAM24449114_rep12-TTTGTTGTCTTAATCC  HTO-10,HTO-7  HTO-10,HTO-7  HTO-10,HTO-7
#
#                                           NGS_ID Biological_replicate 10Xrun  \
# SAM24443678_rep1-AAACCCAAGAATTTGG        NGS5570          REPLICATE_2      1
# SAM24443678_rep1-AAACCCAAGATACCAA        NGS5570          REPLICATE_1      1
# SAM24443678_rep1-AAACCCAAGCATTTCG        NGS5570          REPLICATE_1      1
# SAM24443678_rep1-AAACCCAAGCGACCCT        NGS5570          REPLICATE_1      1
# SAM24443678_rep1-AAACCCAAGCGCTGAA        NGS5570          REPLICATE_1      1
# ...                                          ...                  ...    ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT       NGS5704          REPLICATE_2     12
# SAM24449114_rep12-TTTGTTGTCTAGTTCT       NGS5704          REPLICATE_2     12
# SAM24449114_rep12-TTTGTTGTCTCAACCC       unknown              unknown     12
# SAM24449114_rep12-TTTGTTGTCTGGACCG       NGS5704          REPLICATE_2     12
# SAM24449114_rep12-TTTGTTGTCTTAATCC  HTO-10,HTO-7         HTO-10,HTO-7     12
#
#                                                                            sublibrary  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24443678_rep1-AAACCCAAGATACCAA   GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24443678_rep1-AAACCCAAGCATTTCG   GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24443678_rep1-AAACCCAAGCGACCCT   GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24443678_rep1-AAACCCAAGCGCTGAA   GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# ...                                                                               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT  GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24449114_rep12-TTTGTTGTCTAGTTCT  GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24449114_rep12-TTTGTTGTCTCAACCC                                            unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG  GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24449114_rep12-TTTGTTGTCTTAATCC                                       HTO-10,HTO-7
#
#                                    gRNA_library_MOI  \
# SAM24443678_rep1-AAACCCAAGAATTTGG               0.4
# SAM24443678_rep1-AAACCCAAGATACCAA               0.4
# SAM24443678_rep1-AAACCCAAGCATTTCG               0.4
# SAM24443678_rep1-AAACCCAAGCGACCCT               0.4
# SAM24443678_rep1-AAACCCAAGCGCTGAA               0.4
# ...                                             ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT              0.4
# SAM24449114_rep12-TTTGTTGTCTAGTTCT              0.4
# SAM24449114_rep12-TTTGTTGTCTCAACCC          unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG              0.4
# SAM24449114_rep12-TTTGTTGTCTTAATCC     HTO-10,HTO-7
#
#                                                                           gene_symbol  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   ENSG00000104936_3,ENSG00000184545_1,ENSG000001...
# SAM24443678_rep1-AAACCCAAGATACCAA                 ENSG00000065320_1,ENSG00000144824_1
# SAM24443678_rep1-AAACCCAAGCATTTCG                 ENSG00000104290_1,ENSG00000128218_1
# SAM24443678_rep1-AAACCCAAGCGACCCT                                             unknown
# SAM24443678_rep1-AAACCCAAGCGCTGAA                                             unknown
# ...                                                                               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTAGTTCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTCAACCC                                            unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG                                            unknown
# SAM24449114_rep12-TTTGTTGTCTTAATCC                                            unknown
#
#                                                                                 class  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   ENSG00000104936_3,ENSG00000184545_1,ENSG000001...
# SAM24443678_rep1-AAACCCAAGATACCAA                 ENSG00000065320_1,ENSG00000144824_1
# SAM24443678_rep1-AAACCCAAGCATTTCG                 ENSG00000104290_1,ENSG00000128218_1
# SAM24443678_rep1-AAACCCAAGCGACCCT                                             unknown
# SAM24443678_rep1-AAACCCAAGCGCTGAA                                             unknown
# ...                                                                               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTAGTTCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTCAACCC                                            unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG                                            unknown
# SAM24449114_rep12-TTTGTTGTCTTAATCC                                            unknown
#
#                                     qc_pass
# SAM24443678_rep1-AAACCCAAGAATTTGG     False
# SAM24443678_rep1-AAACCCAAGATACCAA     False
# SAM24443678_rep1-AAACCCAAGCATTTCG     False
# SAM24443678_rep1-AAACCCAAGCGACCCT     False
# SAM24443678_rep1-AAACCCAAGCGCTGAA     False
# ...                                     ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT    False
# SAM24449114_rep12-TTTGTTGTCTAGTTCT    False
# SAM24449114_rep12-TTTGTTGTCTCAACCC    False
# SAM24449114_rep12-TTTGTTGTCTGGACCG    False
# SAM24449114_rep12-TTTGTTGTCTTAATCC    False
#
# [1289274 rows x 17 columns]

# %%
combine_obs.to_csv("/gstore/project/crc_recursion_2/CellInfo_DLD1_day5/DLD1_sublib4_allCells_info.csv")

# %%
obs = pd.read_csv("/gstore/project/crc_recursion_2/CellInfo_DLD1_day5/DLD1_sublib4_allCells_info.csv",index_col=0)

# %%
concat.obs
# Out:
#                                          Sample           Barcode  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   SAM24443678  AAACCCAAGAATTTGG
# SAM24443678_rep1-AAACCCAAGATACCAA   SAM24443678  AAACCCAAGATACCAA
# SAM24443678_rep1-AAACCCAAGCATTTCG   SAM24443678  AAACCCAAGCATTTCG
# SAM24443678_rep1-AAACCCAAGCGACCCT   SAM24443678  AAACCCAAGCGACCCT
# SAM24443678_rep1-AAACCCAAGCGCTGAA   SAM24443678  AAACCCAAGCGCTGAA
# ...                                         ...               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT  SAM24449114  TTTGTTGTCTAGAGCT
# SAM24449114_rep12-TTTGTTGTCTAGTTCT  SAM24449114  TTTGTTGTCTAGTTCT
# SAM24449114_rep12-TTTGTTGTCTCAACCC  SAM24449114  TTTGTTGTCTCAACCC
# SAM24449114_rep12-TTTGTTGTCTGGACCG  SAM24449114  TTTGTTGTCTGGACCG
# SAM24449114_rep12-TTTGTTGTCTTAATCC  SAM24449114  TTTGTTGTCTTAATCC
#
#                                    DemuxType_crispr  \
# SAM24443678_rep1-AAACCCAAGAATTTGG           doublet
# SAM24443678_rep1-AAACCCAAGATACCAA           doublet
# SAM24443678_rep1-AAACCCAAGCATTTCG           doublet
# SAM24443678_rep1-AAACCCAAGCGACCCT           unknown
# SAM24443678_rep1-AAACCCAAGCGCTGAA           unknown
# ...                                             ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT          unknown
# SAM24449114_rep12-TTTGTTGTCTAGTTCT          unknown
# SAM24449114_rep12-TTTGTTGTCTCAACCC          unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG          unknown
# SAM24449114_rep12-TTTGTTGTCTTAATCC          unknown
#
#                                                                DemuxAssignment_crispr  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   ENSG00000104936_3,ENSG00000184545_1,ENSG000001...
# SAM24443678_rep1-AAACCCAAGATACCAA                 ENSG00000065320_1,ENSG00000144824_1
# SAM24443678_rep1-AAACCCAAGCATTTCG                 ENSG00000104290_1,ENSG00000128218_1
# SAM24443678_rep1-AAACCCAAGCGACCCT                                             unknown
# SAM24443678_rep1-AAACCCAAGCGCTGAA                                             unknown
# ...                                                                               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTAGTTCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTCAACCC                                            unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG                                            unknown
# SAM24449114_rep12-TTTGTTGTCTTAATCC                                            unknown
#
#                                    DemuxType_hashing DemuxAssignment_hashing
# SAM24443678_rep1-AAACCCAAGAATTTGG            singlet             SAM24439044
# SAM24443678_rep1-AAACCCAAGATACCAA            singlet             SAM24439043
# SAM24443678_rep1-AAACCCAAGCATTTCG            singlet             SAM24439043
# SAM24443678_rep1-AAACCCAAGCGACCCT            singlet             SAM24439043
# SAM24443678_rep1-AAACCCAAGCGCTGAA            singlet             SAM24439043
# ...                                              ...                     ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT           singlet             SAM24439044
# SAM24449114_rep12-TTTGTTGTCTAGTTCT           singlet             SAM24439044
# SAM24449114_rep12-TTTGTTGTCTCAACCC           unknown                 unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG           singlet             SAM24439044
# SAM24449114_rep12-TTTGTTGTCTTAATCC           doublet            HTO-10,HTO-7
#
# [1289274 rows x 6 columns]

# %%
obs
# Out:
#                                          Sample           Barcode  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   SAM24443678  AAACCCAAGAATTTGG
# SAM24443678_rep1-AAACCCAAGATACCAA   SAM24443678  AAACCCAAGATACCAA
# SAM24443678_rep1-AAACCCAAGCATTTCG   SAM24443678  AAACCCAAGCATTTCG
# SAM24443678_rep1-AAACCCAAGCGACCCT   SAM24443678  AAACCCAAGCGACCCT
# SAM24443678_rep1-AAACCCAAGCGCTGAA   SAM24443678  AAACCCAAGCGCTGAA
# ...                                         ...               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT  SAM24449114  TTTGTTGTCTAGAGCT
# SAM24449114_rep12-TTTGTTGTCTAGTTCT  SAM24449114  TTTGTTGTCTAGTTCT
# SAM24449114_rep12-TTTGTTGTCTCAACCC  SAM24449114  TTTGTTGTCTCAACCC
# SAM24449114_rep12-TTTGTTGTCTGGACCG  SAM24449114  TTTGTTGTCTGGACCG
# SAM24449114_rep12-TTTGTTGTCTTAATCC  SAM24449114  TTTGTTGTCTTAATCC
#
#                                    DemuxType_crispr  \
# SAM24443678_rep1-AAACCCAAGAATTTGG           doublet
# SAM24443678_rep1-AAACCCAAGATACCAA           doublet
# SAM24443678_rep1-AAACCCAAGCATTTCG           doublet
# SAM24443678_rep1-AAACCCAAGCGACCCT           unknown
# SAM24443678_rep1-AAACCCAAGCGCTGAA           unknown
# ...                                             ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT          unknown
# SAM24449114_rep12-TTTGTTGTCTAGTTCT          unknown
# SAM24449114_rep12-TTTGTTGTCTCAACCC          unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG          unknown
# SAM24449114_rep12-TTTGTTGTCTTAATCC          unknown
#
#                                                                DemuxAssignment_crispr  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   ENSG00000104936_3,ENSG00000184545_1,ENSG000001...
# SAM24443678_rep1-AAACCCAAGATACCAA                 ENSG00000065320_1,ENSG00000144824_1
# SAM24443678_rep1-AAACCCAAGCATTTCG                 ENSG00000104290_1,ENSG00000128218_1
# SAM24443678_rep1-AAACCCAAGCGACCCT                                             unknown
# SAM24443678_rep1-AAACCCAAGCGCTGAA                                             unknown
# ...                                                                               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTAGTTCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTCAACCC                                            unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG                                            unknown
# SAM24449114_rep12-TTTGTTGTCTTAATCC                                            unknown
#
#                                    DemuxType_hashing DemuxAssignment_hashing  \
# SAM24443678_rep1-AAACCCAAGAATTTGG            singlet             SAM24439044
# SAM24443678_rep1-AAACCCAAGATACCAA            singlet             SAM24439043
# SAM24443678_rep1-AAACCCAAGCATTTCG            singlet             SAM24439043
# SAM24443678_rep1-AAACCCAAGCGACCCT            singlet             SAM24439043
# SAM24443678_rep1-AAACCCAAGCGCTGAA            singlet             SAM24439043
# ...                                              ...                     ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT           singlet             SAM24439044
# SAM24449114_rep12-TTTGTTGTCTAGTTCT           singlet             SAM24439044
# SAM24449114_rep12-TTTGTTGTCTCAACCC           unknown                 unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG           singlet             SAM24439044
# SAM24449114_rep12-TTTGTTGTCTTAATCC           doublet            HTO-10,HTO-7
#
#                                         cellline     timepoint           HTO  \
# SAM24443678_rep1-AAACCCAAGAATTTGG           DLD1          day5        HTO-14
# SAM24443678_rep1-AAACCCAAGATACCAA           DLD1          day5        HTO-10
# SAM24443678_rep1-AAACCCAAGCATTTCG           DLD1          day5         HTO-3
# SAM24443678_rep1-AAACCCAAGCGACCCT           DLD1          day5        HTO-10
# SAM24443678_rep1-AAACCCAAGCGCTGAA           DLD1          day5         HTO-2
# ...                                          ...           ...           ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT          DLD1          day5        HTO-15
# SAM24449114_rep12-TTTGTTGTCTAGTTCT          DLD1          day5        HTO-14
# SAM24449114_rep12-TTTGTTGTCTCAACCC       unknown       unknown       unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG          DLD1          day5         HTO-5
# SAM24449114_rep12-TTTGTTGTCTTAATCC  HTO-10,HTO-7  HTO-10,HTO-7  HTO-10,HTO-7
#
#                                           NGS_ID Biological_replicate  10Xrun  \
# SAM24443678_rep1-AAACCCAAGAATTTGG        NGS5570          REPLICATE_2       1
# SAM24443678_rep1-AAACCCAAGATACCAA        NGS5570          REPLICATE_1       1
# SAM24443678_rep1-AAACCCAAGCATTTCG        NGS5570          REPLICATE_1       1
# SAM24443678_rep1-AAACCCAAGCGACCCT        NGS5570          REPLICATE_1       1
# SAM24443678_rep1-AAACCCAAGCGCTGAA        NGS5570          REPLICATE_1       1
# ...                                          ...                  ...     ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT       NGS5704          REPLICATE_2      12
# SAM24449114_rep12-TTTGTTGTCTAGTTCT       NGS5704          REPLICATE_2      12
# SAM24449114_rep12-TTTGTTGTCTCAACCC       unknown              unknown      12
# SAM24449114_rep12-TTTGTTGTCTGGACCG       NGS5704          REPLICATE_2      12
# SAM24449114_rep12-TTTGTTGTCTTAATCC  HTO-10,HTO-7         HTO-10,HTO-7      12
#
#                                                                            sublibrary  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24443678_rep1-AAACCCAAGATACCAA   GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24443678_rep1-AAACCCAAGCATTTCG   GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24443678_rep1-AAACCCAAGCGACCCT   GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24443678_rep1-AAACCCAAGCGCTGAA   GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# ...                                                                               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT  GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24449114_rep12-TTTGTTGTCTAGTTCT  GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24449114_rep12-TTTGTTGTCTCAACCC                                            unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG  GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24449114_rep12-TTTGTTGTCTTAATCC                                       HTO-10,HTO-7
#
#                                    gRNA_library_MOI  \
# SAM24443678_rep1-AAACCCAAGAATTTGG               0.4
# SAM24443678_rep1-AAACCCAAGATACCAA               0.4
# SAM24443678_rep1-AAACCCAAGCATTTCG               0.4
# SAM24443678_rep1-AAACCCAAGCGACCCT               0.4
# SAM24443678_rep1-AAACCCAAGCGCTGAA               0.4
# ...                                             ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT              0.4
# SAM24449114_rep12-TTTGTTGTCTAGTTCT              0.4
# SAM24449114_rep12-TTTGTTGTCTCAACCC          unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG              0.4
# SAM24449114_rep12-TTTGTTGTCTTAATCC     HTO-10,HTO-7
#
#                                                                           gene_symbol  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   ENSG00000104936_3,ENSG00000184545_1,ENSG000001...
# SAM24443678_rep1-AAACCCAAGATACCAA                 ENSG00000065320_1,ENSG00000144824_1
# SAM24443678_rep1-AAACCCAAGCATTTCG                 ENSG00000104290_1,ENSG00000128218_1
# SAM24443678_rep1-AAACCCAAGCGACCCT                                             unknown
# SAM24443678_rep1-AAACCCAAGCGCTGAA                                             unknown
# ...                                                                               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTAGTTCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTCAACCC                                            unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG                                            unknown
# SAM24449114_rep12-TTTGTTGTCTTAATCC                                            unknown
#
#                                                                                 class  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   ENSG00000104936_3,ENSG00000184545_1,ENSG000001...
# SAM24443678_rep1-AAACCCAAGATACCAA                 ENSG00000065320_1,ENSG00000144824_1
# SAM24443678_rep1-AAACCCAAGCATTTCG                 ENSG00000104290_1,ENSG00000128218_1
# SAM24443678_rep1-AAACCCAAGCGACCCT                                             unknown
# SAM24443678_rep1-AAACCCAAGCGCTGAA                                             unknown
# ...                                                                               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTAGTTCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTCAACCC                                            unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG                                            unknown
# SAM24449114_rep12-TTTGTTGTCTTAATCC                                            unknown
#
#                                     qc_pass
# SAM24443678_rep1-AAACCCAAGAATTTGG     False
# SAM24443678_rep1-AAACCCAAGATACCAA     False
# SAM24443678_rep1-AAACCCAAGCATTTCG     False
# SAM24443678_rep1-AAACCCAAGCGACCCT     False
# SAM24443678_rep1-AAACCCAAGCGCTGAA     False
# ...                                     ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT    False
# SAM24449114_rep12-TTTGTTGTCTAGTTCT    False
# SAM24449114_rep12-TTTGTTGTCTCAACCC    False
# SAM24449114_rep12-TTTGTTGTCTGGACCG    False
# SAM24449114_rep12-TTTGTTGTCTTAATCC    False
#
# [1289274 rows x 17 columns]

# %%
df = concat.obs.copy()

# %%
df.index
# Out:
# Index(['SAM24443678_rep1-AAACCCAAGAATTTGG',
#        'SAM24443678_rep1-AAACCCAAGATACCAA',
#        'SAM24443678_rep1-AAACCCAAGCATTTCG',
#        'SAM24443678_rep1-AAACCCAAGCGACCCT',
#        'SAM24443678_rep1-AAACCCAAGCGCTGAA',
#        'SAM24443678_rep1-AAACCCAAGCTTCGTA',
#        'SAM24443678_rep1-AAACCCAAGGAATCGC',
#        'SAM24443678_rep1-AAACCCAAGGATACAT',
#        'SAM24443678_rep1-AAACCCAAGTCTTCCC',
#        'SAM24443678_rep1-AAACCCACACAGCTGC',
#        ...
#        'SAM24449114_rep12-TTTGTTGTCCAAGCAT',
#        'SAM24449114_rep12-TTTGTTGTCCATCTCG',
#        'SAM24449114_rep12-TTTGTTGTCCGGCTTT',
#        'SAM24449114_rep12-TTTGTTGTCCGTGGCA',
#        'SAM24449114_rep12-TTTGTTGTCTAGACCA',
#        'SAM24449114_rep12-TTTGTTGTCTAGAGCT',
#        'SAM24449114_rep12-TTTGTTGTCTAGTTCT',
#        'SAM24449114_rep12-TTTGTTGTCTCAACCC',
#        'SAM24449114_rep12-TTTGTTGTCTGGACCG',
#        'SAM24449114_rep12-TTTGTTGTCTTAATCC'],
#       dtype='object', length=1289274)

# %%
df.columns
# Out:
# Index(['Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr',
#        'DemuxType_hashing', 'DemuxAssignment_hashing'],
#       dtype='object')

# %%
df = df.drop(columns=['Sample', 'Barcode', 'DemuxType_hashing', 'DemuxAssignment_hashing',
       'DemuxType_crispr', 'DemuxAssignment_crispr'])

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: [SAM24443678_rep1-AAACCCAAGAATTTGG, SAM24443678_rep1-AAACCCAAGATACCAA, SAM24443678_rep1-AAACCCAAGCATTTCG, SAM24443678_rep1-AAACCCAAGCGACCCT, SAM24443678_rep1-AAACCCAAGCGCTGAA, SAM24443678_rep1-AAACCCAAGCTTCGTA, SAM24443678_rep1-AAACCCAAGGAATCGC, SAM24443678_rep1-AAACCCAAGGATACAT, SAM24443678_rep1-AAACCCAAGTCTTCCC, SAM24443678_rep1-AAACCCACACAGCTGC, SAM24443678_rep1-AAACCCACATGAATAG, SAM24443678_rep1-AAACCCACATGATAGA, SAM24443678_rep1-AAACCCAGTAGAGTTA, SAM24443678_rep1-AAACCCAGTGATGGCA, SAM24443678_rep1-AAACCCAGTGGCTAGA, SAM24443678_rep1-AAACCCAGTTGGCTAT, SAM24443678_rep1-AAACCCATCACGGACC, SAM24443678_rep1-AAACCCATCCGGACTG, SAM24443678_rep1-AAACCCATCGACCATA, SAM24443678_rep1-AAACCCATCGCGTGAC, SAM24443678_rep1-AAACCCATCGGAGCAA, SAM24443678_rep1-AAACCCATCTGAGGCC, SAM24443678_rep1-AAACGAAAGAAGCGGG, SAM24443678_rep1-AAACGAAAGACCAAAT, SAM24443678_rep1-AAACGAAAGCGTTACT, SAM24443678_rep1-AAACGAAAGGCCGCTT, SAM24443678_rep1-AAACGAAAGGTGATCG, SAM24443678_rep1-AAACGAAAGTACAGCG, SAM24443678_rep1-AAACGAACACGGATCC, SAM24443678_rep1-AAACGAACAGCCCAGT, SAM24443678_rep1-AAACGAACATGTTACG, SAM24443678_rep1-AAACGAACATTCGATG, SAM24443678_rep1-AAACGAAGTCACCTTC, SAM24443678_rep1-AAACGAAGTGAGATCG, SAM24443678_rep1-AAACGAAGTGAGATTA, SAM24443678_rep1-AAACGAAGTTGGATCT, SAM24443678_rep1-AAACGAATCAGGAACG, SAM24443678_rep1-AAACGAATCATTGAGC, SAM24443678_rep1-AAACGAATCCCTTGGT, SAM24443678_rep1-AAACGAATCTGGCTGG, SAM24443678_rep1-AAACGAATCTTCCCGA, SAM24443678_rep1-AAACGCTAGATTAGCA, SAM24443678_rep1-AAACGCTAGCCGATTT, SAM24443678_rep1-AAACGCTAGGCGTTAG, SAM24443678_rep1-AAACGCTAGGGCCTCT, SAM24443678_rep1-AAACGCTAGGTCCTGC, SAM24443678_rep1-AAACGCTAGTAAGCAT, SAM24443678_rep1-AAACGCTAGTCCCGGT, SAM24443678_rep1-AAACGCTAGTCGAGGT, SAM24443678_rep1-AAACGCTAGTCTGCGC, SAM24443678_rep1-AAACGCTAGTTACTCG, SAM24443678_rep1-AAACGCTAGTTTGCTG, SAM24443678_rep1-AAACGCTCAACGGTAG, SAM24443678_rep1-AAACGCTCAATATCCG, SAM24443678_rep1-AAACGCTCAATTAGGA, SAM24443678_rep1-AAACGCTCACCAGGTC, SAM24443678_rep1-AAACGCTCACCTGCGA, SAM24443678_rep1-AAACGCTCACGCGTCA, SAM24443678_rep1-AAACGCTCAGATCATC, SAM24443678_rep1-AAACGCTCAGCGAACA, SAM24443678_rep1-AAACGCTCAGGTGACA, SAM24443678_rep1-AAACGCTCAGTAACCT, SAM24443678_rep1-AAACGCTCAGTTTCAG, SAM24443678_rep1-AAACGCTGTCTGCCTT, SAM24443678_rep1-AAACGCTGTGACAACG, SAM24443678_rep1-AAACGCTGTGGCAACA, SAM24443678_rep1-AAACGCTGTGGCGTAA, SAM24443678_rep1-AAACGCTGTTAAGTCC, SAM24443678_rep1-AAACGCTGTTCGTACA, SAM24443678_rep1-AAACGCTGTTTCACAG, SAM24443678_rep1-AAACGCTTCAACTCTT, SAM24443678_rep1-AAACGCTTCACTGTCC, SAM24443678_rep1-AAACGCTTCATACAGC, SAM24443678_rep1-AAACGCTTCATACGAC, SAM24443678_rep1-AAACGCTTCCAACTAG, SAM24443678_rep1-AAACGCTTCCAGGACC, SAM24443678_rep1-AAACGCTTCGATTTCT, SAM24443678_rep1-AAACGCTTCTTGTTAC, SAM24443678_rep1-AAAGAACAGAGAATCT, SAM24443678_rep1-AAAGAACAGAGTCGAC, SAM24443678_rep1-AAAGAACAGCCGTTGC, SAM24443678_rep1-AAAGAACAGCGATGCA, SAM24443678_rep1-AAAGAACAGCGTCTGC, SAM24443678_rep1-AAAGAACAGGATGTTA, SAM24443678_rep1-AAAGAACAGGGTATAT, SAM24443678_rep1-AAAGAACAGTATGACA, SAM24443678_rep1-AAAGAACAGTTACGAA, SAM24443678_rep1-AAAGAACCAGCAATTC, SAM24443678_rep1-AAAGAACCAGGTGTTT, SAM24443678_rep1-AAAGAACGTAGCGAGT, SAM24443678_rep1-AAAGAACGTATCGCGC, SAM24443678_rep1-AAAGAACGTCGAAACG, SAM24443678_rep1-AAAGAACGTGTCCGGT, SAM24443678_rep1-AAAGAACGTGTTCGAT, SAM24443678_rep1-AAAGAACTCAACACGT, SAM24443678_rep1-AAAGAACTCCCTCGAT, SAM24443678_rep1-AAAGAACTCCTAGCCT, SAM24443678_rep1-AAAGAACTCCTCATAT, SAM24443678_rep1-AAAGAACTCGGTCTGG, SAM24443678_rep1-AAAGGATAGACTCGAG, ...]
#
# [1289274 rows x 0 columns]

# %%
tmp= df.join(obs)

# %%
tmp
# Out:
#                                          Sample           Barcode  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   SAM24443678  AAACCCAAGAATTTGG
# SAM24443678_rep1-AAACCCAAGATACCAA   SAM24443678  AAACCCAAGATACCAA
# SAM24443678_rep1-AAACCCAAGCATTTCG   SAM24443678  AAACCCAAGCATTTCG
# SAM24443678_rep1-AAACCCAAGCGACCCT   SAM24443678  AAACCCAAGCGACCCT
# SAM24443678_rep1-AAACCCAAGCGCTGAA   SAM24443678  AAACCCAAGCGCTGAA
# ...                                         ...               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT  SAM24449114  TTTGTTGTCTAGAGCT
# SAM24449114_rep12-TTTGTTGTCTAGTTCT  SAM24449114  TTTGTTGTCTAGTTCT
# SAM24449114_rep12-TTTGTTGTCTCAACCC  SAM24449114  TTTGTTGTCTCAACCC
# SAM24449114_rep12-TTTGTTGTCTGGACCG  SAM24449114  TTTGTTGTCTGGACCG
# SAM24449114_rep12-TTTGTTGTCTTAATCC  SAM24449114  TTTGTTGTCTTAATCC
#
#                                    DemuxType_crispr  \
# SAM24443678_rep1-AAACCCAAGAATTTGG           doublet
# SAM24443678_rep1-AAACCCAAGATACCAA           doublet
# SAM24443678_rep1-AAACCCAAGCATTTCG           doublet
# SAM24443678_rep1-AAACCCAAGCGACCCT           unknown
# SAM24443678_rep1-AAACCCAAGCGCTGAA           unknown
# ...                                             ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT          unknown
# SAM24449114_rep12-TTTGTTGTCTAGTTCT          unknown
# SAM24449114_rep12-TTTGTTGTCTCAACCC          unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG          unknown
# SAM24449114_rep12-TTTGTTGTCTTAATCC          unknown
#
#                                                                DemuxAssignment_crispr  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   ENSG00000104936_3,ENSG00000184545_1,ENSG000001...
# SAM24443678_rep1-AAACCCAAGATACCAA                 ENSG00000065320_1,ENSG00000144824_1
# SAM24443678_rep1-AAACCCAAGCATTTCG                 ENSG00000104290_1,ENSG00000128218_1
# SAM24443678_rep1-AAACCCAAGCGACCCT                                             unknown
# SAM24443678_rep1-AAACCCAAGCGCTGAA                                             unknown
# ...                                                                               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTAGTTCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTCAACCC                                            unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG                                            unknown
# SAM24449114_rep12-TTTGTTGTCTTAATCC                                            unknown
#
#                                    DemuxType_hashing DemuxAssignment_hashing  \
# SAM24443678_rep1-AAACCCAAGAATTTGG            singlet             SAM24439044
# SAM24443678_rep1-AAACCCAAGATACCAA            singlet             SAM24439043
# SAM24443678_rep1-AAACCCAAGCATTTCG            singlet             SAM24439043
# SAM24443678_rep1-AAACCCAAGCGACCCT            singlet             SAM24439043
# SAM24443678_rep1-AAACCCAAGCGCTGAA            singlet             SAM24439043
# ...                                              ...                     ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT           singlet             SAM24439044
# SAM24449114_rep12-TTTGTTGTCTAGTTCT           singlet             SAM24439044
# SAM24449114_rep12-TTTGTTGTCTCAACCC           unknown                 unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG           singlet             SAM24439044
# SAM24449114_rep12-TTTGTTGTCTTAATCC           doublet            HTO-10,HTO-7
#
#                                         cellline     timepoint           HTO  \
# SAM24443678_rep1-AAACCCAAGAATTTGG           DLD1          day5        HTO-14
# SAM24443678_rep1-AAACCCAAGATACCAA           DLD1          day5        HTO-10
# SAM24443678_rep1-AAACCCAAGCATTTCG           DLD1          day5         HTO-3
# SAM24443678_rep1-AAACCCAAGCGACCCT           DLD1          day5        HTO-10
# SAM24443678_rep1-AAACCCAAGCGCTGAA           DLD1          day5         HTO-2
# ...                                          ...           ...           ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT          DLD1          day5        HTO-15
# SAM24449114_rep12-TTTGTTGTCTAGTTCT          DLD1          day5        HTO-14
# SAM24449114_rep12-TTTGTTGTCTCAACCC       unknown       unknown       unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG          DLD1          day5         HTO-5
# SAM24449114_rep12-TTTGTTGTCTTAATCC  HTO-10,HTO-7  HTO-10,HTO-7  HTO-10,HTO-7
#
#                                           NGS_ID Biological_replicate  10Xrun  \
# SAM24443678_rep1-AAACCCAAGAATTTGG        NGS5570          REPLICATE_2       1
# SAM24443678_rep1-AAACCCAAGATACCAA        NGS5570          REPLICATE_1       1
# SAM24443678_rep1-AAACCCAAGCATTTCG        NGS5570          REPLICATE_1       1
# SAM24443678_rep1-AAACCCAAGCGACCCT        NGS5570          REPLICATE_1       1
# SAM24443678_rep1-AAACCCAAGCGCTGAA        NGS5570          REPLICATE_1       1
# ...                                          ...                  ...     ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT       NGS5704          REPLICATE_2      12
# SAM24449114_rep12-TTTGTTGTCTAGTTCT       NGS5704          REPLICATE_2      12
# SAM24449114_rep12-TTTGTTGTCTCAACCC       unknown              unknown      12
# SAM24449114_rep12-TTTGTTGTCTGGACCG       NGS5704          REPLICATE_2      12
# SAM24449114_rep12-TTTGTTGTCTTAATCC  HTO-10,HTO-7         HTO-10,HTO-7      12
#
#                                                                            sublibrary  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24443678_rep1-AAACCCAAGATACCAA   GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24443678_rep1-AAACCCAAGCATTTCG   GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24443678_rep1-AAACCCAAGCGACCCT   GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24443678_rep1-AAACCCAAGCGCTGAA   GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# ...                                                                               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT  GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24449114_rep12-TTTGTTGTCTAGTTCT  GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24449114_rep12-TTTGTTGTCTCAACCC                                            unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG  GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24449114_rep12-TTTGTTGTCTTAATCC                                       HTO-10,HTO-7
#
#                                    gRNA_library_MOI  \
# SAM24443678_rep1-AAACCCAAGAATTTGG               0.4
# SAM24443678_rep1-AAACCCAAGATACCAA               0.4
# SAM24443678_rep1-AAACCCAAGCATTTCG               0.4
# SAM24443678_rep1-AAACCCAAGCGACCCT               0.4
# SAM24443678_rep1-AAACCCAAGCGCTGAA               0.4
# ...                                             ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT              0.4
# SAM24449114_rep12-TTTGTTGTCTAGTTCT              0.4
# SAM24449114_rep12-TTTGTTGTCTCAACCC          unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG              0.4
# SAM24449114_rep12-TTTGTTGTCTTAATCC     HTO-10,HTO-7
#
#                                                                           gene_symbol  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   ENSG00000104936_3,ENSG00000184545_1,ENSG000001...
# SAM24443678_rep1-AAACCCAAGATACCAA                 ENSG00000065320_1,ENSG00000144824_1
# SAM24443678_rep1-AAACCCAAGCATTTCG                 ENSG00000104290_1,ENSG00000128218_1
# SAM24443678_rep1-AAACCCAAGCGACCCT                                             unknown
# SAM24443678_rep1-AAACCCAAGCGCTGAA                                             unknown
# ...                                                                               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTAGTTCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTCAACCC                                            unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG                                            unknown
# SAM24449114_rep12-TTTGTTGTCTTAATCC                                            unknown
#
#                                                                                 class  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   ENSG00000104936_3,ENSG00000184545_1,ENSG000001...
# SAM24443678_rep1-AAACCCAAGATACCAA                 ENSG00000065320_1,ENSG00000144824_1
# SAM24443678_rep1-AAACCCAAGCATTTCG                 ENSG00000104290_1,ENSG00000128218_1
# SAM24443678_rep1-AAACCCAAGCGACCCT                                             unknown
# SAM24443678_rep1-AAACCCAAGCGCTGAA                                             unknown
# ...                                                                               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTAGTTCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTCAACCC                                            unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG                                            unknown
# SAM24449114_rep12-TTTGTTGTCTTAATCC                                            unknown
#
#                                     qc_pass
# SAM24443678_rep1-AAACCCAAGAATTTGG     False
# SAM24443678_rep1-AAACCCAAGATACCAA     False
# SAM24443678_rep1-AAACCCAAGCATTTCG     False
# SAM24443678_rep1-AAACCCAAGCGACCCT     False
# SAM24443678_rep1-AAACCCAAGCGCTGAA     False
# ...                                     ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT    False
# SAM24449114_rep12-TTTGTTGTCTAGTTCT    False
# SAM24449114_rep12-TTTGTTGTCTCAACCC    False
# SAM24449114_rep12-TTTGTTGTCTGGACCG    False
# SAM24449114_rep12-TTTGTTGTCTTAATCC    False
#
# [1289274 rows x 17 columns]

# %%
concat.obs
# Out:
#                                          Sample           Barcode  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   SAM24443678  AAACCCAAGAATTTGG
# SAM24443678_rep1-AAACCCAAGATACCAA   SAM24443678  AAACCCAAGATACCAA
# SAM24443678_rep1-AAACCCAAGCATTTCG   SAM24443678  AAACCCAAGCATTTCG
# SAM24443678_rep1-AAACCCAAGCGACCCT   SAM24443678  AAACCCAAGCGACCCT
# SAM24443678_rep1-AAACCCAAGCGCTGAA   SAM24443678  AAACCCAAGCGCTGAA
# ...                                         ...               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT  SAM24449114  TTTGTTGTCTAGAGCT
# SAM24449114_rep12-TTTGTTGTCTAGTTCT  SAM24449114  TTTGTTGTCTAGTTCT
# SAM24449114_rep12-TTTGTTGTCTCAACCC  SAM24449114  TTTGTTGTCTCAACCC
# SAM24449114_rep12-TTTGTTGTCTGGACCG  SAM24449114  TTTGTTGTCTGGACCG
# SAM24449114_rep12-TTTGTTGTCTTAATCC  SAM24449114  TTTGTTGTCTTAATCC
#
#                                    DemuxType_crispr  \
# SAM24443678_rep1-AAACCCAAGAATTTGG           doublet
# SAM24443678_rep1-AAACCCAAGATACCAA           doublet
# SAM24443678_rep1-AAACCCAAGCATTTCG           doublet
# SAM24443678_rep1-AAACCCAAGCGACCCT           unknown
# SAM24443678_rep1-AAACCCAAGCGCTGAA           unknown
# ...                                             ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT          unknown
# SAM24449114_rep12-TTTGTTGTCTAGTTCT          unknown
# SAM24449114_rep12-TTTGTTGTCTCAACCC          unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG          unknown
# SAM24449114_rep12-TTTGTTGTCTTAATCC          unknown
#
#                                                                DemuxAssignment_crispr  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   ENSG00000104936_3,ENSG00000184545_1,ENSG000001...
# SAM24443678_rep1-AAACCCAAGATACCAA                 ENSG00000065320_1,ENSG00000144824_1
# SAM24443678_rep1-AAACCCAAGCATTTCG                 ENSG00000104290_1,ENSG00000128218_1
# SAM24443678_rep1-AAACCCAAGCGACCCT                                             unknown
# SAM24443678_rep1-AAACCCAAGCGCTGAA                                             unknown
# ...                                                                               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTAGTTCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTCAACCC                                            unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG                                            unknown
# SAM24449114_rep12-TTTGTTGTCTTAATCC                                            unknown
#
#                                    DemuxType_hashing DemuxAssignment_hashing
# SAM24443678_rep1-AAACCCAAGAATTTGG            singlet             SAM24439044
# SAM24443678_rep1-AAACCCAAGATACCAA            singlet             SAM24439043
# SAM24443678_rep1-AAACCCAAGCATTTCG            singlet             SAM24439043
# SAM24443678_rep1-AAACCCAAGCGACCCT            singlet             SAM24439043
# SAM24443678_rep1-AAACCCAAGCGCTGAA            singlet             SAM24439043
# ...                                              ...                     ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT           singlet             SAM24439044
# SAM24449114_rep12-TTTGTTGTCTAGTTCT           singlet             SAM24439044
# SAM24449114_rep12-TTTGTTGTCTCAACCC           unknown                 unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG           singlet             SAM24439044
# SAM24449114_rep12-TTTGTTGTCTTAATCC           doublet            HTO-10,HTO-7
#
# [1289274 rows x 6 columns]

# %%
concat.obs = tmp.copy()

# %%
concat.obs
# Out:
#                                          Sample           Barcode  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   SAM24443678  AAACCCAAGAATTTGG
# SAM24443678_rep1-AAACCCAAGATACCAA   SAM24443678  AAACCCAAGATACCAA
# SAM24443678_rep1-AAACCCAAGCATTTCG   SAM24443678  AAACCCAAGCATTTCG
# SAM24443678_rep1-AAACCCAAGCGACCCT   SAM24443678  AAACCCAAGCGACCCT
# SAM24443678_rep1-AAACCCAAGCGCTGAA   SAM24443678  AAACCCAAGCGCTGAA
# ...                                         ...               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT  SAM24449114  TTTGTTGTCTAGAGCT
# SAM24449114_rep12-TTTGTTGTCTAGTTCT  SAM24449114  TTTGTTGTCTAGTTCT
# SAM24449114_rep12-TTTGTTGTCTCAACCC  SAM24449114  TTTGTTGTCTCAACCC
# SAM24449114_rep12-TTTGTTGTCTGGACCG  SAM24449114  TTTGTTGTCTGGACCG
# SAM24449114_rep12-TTTGTTGTCTTAATCC  SAM24449114  TTTGTTGTCTTAATCC
#
#                                    DemuxType_crispr  \
# SAM24443678_rep1-AAACCCAAGAATTTGG           doublet
# SAM24443678_rep1-AAACCCAAGATACCAA           doublet
# SAM24443678_rep1-AAACCCAAGCATTTCG           doublet
# SAM24443678_rep1-AAACCCAAGCGACCCT           unknown
# SAM24443678_rep1-AAACCCAAGCGCTGAA           unknown
# ...                                             ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT          unknown
# SAM24449114_rep12-TTTGTTGTCTAGTTCT          unknown
# SAM24449114_rep12-TTTGTTGTCTCAACCC          unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG          unknown
# SAM24449114_rep12-TTTGTTGTCTTAATCC          unknown
#
#                                                                DemuxAssignment_crispr  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   ENSG00000104936_3,ENSG00000184545_1,ENSG000001...
# SAM24443678_rep1-AAACCCAAGATACCAA                 ENSG00000065320_1,ENSG00000144824_1
# SAM24443678_rep1-AAACCCAAGCATTTCG                 ENSG00000104290_1,ENSG00000128218_1
# SAM24443678_rep1-AAACCCAAGCGACCCT                                             unknown
# SAM24443678_rep1-AAACCCAAGCGCTGAA                                             unknown
# ...                                                                               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTAGTTCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTCAACCC                                            unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG                                            unknown
# SAM24449114_rep12-TTTGTTGTCTTAATCC                                            unknown
#
#                                    DemuxType_hashing DemuxAssignment_hashing  \
# SAM24443678_rep1-AAACCCAAGAATTTGG            singlet             SAM24439044
# SAM24443678_rep1-AAACCCAAGATACCAA            singlet             SAM24439043
# SAM24443678_rep1-AAACCCAAGCATTTCG            singlet             SAM24439043
# SAM24443678_rep1-AAACCCAAGCGACCCT            singlet             SAM24439043
# SAM24443678_rep1-AAACCCAAGCGCTGAA            singlet             SAM24439043
# ...                                              ...                     ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT           singlet             SAM24439044
# SAM24449114_rep12-TTTGTTGTCTAGTTCT           singlet             SAM24439044
# SAM24449114_rep12-TTTGTTGTCTCAACCC           unknown                 unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG           singlet             SAM24439044
# SAM24449114_rep12-TTTGTTGTCTTAATCC           doublet            HTO-10,HTO-7
#
#                                         cellline     timepoint           HTO  \
# SAM24443678_rep1-AAACCCAAGAATTTGG           DLD1          day5        HTO-14
# SAM24443678_rep1-AAACCCAAGATACCAA           DLD1          day5        HTO-10
# SAM24443678_rep1-AAACCCAAGCATTTCG           DLD1          day5         HTO-3
# SAM24443678_rep1-AAACCCAAGCGACCCT           DLD1          day5        HTO-10
# SAM24443678_rep1-AAACCCAAGCGCTGAA           DLD1          day5         HTO-2
# ...                                          ...           ...           ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT          DLD1          day5        HTO-15
# SAM24449114_rep12-TTTGTTGTCTAGTTCT          DLD1          day5        HTO-14
# SAM24449114_rep12-TTTGTTGTCTCAACCC       unknown       unknown       unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG          DLD1          day5         HTO-5
# SAM24449114_rep12-TTTGTTGTCTTAATCC  HTO-10,HTO-7  HTO-10,HTO-7  HTO-10,HTO-7
#
#                                           NGS_ID Biological_replicate  10Xrun  \
# SAM24443678_rep1-AAACCCAAGAATTTGG        NGS5570          REPLICATE_2       1
# SAM24443678_rep1-AAACCCAAGATACCAA        NGS5570          REPLICATE_1       1
# SAM24443678_rep1-AAACCCAAGCATTTCG        NGS5570          REPLICATE_1       1
# SAM24443678_rep1-AAACCCAAGCGACCCT        NGS5570          REPLICATE_1       1
# SAM24443678_rep1-AAACCCAAGCGCTGAA        NGS5570          REPLICATE_1       1
# ...                                          ...                  ...     ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT       NGS5704          REPLICATE_2      12
# SAM24449114_rep12-TTTGTTGTCTAGTTCT       NGS5704          REPLICATE_2      12
# SAM24449114_rep12-TTTGTTGTCTCAACCC       unknown              unknown      12
# SAM24449114_rep12-TTTGTTGTCTGGACCG       NGS5704          REPLICATE_2      12
# SAM24449114_rep12-TTTGTTGTCTTAATCC  HTO-10,HTO-7         HTO-10,HTO-7      12
#
#                                                                            sublibrary  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24443678_rep1-AAACCCAAGATACCAA   GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24443678_rep1-AAACCCAAGCATTTCG   GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24443678_rep1-AAACCCAAGCGACCCT   GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24443678_rep1-AAACCCAAGCGCTGAA   GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# ...                                                                               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT  GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24449114_rep12-TTTGTTGTCTAGTTCT  GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24449114_rep12-TTTGTTGTCTCAACCC                                            unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG  GMTY210:cropseq.crisprko.cas9.human.lib4.conce...
# SAM24449114_rep12-TTTGTTGTCTTAATCC                                       HTO-10,HTO-7
#
#                                    gRNA_library_MOI  \
# SAM24443678_rep1-AAACCCAAGAATTTGG               0.4
# SAM24443678_rep1-AAACCCAAGATACCAA               0.4
# SAM24443678_rep1-AAACCCAAGCATTTCG               0.4
# SAM24443678_rep1-AAACCCAAGCGACCCT               0.4
# SAM24443678_rep1-AAACCCAAGCGCTGAA               0.4
# ...                                             ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT              0.4
# SAM24449114_rep12-TTTGTTGTCTAGTTCT              0.4
# SAM24449114_rep12-TTTGTTGTCTCAACCC          unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG              0.4
# SAM24449114_rep12-TTTGTTGTCTTAATCC     HTO-10,HTO-7
#
#                                                                           gene_symbol  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   ENSG00000104936_3,ENSG00000184545_1,ENSG000001...
# SAM24443678_rep1-AAACCCAAGATACCAA                 ENSG00000065320_1,ENSG00000144824_1
# SAM24443678_rep1-AAACCCAAGCATTTCG                 ENSG00000104290_1,ENSG00000128218_1
# SAM24443678_rep1-AAACCCAAGCGACCCT                                             unknown
# SAM24443678_rep1-AAACCCAAGCGCTGAA                                             unknown
# ...                                                                               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTAGTTCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTCAACCC                                            unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG                                            unknown
# SAM24449114_rep12-TTTGTTGTCTTAATCC                                            unknown
#
#                                                                                 class  \
# SAM24443678_rep1-AAACCCAAGAATTTGG   ENSG00000104936_3,ENSG00000184545_1,ENSG000001...
# SAM24443678_rep1-AAACCCAAGATACCAA                 ENSG00000065320_1,ENSG00000144824_1
# SAM24443678_rep1-AAACCCAAGCATTTCG                 ENSG00000104290_1,ENSG00000128218_1
# SAM24443678_rep1-AAACCCAAGCGACCCT                                             unknown
# SAM24443678_rep1-AAACCCAAGCGCTGAA                                             unknown
# ...                                                                               ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTAGTTCT                                            unknown
# SAM24449114_rep12-TTTGTTGTCTCAACCC                                            unknown
# SAM24449114_rep12-TTTGTTGTCTGGACCG                                            unknown
# SAM24449114_rep12-TTTGTTGTCTTAATCC                                            unknown
#
#                                     qc_pass
# SAM24443678_rep1-AAACCCAAGAATTTGG     False
# SAM24443678_rep1-AAACCCAAGATACCAA     False
# SAM24443678_rep1-AAACCCAAGCATTTCG     False
# SAM24443678_rep1-AAACCCAAGCGACCCT     False
# SAM24443678_rep1-AAACCCAAGCGCTGAA     False
# ...                                     ...
# SAM24449114_rep12-TTTGTTGTCTAGAGCT    False
# SAM24449114_rep12-TTTGTTGTCTAGTTCT    False
# SAM24449114_rep12-TTTGTTGTCTCAACCC    False
# SAM24449114_rep12-TTTGTTGTCTGGACCG    False
# SAM24449114_rep12-TTTGTTGTCTTAATCC    False
#
# [1289274 rows x 17 columns]

# %%
concat
# Out:
# AnnData object with n_obs × n_vars = 1289274 × 20872
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'qc_pass'
#     layers: 'counts'

# %%
concat.obs['gRNA_library_MOI'] = concat.obs['gRNA_library_MOI'].astype("str")

# %%
concat.write(OUT)

# %%
gRNA_qc = concat[concat.obs['qc_pass']==True].copy()

# %%
gRNA_qc
# Out:
# AnnData object with n_obs × n_vars = 446413 × 20872
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class', 'qc_pass'
#     layers: 'counts'

# %%
gRNA_qc.write("/gstore/scratch/u/ghaffars/Dataset/sublib4/gRNA_qc.h5ad")
