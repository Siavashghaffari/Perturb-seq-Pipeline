# %% [markdown]
# # Dataset Crispr Hashing Harmonization: This Notebook retrieves a dataset, creates a new experiment for cripr and hashing information comnied together and then updates the dataset with new experiment of cripr and hashing harmonized

# %% [markdown]
# ## 1. A little bit of set-up

# %% [markdown]
# #### Please insert your inputs

# %%
DSID = DatasetID
Version = '3'   # the version of your dataset
Version2 = '2' 
New_experiment = "crispr_hashing_harmonized" # A string that is a key known for the updated data saved by that that name

# %%
import sys
sys.path.append("..")
import Templates.tools.DatasetDB as DB
import Templates.tools.scHarmony as Hproc

# %% [markdown]
# ## Instantiate a dataset object given our dataset info

# %%
DS = DB.DATASET(DSID, DEV, title=title, description=description, name_space=name_space, organism=organism,
                       sources=sources, tech_name=tech_name, author=author)

# %% [markdown]
# ## 2. Access and collect Dataset

# %%
adata, adatas = DS.load_dataset(Version, your_experiment, Corr=True)
# Out:
# 08:50:41 -> Collating dataset: 'DS000015686' metadata.
# 08:50:41 -> Retrieving all project: 'DS000015686@3' metadata.
#
# 08:50:41 -> Reading: 'DS000015686'.
#
# 08:50:41 -> Reading: 'DS000015686 -> Experiment: main'.
#
# 08:50:41 -> Reading: 'DS000015686 -> Experiment: main -> Alt. Exp.: crispr'.
#
# 08:50:42 -> Reading: 'DS000015686 -> Experiment: main -> Alt. Exp.: hashing'.
# /apps/user/gpy/envs/dev/GPy39/lib/python3.9/site-packages/multiassayexperiment/MultiAssayExperiment.py:127: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for group, rows in agroups:

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 40383 × 36603
#     obs: 'Sample', 'Barcode', 'demux_type', 'assignment', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', 'sublibrary', 'gRNA_library_MOI', 'demux_type_v2', 'assignment_v2', 'gene_symbol', 'class'
#     var: 'ID', 'Symbol', 'Type'
#     uns: 'genome', 'modality', 'uid', 'adt_summary', '.internal'
#     layers: 'counts'

# %%
adatas
# Out:
# {'crispr': AnnData object with n_obs × n_vars = 40383 × 21091
#      uns: '.internal'
#      layers: 'counts',
#  'hashing': AnnData object with n_obs × n_vars = 40383 × 19
#      uns: '.internal'
#      layers: 'counts'}

# %% [markdown]
# ### Checking the dataset

# %%
adata.obs
# Out:
#                                              Sample           Barcode  \
# SAM24439046_rep1-AAACCCAAGACCACGA  SAM24439046_rep1  AAACCCAAGACCACGA
# SAM24439046_rep1-AAACCCAAGAGTGGCT  SAM24439046_rep1  AAACCCAAGAGTGGCT
# SAM24439046_rep1-AAACCCAAGAGTGTTA  SAM24439046_rep1  AAACCCAAGAGTGTTA
# SAM24439046_rep1-AAACCCAAGCACTCAT  SAM24439046_rep1  AAACCCAAGCACTCAT
# SAM24439046_rep1-AAACCCAAGCATTGTC  SAM24439046_rep1  AAACCCAAGCATTGTC
# ...                                             ...               ...
# SAM24439046_rep1-TTTGTTGTCCATTTAC  SAM24439046_rep1  TTTGTTGTCCATTTAC
# SAM24439046_rep1-TTTGTTGTCCCATTCG  SAM24439046_rep1  TTTGTTGTCCCATTCG
# SAM24439046_rep1-TTTGTTGTCTGACGCG  SAM24439046_rep1  TTTGTTGTCTGACGCG
# SAM24439046_rep1-TTTGTTGTCTTAATCC  SAM24439046_rep1  TTTGTTGTCTTAATCC
# SAM24439046_rep1-TTTGTTGTCTTCTAAC  SAM24439046_rep1  TTTGTTGTCTTCTAAC
#
#                                   demux_type  \
# SAM24439046_rep1-AAACCCAAGACCACGA    singlet
# SAM24439046_rep1-AAACCCAAGAGTGGCT    singlet
# SAM24439046_rep1-AAACCCAAGAGTGTTA    singlet
# SAM24439046_rep1-AAACCCAAGCACTCAT    singlet
# SAM24439046_rep1-AAACCCAAGCATTGTC    doublet
# ...                                      ...
# SAM24439046_rep1-TTTGTTGTCCATTTA
TO-1,HTO-18
# SAM24439046_rep1-TTTGTTGTCTGACGCG  GMTY210:cropseq.crisprko.cas9.human.lib2.conce...
# SAM24439046_rep1-TTTGTTGTCTTAATCC                                      HTO-14,HTO-16
# SAM24439046_rep1-TTTGTTGTCTTCTAAC  GMTY210:cropseq.crisprko.cas9.human.lib2.conce...
#
#                                   gRNA_library_MOI demux_type_v2  \
# SAM24439046_rep1-AAACCCAAGACCACGA              0.4       singlet
# SAM24439046_rep1-AAACCCAAGAGTGGCT              0.4       singlet
# SAM24439046_rep1-AAACCCAAGAGTGTTA              0.4       singlet
# SAM24439046_rep1-AAACCCAAGCACTCAT              0.4       singlet
# SAM24439046_rep1-AAACCCAAGCATTGTC              0.4       singlet
# ...                                            ...           ...
# SAM24439046_rep1-TTTGTTGTCCATTTAC              0.4       singlet
# SAM24439046_rep1-TTTGTTGTCCCATTCG     HTO-1,HTO-18       doublet
# SAM24439046_rep1-TTTGTTGTCTGACGCG              0.4       singlet
# SAM24439046_rep1-TTTGTTGTCTTAATCC    HTO-14,HTO-16       doublet
# SAM24439046_rep1-TTTGTTGTCTTCTAAC              0.4       singlet
#
#                                    assignment_v2  \
# SAM24439046_rep1-AAACCCAAGACCACGA    SAM24439045
# SAM24439046_rep1-AAACCCAAGAGTGGCT    SAM24439043
# SAM24439046_rep1-AAACCCAAGAGTGTTA    SAM24439045
# SAM24439046_rep1-AAACCCAAGCACTCAT    SAM24439044
# SAM24439046_rep1-AAACCCAAGCATTGTC    SAM24439044
# ...                                          ...
# SAM24439046_rep1-TTTGTTGTCCATTTAC    SAM24439043
# SAM24439046_rep1-TTTGTTGTCCCATTCG   HTO-1,HTO-18
# SAM24439046_rep1-TTTGTTGTCTGACGCG    SAM24439043
# SAM24439046_rep1-TTTGTTGTCTTAATCC  HTO-14,HTO-16
# SAM24439046_rep1-TTTGTTGTCTTCTAAC    SAM24439043
#
#                                                            gene_symbol  \
# SAM24439046_rep1-AAACCCAAGACCACGA                              FAM170B
# SAM24439046_rep1-AAACCCAAGAGTGGCT                              ANKRD39
# SAM24439046_rep1-AAACCCAAGAGTGTTA                                 MPST
# SAM24439046_rep1-AAACCCAAGCACTCAT                                KNTC1
# SAM24439046_rep1-AAACCCAAGCATTGTC  ENSG00000197747_3,ENSG00000022355_3
# ...                                                                ...
# SAM24439046_rep1-TTTGTTGTCCATTTAC                              unknown
# SAM24439046_rep1-TTTGTTGTCCCATTCG                               PKNOX2
# SAM24439046_rep1-TTTGTTGTCTGACGCG                              CCDC171
# SAM24439046_rep1-TTTGTTGTCTTAATCC  ENSG00000100302_3,ENSG00000158623_4
# SAM24439046_rep1-TTTGTTGTCTTCTAAC                                  NTC
#
#                                                                  class
# SAM24439046_rep1-AAACCCAAGACCACGA                               target
# SAM24439046_rep1-AAACCCAAGAGTGGCT                               target
# SAM24439046_rep1-AAACCCAAGAGTGTTA                               target
# SAM24439046_rep1-AAACCCAAGCACTCAT                               target
# SAM24439046_rep1-AAACCCAAGCATTGTC  ENSG00000197747_3,ENSG00000022355_3
# ...                                                                ...
# SAM24439046_rep1-TTTGTTGTCCATTTAC                              unknown
# SAM24439046_rep1-TTTGTTGTCCCATTCG                               target
# SAM24439046_rep1-TTTGTTGTCTGACGCG                               target
# SAM24439046_rep1-TTTGTTGTCTTAATCC  ENSG00000100302_3,ENSG00000158623_4
# SAM24439046_rep1-TTTGTTGTCTTCTAAC                                  ntc
#
# [40383 rows x 15 columns]

# %%
adata.var_names
# Out:
# Index(['3xLinker_3xLinker', 'GRCh38-2020-A_ENSG00000243485',
#        'GRCh38-2020-A_ENSG00000237613', 'GRCh38-2020-A_ENSG00000186092',
#        'GRCh38-2020-A_ENSG00000238009', 'GRCh38-2020-A_ENSG00000239945',
#        'GRCh38-2020-A_ENSG00000239906', 'GRCh38-2020-A_ENSG00000241860',
#        'GRCh38-2020-A_ENSG00000241599', 'GRCh38-2020-A_ENSG00000286448',
#        ...
#        'GRCh38-2020-A_ENSG00000275869', 'GRCh38-2020-A_ENSG00000273554',
#        'GRCh38-2020-A_ENSG00000278782', 'GRCh38-2020-A_ENSG00000277761',
#        'GRCh38-2020-A_ENSG00000277836', 'GRCh38-2020-A_ENSG00000278633',
#        'GRCh38-2020-A_ENSG00000276017', 'GRCh38-2020-A_ENSG00000278817',
#        'GRCh38-2020-A_ENSG00000277196', 'TurboGFP_TurboGFP'],
#       dtype='object', length=36603)

# %%
adata.var.head()
# Out:
#                                                           ID  \
# 3xLinker_3xLinker                          3xLinker_3xLinker
# GRCh38-2020-A_ENSG00000243485  GRCh38-2020-A_ENSG00000243485
# GRCh38-2020-A_ENSG00000237613  GRCh38-2020-A_ENSG00000237613
# GRCh38-2020-A_ENSG00000186092  GRCh38-2020-A_ENSG00000186092
# GRCh38-2020-A_ENSG00000238009  GRCh38-2020-A_ENSG00000238009
#
#                                                   Symbol             Type
# 3xLinker_3xLinker                      3xLinker_3xLinker  Gene Expression
# GRCh38-2020-A_ENSG00000243485  GRCh38-2020-A_MIR1302-2HG  Gene Expression
# GRCh38-2020-A_ENSG00000237613      GRCh38-2020-A_FAM138A  Gene Expression
# GRCh38-2020-A_ENSG00000186092        GRCh38-2020-A_OR4F5  Gene Expression
# GRCh38-2020-A_ENSG00000238009   GRCh38-2020-A_AL627309.1  Gene Expression

# %%
adata.X
# Out:
# <40383x36603 sparse matrix of type '<class 'numpy.int32'>'
# 	with 40520263 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## 3. Modify the anndata using a function (any operations you want)

# %%
tmp = adata.obs.copy()

# %%
tmp
# Out:
#                                              Sample           Barcode  \
# SAM24439046_rep1-AAACCCAAGACCACGA  SAM24439046_rep1  AAACCCAAGACCACGA
# SAM24439046_rep1-AAACCCAAGAGTGGCT  SAM24439046_rep1  AAACCCAAGAGTGGCT
# SAM24439046_rep1-AAACCCAAGAGTGTTA  SAM24439046_rep1  AAACCCAAGAGTGTTA
# SAM24439046_rep1-AAACCCAAGCACTCAT  SAM24439046_rep1  AAACCCAAGCACTCAT
# SAM24439046_rep1-AAACCCAAGCATTGTC  SAM24439046_rep1  AAACCCAAGCATTGTC
# ...                                             ...               ...
# SAM24439046_rep1-TTTGTTGTCCATTTAC  SAM24439046_rep1  TTTGTTGTCCATTTAC
# SAM24439046_rep1-TTTGTTGTCCCATTCG  SAM24439046_rep1  TTTGTTGTCCCATTCG
# SAM24439046_rep1-TTTGTTGTCTGACGCG  SAM24439046_rep1  TTTGTTGTCTGACGCG
# SAM24439046_rep1-TTTGTTGTCTTAATCC  SAM24439046_rep1  TTTGTTGTCTTAATCC
# SAM24439046_rep1-TTTGTTGTCTTCTAAC  SAM24439046_rep1  TTTGTTGTCTTCTAAC
#
#                                   demux_type  \
# SAM24439046_rep1-AAACCCAAGACCACGA    singlet
# SAM24439046_rep1-AAACCCAAGAGTGGCT    singlet
# SAM24439046_rep1-AAACCCAAGAGTGTTA    singlet
# SAM24439046_rep1-AAACCCAAGCACTCAT    singlet
# SAM24439046_rep1-AAACCCAAGCATTGTC    doublet
# ...                                      ...
# SAM24439046_rep1-TTTGTTGTCCATTTAC    unknown
# SAM24439046_rep1-TTTGTTGTCCCATTC
TO-14,HTO-16
# SAM24439046_rep1-TTTGTTGTCTTCTAAC  GMTY210:cropseq.crisprko.cas9.human.lib2.conce...
#
#                                   gRNA_library_MOI demux_type_v2  \
# SAM24439046_rep1-AAACCCAAGACCACGA              0.4       singlet
# SAM24439046_rep1-AAACCCAAGAGTGGCT              0.4       singlet
# SAM24439046_rep1-AAACCCAAGAGTGTTA              0.4       singlet
# SAM24439046_rep1-AAACCCAAGCACTCAT              0.4       singlet
# SAM24439046_rep1-AAACCCAAGCATTGTC              0.4       singlet
# ...                                            ...           ...
# SAM24439046_rep1-TTTGTTGTCCATTTAC              0.4       singlet
# SAM24439046_rep1-TTTGTTGTCCCATTCG     HTO-1,HTO-18       doublet
# SAM24439046_rep1-TTTGTTGTCTGACGCG              0.4       singlet
# SAM24439046_rep1-TTTGTTGTCTTAATCC    HTO-14,HTO-16       doublet
# SAM24439046_rep1-TTTGTTGTCTTCTAAC              0.4       singlet
#
#                                    assignment_v2  \
# SAM24439046_rep1-AAACCCAAGACCACGA    SAM24439045
# SAM24439046_rep1-AAACCCAAGAGTGGCT    SAM24439043
# SAM24439046_rep1-AAACCCAAGAGTGTTA    SAM24439045
# SAM24439046_rep1-AAACCCAAGCACTCAT    SAM24439044
# SAM24439046_rep1-AAACCCAAGCATTGTC    SAM24439044
# ...                                          ...
# SAM24439046_rep1-TTTGTTGTCCATTTAC    SAM24439043
# SAM24439046_rep1-TTTGTTGTCCCATTCG   HTO-1,HTO-18
# SAM24439046_rep1-TTTGTTGTCTGACGCG    SAM24439043
# SAM24439046_rep1-TTTGTTGTCTTAATCC  HTO-14,HTO-16
# SAM24439046_rep1-TTTGTTGTCTTCTAAC    SAM24439043
#
#                                                            gene_symbol  \
# SAM24439046_rep1-AAACCCAAGACCACGA                              FAM170B
# SAM24439046_rep1-AAACCCAAGAGTGGCT                              ANKRD39
# SAM24439046_rep1-AAACCCAAGAGTGTTA                                 MPST
# SAM24439046_rep1-AAACCCAAGCACTCAT                                KNTC1
# SAM24439046_rep1-AAACCCAAGCATTGTC  ENSG00000197747_3,ENSG00000022355_3
# ...                                                                ...
# SAM24439046_rep1-TTTGTTGTCCATTTAC                              unknown
# SAM24439046_rep1-TTTGTTGTCCCATTCG                               PKNOX2
# SAM24439046_rep1-TTTGTTGTCTGACGCG                              CCDC171
# SAM24439046_rep1-TTTGTTGTCTTAATCC  ENSG00000100302_3,ENSG00000158623_4
# SAM24439046_rep1-TTTGTTGTCTTCTAAC                                  NTC
#
#                                                                  class
# SAM24439046_rep1-AAACCCAAGACCACGA                               target
# SAM24439046_rep1-AAACCCAAGAGTGGCT                               target
# SAM24439046_rep1-AAACCCAAGAGTGTTA                               target
# SAM24439046_rep1-AAACCCAAGCACTCAT                               target
# SAM24439046_rep1-AAACCCAAGCATTGTC  ENSG00000197747_3,ENSG00000022355_3
# ...                                                                ...
# SAM24439046_rep1-TTTGTTGTCCATTTAC                              unknown
# SAM24439046_rep1-TTTGTTGTCCCATTCG                               target
# SAM24439046_rep1-TTTGTTGTCTGACGCG                               target
# SAM24439046_rep1-TTTGTTGTCTTAATCC  ENSG00000100302_3,ENSG00000158623_4
# SAM24439046_rep1-TTTGTTGTCTTCTAAC                                  ntc
#
# [40383 rows x 15 columns]

# %%
tmp = tmp.rename(columns={"demux_type":"DemuxType_crispr","assignment":"DemuxAssignment_crispr",
                          "demux_type_v2":"DemuxType_hashing","assignment_v2":"DemuxAssignment_hashing"})

# %%
tmp["10Xrun"] = tmp ["Sample"].str.split('_').str[1]
tmp["10Xrun"] = tmp ["10Xrun"].str.extract('(\d+)')

# %%
tmp["Sample"] = tmp ["Sample"].str.split('_').str[0]

# %%
tmp = tmp[['Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr',
       'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint','HTO', 'NGS_ID',
       'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MO
                                ...
# SAM24439046_rep1-TTTGTTGTCCATTTAC                              unknown
# SAM24439046_rep1-TTTGTTGTCCCATTCG                               PKNOX2
# SAM24439046_rep1-TTTGTTGTCTGACGCG                              CCDC171
# SAM24439046_rep1-TTTGTTGTCTTAATCC  ENSG00000100302_3,ENSG00000158623_4
# SAM24439046_rep1-TTTGTTGTCTTCTAAC                                  NTC
#
#                                                                  class
# SAM24439046_rep1-AAACCCAAGACCACGA                               target
# SAM24439046_rep1-AAACCCAAGAGTGGCT                               target
# SAM24439046_rep1-AAACCCAAGAGTGTTA                               target
# SAM24439046_rep1-AAACCCAAGCACTCAT                               target
# SAM24439046_rep1-AAACCCAAGCATTGTC  ENSG00000197747_3,ENSG00000022355_3
# ...                                                                ...
# SAM24439046_rep1-TTTGTTGTCCATTTAC                              unknown
# SAM24439046_rep1-TTTGTTGTCCCATTCG                               target
# SAM24439046_rep1-TTTGTTGTCTGACGCG                               target
# SAM24439046_rep1-TTTGTTGTCTTAATCC  ENSG00000100302_3,ENSG00000158623_4
# SAM24439046_rep1-TTTGTTGTCTTCTAAC                                  ntc
#
# [40383 rows x 16 columns]

# %%
adata_updated = adata.copy()
adatas_updated = adatas.copy()

# %%
adata_updated
# Out:
# AnnData object with n_obs × n_vars = 40383 × 36603
#     obs: 'Sample', 'Barcode', 'demux_type', 'assignment', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', 'sublibrary', 'gRNA_library_MOI', 'demux_type_v2', 'assignment_v2', 'gene_symbol', 'class'
#     var: 'ID', 'Symbol', 'Type'
#     uns: 'genome', 'modality', 'uid', 'adt_summary', '.internal'
#     layers: 'counts'

# %%
adatas_updated
# Out:
# {'crispr': AnnData object with n_obs × n_vars = 40383 × 21091
#      uns: '.internal'
#      layers: 'counts',
#  'hashing': AnnData object with n_obs × n_vars = 40383 × 19
#      uns: '.internal'
#      layers: 'counts'}

# %%
adata_updated.obs = tmp.copy()

# %%
adata_updated
# Out:
# AnnData object with n_obs × n_vars = 40383 × 36603
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'cellline', 'timepoint', 'HTO', 'NGS_ID', 'Biological_replicate', '10Xrun', 'sublibrary', 'gRNA_library_MOI', 'gene_symbol', 'class'
#     var: 'ID', 'Symbol', 'Type'
#     uns: 'genome', 'modality', 'uid', 'adt_summary', '.internal'
#     layers: 'counts'

# %%
adatas_updated
# Out:
# {'crispr': AnnData object with n_obs × n_vars = 40383 × 21091
#      uns: '.internal'
#      layers: 'counts',
#  'hashing': AnnData object with n_obs × n_vars = 40383 × 19
#      uns: '.internal'
#      layers: 'counts'}

# %% [markdown]
# ## 4. Upload

# %%
if DS_test==False:
    dsid, version = DS.update_dataset(New_experiment, adata_updated, adatas_updated, test=False)
else:    
    dsid, version = DS.update_another_dataset(test_DatasetID, True, 1, New_experiment, adata_updated, adatas_updated, test=True)
# Out:
# 09:00:02 -> Collating dataset: 'DS000015686' metadata.
# 09:00:02 -> Retrieving all project: 'DS000015686@1' metadata.
#
# 09:00:03 -> Reading: 'DS000015686'.
#
# 09:00:03 -> Reading: 'DS000015686 -> Experiment: main'.
#
# 09:00:03 -> Reading: 'DS000015686 -> Experiment: main -> Alt. Exp.: crispr'.
# DS000015686 -> Experiment: main -> Alt. Exp.: crispr -> Reduced Dimensions -> NDArrays: 100%|████████████████████████████████████████| 800/800 [00:00<00:00, 551kB/s]
# DS000015686 -> Experiment: main -> Alt. Exp.: crispr -> Assay: counts -> Sparse Matrix: 100%|████████████████████████████████████████| 2.16M/2.16M [00:06<00:00, 338kB/s]
# DS000015686 -> Experiment: main -> Alt. Exp.: crispr -> Column Data -> Data Frame: 100%|████████████████████████████████████████| 168k/168k [00:00<00:00, 55.8MB/s]
# DS000015686 -> Experiment: main -> Alt. Exp.: crispr -> Row Data -> Data Frame: 100%|████████████████████████████████████████| 51.8k/51.8k [00:00<00:00, 29.0MB/s]
# 09:00:15 -> Reading: 'DS000015686 -> Experiment: main -> Alt. Exp.: hashing'.
# DS000015686 -> Experiment: main -> Alt. Exp.: hashing -> Reduced Dimensions -> NDArrays: 100%|████████████████████████████████████████| 800/800 [00:00<00:00, 532kB/s]
# DS000015686 -> Experiment: main -> Alt. Exp.: hashing -> Assay: counts -> Sparse Matrix: 100%|████████████████████████████████████████| 2.46M/2.46M [00:01<00:00, 1.49MB/s]
# DS000015686 -> Experiment: main -> Alt. Exp.: hashing -> Column Data -> Data Frame: 100%|████████████████████████████████████████| 168k/168k [00:00<00:00, 2.20MB/s]
# DS000015686 -> Experiment: main -> Alt. Exp.: hashing -> Row Data -> Data Frame: 100%|████████████████████████████████████████| 90.0/90.0 [00:00<00:00, 65.8kB/s]
# DS000015686 -> Experiment: main -> Reduced Dimensions -> NDArrays: 100%|████████████████████████████████████████| 800/800 [00:00<00:00, 610kB/s]
# DS000015686 -> Experiment: main -> Assay: counts -> Sparse Matrix: 100%|████████████████████████████████████████| 243M/243M [00:14<00:00, 16.3MB/s]
# DS000015686 -> Experiment: main -> Column Data -> Data Frame -> Column: 'Sample' -> Data Frame: 100%|████████████████████████████████████████| 48.0/48.0 [00:00<00:00, 35.2kB/s]
# DS000015686 -> Experiment: main -> Column Data -> Data Frame: 100%|████████████████████████████████████████| 266k/266k [00:00<00:00, 77.6MB/s]
# DS000015686 -> Experiment: main -> Other Data -> Basic List: 100%|████████████████████████████████████████| 474/474 [00:00<00:00, 334kB/s]
# DS000015686 -> Experiment: main -> Row Data -> Data Frame: 100%|████████████████████████████████████████| 408k/408k [00:00<00:00, 16.4MB/s]
# DS000015686 -> Column Data -> Data Frame: 100%|████████████████████████████████████████| 78.0/78.0 [00:00<00:00, 56.2kB/s]
# DS000015686 -> Sample Mapping: 100%|████████████████████████████████████████| 279k/279k [00:00<00:00, 7.86MB/s]
# /apps/user/gpy/envs/dev/GPy39/lib/python3.9/site-packages/multiassayexperiment/MultiAssayExperiment.py:127: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for group, rows in agroups:
#
# PYDSDB:INFO: Experiment already contained metadata, overwriting.
#
# PYDSDB:INFO: Experiment already contained metadata, overwriting.
#
# PYDSDB:INFO: Experiment already contained metadata, overwriting.
# /apps/user/gpy/envs/dev/GPy39/lib/python3.9/site-packages/multiassayexperiment/MultiAssayExperiment.py:127: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for group, rows in agroups:
# /apps/user/gpy/envs/dev/GPy39/lib/python3.9/site-packages/multiassayexperiment/MultiAssayExperiment.py:127: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for group, rows in agroups:
# ---------------------------------------------------------------------------
# PYDSDBError                               Traceback (most recent call last)
# Cell In[30], line 2
#       1 if DS_test==False:
# ----> 2     dsid, version = DS.update_dataset(New_experiment, adata_updated, adatas_updated, test=False)
#       3 else:
#       4     dsid, version = DS.update_another_dataset(test_DatasetID, True, 1, New_experiment, adata_updated, adatas_updated, test=True)
#
# File ~/Cumulus/crc_ngs5445/crop-seq-pipeline/src/Templates/../Templates/tools/DatasetDB.py:224, in DATASET.update_dataset(self, new_experiment, adata_updated, adatas_updated, test, Corr)
#     217     new_mae = mae.MultiAssayExperiment(
#     218     {**self.experiments,new_experiment: tse},
#     219     column_data,
#     220     sample_map,
#     221     self.metadata
#     222     )
#     223 # Initialize the upload
# --> 224 upload = pydsdb.Upload(new_mae)
#     225 # Set Permissions
#     226 permissions = pydsdb.create_permissions_info()
#
# File /apps/user/gpy/envs/dev/GPy39/lib/python3.9/site-packages/pydsdb/upload/upload.py:125, in Upload.__init__(self, dataset, staging_dir, descriptor, file_size_limit, overwrite)
#     123         self._staging_dir = staging_dir
#     124 else:
# --> 125     self._staging_dir = DatasetStager(
#     126         dataset, descriptor, file_size_limit, overwrite, staging_dir
#     127     ).stage()
#     129 self._permissions_info: Optional[PermissionsInfo] = None
#     130 if (
#     131     dataset is not None
#     132     and dataset.metadata is not None  # type: ignore
#     133     and INTERNAL in dataset.metadata  # type: ignore
#     134 ):
#
# File /apps/user/gpy/envs/dev/GPy39/lib/python3.9/site-packages/pydsdb/upload/dataset/generic.py:164, in DatasetStager.stage(self)
#     156 if update_info.update_ready is False:
#     157     raise PYDSDBError(
#     158         "Cannot stage this dataset as it is missing data due to "
#     159         "partially supported resource types"
#     160     )
#     162 self._write_metadata(
#     163     self._make_paths(None, "dataset", "")[2],
# --> 164     self._make_metadata(update_info),
#     165     f"{loads(update_info.metadata)['$schema']}",
#     166 )
#     168 return self._staging_dir
#
# File /apps/user/gpy/envs/dev/GPy39/lib/python3.9/site-packages/pydsdb/upload/dataset/stagers/dataset.py:199, in DatasetStager._make_metadata(self, update_info)
#     193     raise PYDSDBError(
#     194         f"Dataset: '{self._descriptor}' metadata could not be parsed!"
#     195     ) from expt
#     197 self._staging_dir.joinpath(OLD_PATHS).write_text(dumps(self.old_paths))
# --> 199 metadata.dataset = self._stage_dataset_components(
#     200     metadata.dataset,
#     201     update_info.column_data,
#     202     update_info.sample_mapping,
#     203     update_info.exp_nums,
#     204 )
#     206 metadata.is_child = self._is_child
#     208 return metadata.dict()
#
# File /apps/user/gpy/envs/dev/GPy39/lib/python3.9/site-packages/pydsdb/upload/dataset/stagers/dataset.py:127, in DatasetStager._stage_dataset_components(self, metadata, orig_column_data, orig_sample_mapping, exp_nums)
#     122     else:
#     123         exp_stager = self._make_child_experiment_stager(
#     124             self._se_stager, exp, *exp_args
#     125         )
# --> 127     exps.append(exp_stager.stage(name))
#     128     self.old_paths.extend(exp_stager.old_paths)
#     130 metadata.experiments = self._combine_named_resources(
#     131     metadata.experiments, exps
#     132 )
#
# File /apps/user/gpy/envs/dev/GPy39/lib/python3.9/site-packages/pydsdb/upload/experiments/generic.py:211, in ExperimentStager.stage(self, name)
#     205 if update_info.update_ready is False:
#     206     raise PYDSDBError(
#     207         "Cannot stage this experiment as it is missing data due to "
#     208         "partially supported resource types"
#     209     )
# --> 211 metadata = self._make_metadata(update_info)
#     213 metadata_path, metadata["path"], _ = self._make_paths(
#     214     None, "experiment", ".json"
#     215 )
#     217 metadata["is_child"] = self._is_child
#
# File /apps/user/gpy/envs/dev/GPy39/lib/python3.9/site-packages/pydsdb/upload/experiments/stagers/sce.py:390, in SingleCellExperimentStager._make_metadata(self, update_info)
#     384 except Exception as expt:
#     385     raise PYDSDBError(
#     386         f"Experiment: '{self._descriptor}' metadata could not be "
#     387         "parsed!"
#     388     ) from expt
# --> 390 return self._update_metadata(metadata, update_info).dict()
#
# File /apps/user/gpy/envs/dev/GPy39/lib/python3.9/site-packages/pydsdb/upload/experiments/stagers/sce.py:324, in SingleCellExperimentStager._update_metadata(self, metadata, update_info)
#     305 def _update_metadata(
#     306     self,
#     307     metadata: SingleCellExperimentUp,
#     308     update_info: ExperimentUpdateInfo,
#     309 ) -> SingleCellExperimentUp:
#     310     """Update the contents of the metadata.
#     311
#     312     Parameters
#    (...)
#     322         The updated metadata.
#     323     """
# --> 324     metadata.summarized_experiment = self._stage_se_resources(
#     325         metadata.summarized_experiment,
#     326         update_info.assay_nums,
#     327     )
#     329     metadata.single_cell_experiment = self._stage_sce_resources(
#     330         metadata.single_cell_experiment,
#     331         update_info.alt_nums,
#     332     )
#     334     if isinstance(metadata, SingleCellAccessibilityReferenceUp):
#
# File /apps/user/gpy/envs/dev/GPy39/lib/python3.9/site-packages/pydsdb/upload/experiments/stagers/se.py:148, in SummarizedExperimentStagingMethods._stage_se_resources(self, metadata, assay_nums)
#     143 metadata.assays = self._combine_named_resources(
#     144     metadata.assays, assays
#     145 )
#     147 if isinstance(self._artifact.colData, DataFrame):
# --> 148     metadata.column_data = self._make_child_resource_stager(
#     149         self._data_frame_stager,
#     150         self._artifact.colData,
#     151         f"{self._descriptor} -> Column Data",
#     152         self._staging_dir.joinpath("coldata"),
#     153     ).stage()
#     154 else:
#     155     raise PYDSDBError(
#     156         "Staging does not currently support 'BiocFrame' in "
#     157         f"experiment: '{self._descriptor} -> Column Data'."
#     158     )
#
# File /apps/user/gpy/envs/dev/GPy39/lib/python3.9/site-packages/pydsdb/upload/resources/generic.py:189, in ResourceStager.stage(self, name)
#     173 """Stage a resource.
#     174
#     175 Parameters
#    (...)
#     183     The `Resource` of the staged resource.
#     184 """
#     185 resource_path, relative_path, metadata_path = self._make_paths(
#     186     name, self._default_name, self._extension
#     187 )
# --> 189 self._write_resource(resource_path)
#     191 self.check_file_size(resource_path)
#     193 self._write_metadata(
#     194     metadata_path,
#     195     self._make_metadata(resource_path, relative_path),
#     196     f"{self._schema_dir}/{self._schema_name()}",
#     197 )
#
# File /apps/user/gpy/envs/dev/GPy39/lib/python3.9/site-packages/pydsdb/upload/resources/stagers/csv_data_frame.py:79, in CSVDataFrameStager._write_resource(self, resource_path)
#      71 def _write_resource(self, resource_path: Path) -> None:
#      72     """Write out a resource.
#      73
#      74     Parameters
#    (...)
#      77         The path to the resource file to write to.
#      78     """
# ---> 79     self._column_resources = self._make_column_resources(self._artifact)
#      81     other_columns = {  # type: ignore
#      82         column.name: self._artifact[column.name]
#      83         for column in self._column_resources
#      84         if column.resource is not None
#      85     }
#      86     for name in other_columns.keys():
#
# File /apps/user/gpy/envs/dev/GPy39/lib/python3.9/site-packages/pydsdb/upload/resources/stagers/data_frame_type_stager.py:96, in DataFrameTypeStager._make_column_resources(self, data)
#      91 value_types = set(type(value) for value in column) - set(  # type: ignore
#      92     [type(None)]
#      93 )
#      95 if len(value_types) > 1:
# ---> 96     raise PYDSDBError(
#      97         f"For column: '{name}' with row 'object' dtype "
#      98         "row values have more than one type (excluding "
#      99         f"'None'): '{value_types}', this is not supported."
#     100     )
#     102 if bool in value_types or bool_ in value_types:
#     103     column_resources.append(
#     104         ColumnsField(name=name, type=ColumnTypes.BOOLEAN)
#     105     )
#
# PYDSDBError: For column: 'DemuxType_hashing' with row 'object' dtype row values have more than one type (excluding 'None'): '{<class 'float'>, <class 'str'>}', this is not supported.

# %%
dsid, version
# Out:
# ('test-DS000004801', '2')

# %% [markdown]
# ## 6. Retrieve back the dataset for checking purpose

# %%
import pydsdb

# %%
dss = pydsdb.get_dataset(dsid, dev=DEV, version=version)
# Out:
# 17:43:19 -> Collating dataset: 'test-DS000004801' metadata.
#
# 17:43:23 -> Reading: 'test-DS000004801'.
# Column Data -> Data Frame: 100%|████████████████████████████████████████| 102/102 [00:00<00:00, 22.9kB/s]
# 17:43:23 -> Reading: 'test-DS000004801 -> Experiment: main'.
#
# 17:43:23 -> Reading: 'test-DS000004801 -> Experiment: main -> Alt. Exp.: crispr'.
# Alt. Exp.: crispr -> Reduced Dimensions -> NDArrays: 100%|████████████████████████████████████████| 800/800 [00:00<00:00, 243kB/s]
# Alt. Exp.: crispr -> Assay: counts -> Sparse Matrix: 100%|████████████████████████████████████████| 4.64M/4.64M [00:18<00:00, 248kB/s]
# Alt. Exp.: crispr -> Column Data -> Data Frame: 100%|████████████████████████████████████████| 164k/164k [00:00<00:00, 186kB/s]
# Alt. Exp.: crispr -> Row Data -> Data Frame: 100%|████████████████████████████████████████| 51.8k/51.8k [00:00<00:00, 219kB/s]
# Experiment: main -> Reduced Dimensions -> NDArrays: 100%|████████████████████████████████████████| 800/800 [00:00<00:00, 200kB/s]
# Experiment: main -> Assay: counts -> Sparse Matrix: 100%|████████████████████████████████████████| 303M/303M [21:14<00:00, 238kB/s]
# Experiment: main -> Column Data -> Data Frame: 100%|████████████████████████████████████████| 743k/743k [00:02<00:00, 274kB/s]
# Experiment: main -> Row Data -> Data Frame: 100%|████████████████████████████████████████| 408k/408k [00:01<00:00, 205kB/s]
# 18:05:06 -> Reading: 'test-DS000004801 -> Experiment: raw_qc'.
# Experiment: raw_qc -> Reduced Dimensions -> NDArrays: 100%|████████████████████████████████████████| 800/800 [00:00<00:00, 379kB/s]
# Experiment: raw_qc -> Assay: counts -> Sparse Matrix: 100%|████████████████████████████████████████| 207M/207M [14:01<00:00, 246kB/s]
# Experiment: raw_qc -> Assay: X -> Sparse Matrix: 100%|████████████████████████████████████████| 310M/310M [03:21<00:00, 1.54MB/s]
# Experiment: raw_qc -> Column Data -> Data Frame -> Column: Sample -> Data Frame: 100%|████████████████████████████████████████| 57.0/57.0 [00:00<00:00, 19.1kB/s]
# Experiment: raw_qc -> Column Data -> Data Frame -> Column: Barcode -> Data Frame: 100%|████████████████████████████████████████| 105k/105k [00:00<00:00, 2.17MB/s]
# Experiment: raw_qc -> Column Data -> Data Frame -> Column: demux_type -> Data Frame: 100%|████████████████████████████████████████| 39.0/39.0 [00:00<00:00, 11.7kB/s]
# Experiment: raw_qc -> Column Data -> Data Frame -> Column: assignment -> Data Frame: 100%|████████████████████████████████████████| 58.0/58.0 [00:00<00:00, 17.2kB/s]
# Experiment: raw_qc -> Column Data -> Data Frame -> Column: phase -> Data Frame: 100%|████████████████████████████████████████| 40.0/40.0 [00:00<00:00, 11.8kB/s]
# Experiment: raw_qc -> Column Data -> Data Frame: 100%|████████████████████████████████████████| 1.67M/1.67M [00:00<00:00, 15.8MB/s]
# Experiment: raw_qc -> Row Data -> Data Frame -> Column: Symbol -> Data Frame: 100%|████████████████████████████████████████| 76.1k/76.1k [00:00<00:00, 24.2MB/s]
# Experiment: raw_qc -> Row Data -> Data Frame -> Column: Type -> Data Frame: 100%|████████████████████████████████████████| 47.0/47.0 [00:00<00:00, 20.0kB/s]
# Experiment: raw_qc -> Row Data -> Data Frame: 100%|████████████████████████████████████████| 886k/886k [00:00<00:00, 68.7MB/s]
# 18:22:35 -> Reading: 'test-DS000004801 -> Experiment: crispr_hashing_harmonized'.
#
# 18:22:35 -> Reading: 'test-DS000004801 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: crispr'.
# Alt. Exp.: crispr -> Reduced Dimensions -> NDArrays: 100%|████████████████████████████████████████| 800/800 [00:00<00:00, 173kB/s]
# Alt. Exp.: crispr -> Assay: counts -> Sparse Matrix: 100%|████████████████████████████████████████| 4.64M/4.64M [00:01<00:00, 3.93MB/s]
# Alt. Exp.: crispr -> Column Data -> Data Frame: 100%|████████████████████████████████████████| 164k/164k [00:00<00:00, 32.3MB/s]
# Alt. Exp.: crispr -> Row Data -> Data Frame: 100%|████████████████████████████████████████| 51.8k/51.8k [00:00<00:00, 1.33MB/s]
# 18:22:37 -> Reading: 'test-DS000004801 -> Experiment: crispr_hashing_harmonized -> Alt. Exp.: hashing'.
# Alt. Exp.: hashing -> Reduced Dimensions -> NDArrays: 100%|████████████████████████████████████████| 800/800 [00:00<00:00, 232kB/s]
# Alt. Exp.: hashing -> Assay: counts -> Sparse Matrix: 100%|████████████████████████████████████████| 595k/595k [00:00<00:00, 1.46MB/s]
# Alt. Exp.: hashing -> Column Data -> Data Frame: 100%|████████████████████████████████████████| 164k/164k [00:00<00:00, 3.38MB/s]
# Alt. Exp.: hashing -> Row Data -> Data Frame: 100%|████████████████████████████████████████| 59.0/59.0 [00:00<00:00, 17.2kB/s]
# Experiment: crispr_hashing_harmonized -> Reduced Dimensions -> NDArrays: 100%|████████████████████████████████████████| 800/800 [00:00<00:00, 232kB/s]
# Experiment: crispr_hashing_harmonized -> Assay: counts -> Sparse Matrix: 100%|████████████████████████████████████████| 303M/303M [00:37<00:00, 8.18MB/s]
# Experiment: crispr_hashing_harmonized -> Column Data -> Data Frame: 100%|████████████████████████████████████████| 644k/644k [00:00<00:00, 23.5MB/s]
# Experiment: crispr_hashing_harmonized -> Row Data -> Data Frame: 100%|████████████████████████████████████████| 408k/408k [00:00<00:00, 97.2MB/s]
# Sample Mapping: 100%|████████████████████████████████████████| 725k/725k [00:00<00:00, 24.1MB/s]
# /apps/user/gpy/envs/dev/GPy39/lib/python3.9/site-packages/multiassayexperiment/MultiAssayExperiment.py:112: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for group, rows in agroups:

# %%
dss.metadata
# Out:
# {'.internal': {'metadata': '{"dataset": {"authors": ["SG"], "column_data": {"resource": {"path": "sample_data/simple.csv.gz", "type": "local"}}, "creation_date": "2023-04-05T19:11:25+00:00", "description": "Siavash test upload; this should be gone", "experiments": [{"name": "main", "resource": {"path": "experiment-1/experiment.json", "type": "local"}}, {"name": "raw_qc", "resource": {"path": "experiment-2/experiment.json", "type": "local"}}, {"name": "crispr_hashing_harmonized", "resource": {"path": "experiment-3/experiment.json", "type": "local"}}], "sample_mapping": {"resource": {"path": "sample_mapping/simple.csv.gz", "type": "local"}}, "title": "Siavash test upload"}, "is_child": false, "path": "dataset.json", "$schema": "dataset/v2.json"}',
#   'paths': ['dataset.json',
#    'sample_data/simple.csv.gz',
#    'sample_mapping/simple.csv.gz'],
#   'column_data':                                                                            samples
#   unknown_sample_crispr_hashing_harmonized  unknown_sample_crispr_hashing_harmonized
#   unknown_sample_raw_qc                                        unknown_sample_raw_qc
#   unknown_sample_main                                            unknown_sample_main,
#   'sample_mapping':                            assay                                   primary  \
#   0      crispr_hashing_harmonized  unknown_sample_crispr_hashing_harmonized
#   1      crispr_hashing_harmonized  unknown_sample_crispr_hashing_harmonized
#   2      crispr_hashing_harmonized  unknown_sample_crispr_hashing_harmonized
#   3      crispr_hashing_harmonized  unknown_sample_crispr_hashing_harmonized
#   4      crispr_hashing_harmonized  unknown_sample_crispr_hashing_harmonized
#   ...                          ...                                       ...
#   37066                       main                       unknown_sample_main
#   37067                       main                       unknown_sample_main
#   37068                       main                       unknown_sample_main
#   37069                       main                       unknown_sample_main
#   37070                       main                       unknown_sample_main
#
#                                            colname
#   0      SAM24424070_Replicate1-AAACCCAAGACGTCGA-1
#   1      SAM24424070_Replicate1-AAACCCAAGAGATTCA-1
#   2      SAM24424070_Replicate1-AAACCCAAGCCAGACA-1
#   3      SAM24424070_Replicate1-AAACCCAAGCGATGCA-1
#   4      SAM24424070_Replicate1-AAACCCAAGGATATGT-1
#   ...                                          ...
#   37066  SAM24424071_Replicate1-TTTGTTGTCGCCGAAC-1
#   37067  SAM24424071_Replicate1-TTTGTTGTCGCGAAGA-1
#   37068  SAM24424071_Replicate1-TTTGTTGTCGCTGTCT-1
#   37069  SAM24424071_Replicate1-TTTGTTGTCGTCACCT-1
#   37070  SAM24424071_Replicate1-TTTGTTGTCTGGGTCG-1
#
#   [100044 rows x 3 columns],
#   'exp_nums': {'main': 1, 'raw_qc': 2, 'crispr_hashing_harmonized': 3},
#   'permissions_info': {'owners': ['ghaffars'],
#    'read_access': 'public',
#    'scope': 'project',
#    'write_access': 'owners'}}}

# %%
print(dss)
# Out:
#         Class MultiAssayExperiment with 3 experiments and 3 samples
#             experiments:
#                 ["main: \n        Class SingleCellExperiment with 36603 features and 37071 cells\n          mainExperimentName: None\n          assays: ['counts']\n          features: Index(['ID', 'Symbol', 'Type'], dtype='object')\n          cell metadata: Index(['Sample', 'Barcode', 'demux_type', 'assignment', 'pBarcode_assignment'], dtype='object')\n          reduced dimensions: []\n          alternative experiments: ['crispr']\n        ", "raw_qc: \n        Class SingleCellExperiment with 26987 features and 25902 cells\n          mainExperimentName: None\n          assays: ['counts', 'X']\n          features: Index(['ID', 'Symbol', 'Type', 'mt', 'ribo', 'n_cells_by_counts',\n       'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'n_cells'],\n      dtype='object')\n          cell metadata: Index(['Sample', 'Barcode', 'demux_type', 'assignment', 'n_genes_by_counts',\n       'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo',\n       'pct_counts_ribo', 'n_genes', 'phase', 'G2M_score', 'S_score'],\n      dtype='object')\n          reduced dimensions: []\n          alternative experiments: None\n        ", "crispr_hashing_harmonized: \n        Class SingleCellExperiment with 36603 features and 37071 cells\n          mainExperimentName: None\n          assays: ['counts']\n          features: Index(['ID', 'Symbol', 'Type'], dtype='object')\n          cell metadata: Index(['Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr',\n       'DemuxType_hashing', 'DemuxAssignment_hashing', 'Protocol'],\n      dtype='object')\n          reduced dimensions: []\n          alternative experiments: ['crispr', 'hashing']\n        "]

# %%
adata_2, adatas_2 = dss.experiments["main"].toAnnData(alts=True)

# %%
adata_2
# Out:
# AnnData object with n_obs × n_vars = 37071 × 36603
#     obs: 'Sample', 'Barcode', 'demux_type', 'assignment', 'pBarcode_assignment'
#     var: 'ID', 'Symbol', 'Type'
#     uns: '.internal'
#     layers: 'counts'

# %%
adatas_2
# Out:
# {'crispr': AnnData object with n_obs × n_vars = 37071 × 21091
#      uns: '.internal'
#      layers: 'counts'}

# %%
adata_3, adatas_3 = dss.experiments["crispr_hashing_harmonized"].toAnnData(alts=True)

# %%
adata_3
# Out:
# AnnData object with n_obs × n_vars = 37071 × 36603
#     obs: 'Sample', 'Barcode', 'DemuxType_crispr', 'DemuxAssignment_crispr', 'DemuxType_hashing', 'DemuxAssignment_hashing', 'Protocol'
#     var: 'ID', 'Symbol', 'Type'
#     uns: '.internal'
#     layers: 'counts'

# %%
adatas_3
# Out:
# {'crispr': AnnData object with n_obs × n_vars = 37071 × 21091
#      uns: '.internal'
#      layers: 'counts',
#  'hashing': AnnData object with n_obs × n_vars = 37071 × 8
#      uns: '.internal'
#      layers: 'counts'}
